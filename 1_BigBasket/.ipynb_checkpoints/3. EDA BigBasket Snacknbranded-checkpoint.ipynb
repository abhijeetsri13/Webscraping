# %% [markdown]
# ## This notebook is for EDA on Bigbasket Beverage section, this is to be perfomed on each dataset/csv file extracted from website using scrapping.
# ### Import SYS and OS and display system version with current working directory.
# ### On next cell, import the Pandas, Numpy and Matplotlib for various EDA functions.

# %%
import sys
print(sys.version)

import os
print(os.getcwd())
# Out:
# 3.11.3 | packaged by Anaconda, Inc. | (main, Apr 19 2023, 23:46:34) [MSC v.1916 64 bit (AMD64)]
# C:\Users\pijadhav\OneDrive - BMC Software, Inc\BITS DS\Piyush

# %% [markdown]
# ### This is to import all the necessary libraries from python directories in order to run the various commands.

# %%
import pandas as pd
print("pandas imported as pd")
import numpy as np
print("numpy imported as np")
import matplotlib
print("matplotlib imported")
# Out:
# pandas imported as pd
# numpy imported as np
# matplotlib imported

# %% [markdown]
# # Data Exploration by printing basic
# ### Reading the .csv file into the local dataset created for reading and viewing or explorative data analysis purpose using pandas
#
# ### BB_Snacknbranded will now contain all the data as it is present in a .csv file saved at particular location.

# %% [markdown]
# ### BB_Snacknbranded will now contain all the data as it is present in a .csv file saved at particular location.
# ### Data Exploration by printing basic info, info command describes the information present at csv on very high level, by using it and reading the output of the same,
# ### we can analyze that dataset have 6 columns (0-5), Column has null or not-null count, Data types.
# ### Quantitative variable is either integer or float.
# ### Qualitative/categorical variable is always of object type.

# %%
# Reading the .csv file.
BB_Snacknbranded=pd.read_csv('C:/Users/pijadhav/OneDrive - BMC Software, Inc/BITS DS/Piyush/BB_Snacknbranded_23Nov.csv')

#info command dispalys the basic information about the dataset. 
BB_Snacknbranded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      901 non-null    int64
#  1   Grocery_Name    901 non-null    object
#  2   Discount_Price  901 non-null    object
#  3   MRP_Price       901 non-null    object
#  4   Brand_Name      901 non-null    object
#  5   Quantity        901 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 42.4+ KB

# %%
print("BB_Snacknbranded_columns:",BB_Snacknbranded.columns)
# Column command provides the desciption of the columns i.e.'Unnamed: 0','Grocery_Name','Discount_Price','MRP_Price','Brand_Name', 'Quantity'.
# Out:
# BB_Snacknbranded_columns: Index(['Unnamed: 0', 'Grocery_Name', 'Discount_Price', 'MRP_Price',
#        'Brand_Name', 'Quantity'],
#       dtype='object')

# %%
# Data Exploration by looking at some records
#this prints the head of the CSV dataset, as we have mentioned 5 in brackets it printed top 5 recrods.
print("Top 5 recs:")
print(BB_Snacknbranded.head(5))
print("Last 5 recs:")
BB_Snacknbranded.tail(5)
# Out:
# Top 5 recs:
#    Unnamed: 0                                       Grocery_Name  \
# 0           0                            Gulab Jamun Dessert Mix
# 1           1                       2-Min Masala Instant Noodles
# 2           2  Chocolate Muesli - With 57% Multigrain, Fruit,...
# 3           3  Marie Gold Biscuit - Crunchy, Light, Zero Tran...
# 4           4                           Gluco Biscuits - Parle-G
#
#   Discount_Price MRP_Price    Brand_Name                    Quantity
# 0         ₹133.4      ₹145  Tata Sampann  175 g - (Buy 1 Get 1 Free)
# 1           ₹160      ₹168        MAGGI    840 g - (12 Packs x 70 g)
# 2           ₹310      ₹360      Kelloggs                      450 g
# 3           ₹120      ₹140     Britannia                      950 g
# 4           ₹108      ₹120         Parle        12x130 g - Multipack
# Last 5 recs:
#      Unnamed: 0                                       Grocery_Name  \
# 896         896                   Roasted Peanuts - Lemon & Chilli
# 897         897  Oats - Dark Chocolate, Healthy, High In Fibre,...
# 898         898  Oats -Whole Grain, Breakfast Cereal, Rich In F...
# 899         899                      Snack Bar - Multigrain, Choco
# 900         900                   Playz Puffs Masala Munch Namkeen
#
#     Discount_Price MRP_Price Brand_Name            Quantity
# 896            ₹70       ₹70    JABSONS              140 g
# 897            ₹15       ₹25   Yoga Bar               40 g
# 898           ₹119      ₹119     Quaker       600 g - Pouch
# 899           ₹180      ₹240     UNIBIC  6X30 g - Multipack
# 900            ₹18       ₹20    Kurkure               55 g

# %% [markdown]
# ### By looking at those records we came to know that, Sr. No. Column is named as "Unnamed", we need to change that for more meaningful column name. Discount price and MRP price has rupees symbol included in it, because of which it is showing as type as object which should be changed to float to have various operations to be performed on it, Quantity has multiple values associated with it, Box, Multipack etc etc. this field can be modified to get the per gram or per liter value of mentioned product.

# %%
#using include(all) command for data exploration we can get more insights of the data that has been extracted. 

BB_Snacknbranded.describe(include='all')
# Out:
#         Unnamed: 0 Grocery_Name Discount_Price MRP_Price  Brand_Name Quantity
# count   901.000000          901            901       901         901      901
# unique         NaN          871            423       203         205      459
# top            NaN   Vermicelli            ₹60      ₹120  Haldiram's   200 g
# freq           NaN            4             22        39          40       35
# mean    450.000000          NaN            NaN       NaN         NaN      NaN
# std     260.240594          NaN            NaN       NaN         NaN      NaN
# min       0.000000          NaN            NaN       NaN         NaN      NaN
# 25%     225.000000          NaN            NaN       NaN         NaN      NaN
# 50%     450.000000          NaN            NaN       NaN         NaN      NaN
# 75%     675.000000          NaN            NaN       NaN         NaN      NaN
# max     900.000000          NaN            NaN       NaN         NaN      NaN

# %%
# By checking the Discount_Price we get to know that it has rupees sign init. We would have to replace it and also need to change it numeric column.
print('Discount_price before:',BB_Snacknbranded.Discount_Price)
BB_Snacknbranded['Discount_Price'] = BB_Snacknbranded['Discount_Price'].str.replace('₹', '')
BB_Snacknbranded['Discount_Price'] = BB_Snacknbranded.Discount_Price.astype(float)
BB_Snacknbranded.Discount_Price
# Out:
# Discount_price before: 0      ₹133.4
# 1        ₹160
# 2        ₹310
# 3        ₹120
# 4        ₹108
#         ...
# 896       ₹70
# 897       ₹15
# 898      ₹119
# 899      ₹180
# 900       ₹18
# Name: Discount_Price, Length: 901, dtype: object
# 0      133.4
# 1      160.0
# 2      310.0
# 3      120.0
# 4      108.0
#        ...
# 896     70.0
# 897     15.0
# 898    119.0
# 899    180.0
# 900     18.0
# Name: Discount_Price, Length: 901, dtype: float64

# %%
# By checking the MRP_Price we get to know that it has rupees sign embeded init. We would have to replace it and also need to change it numeric column.print(BB_Snacknbranded.MRP_Price)
print('MRP_price before:',BB_Snacknbranded.MRP_Price)
BB_Snacknbranded['MRP_Price'] = BB_Snacknbranded['MRP_Price'].str.replace('₹', '')
BB_Snacknbranded['MRP_Price'] = BB_Snacknbranded.MRP_Price.astype(float)
BB_Snacknbranded.MRP_Price
# Out:
# MRP_price before: 0      145.0
# 1      168.0
# 2      360.0
# 3      140.0
# 4      120.0
#        ...
# 896     70.0
# 897     25.0
# 898    119.0
# 899    240.0
# 900     20.0
# Name: MRP_Price, Length: 901, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 # By checking the MRP_Price we get to know that it has rupees sign embeded init. We would have to replace it and also need to change it numeric column.print(BB_foodnoil.MRP_Price)
#       2 print('MRP_price before:',BB_Snacknbranded.MRP_Price)
# ----> 3 BB_Snacknbranded['MRP_Price'] = BB_Snacknbranded['MRP_Price'].str.replace('₹', '')
#       4 BB_Snacknbranded['MRP_Price'] = BB_Snacknbranded.MRP_Price.astype(float)
#       5 BB_Snacknbranded.MRP_Price
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
# Now if we describe the dataset, it give below information. Which included the Discount and MRP price as numeric.
BB_Snacknbranded.describe(include='all')
# Out:
#         Unnamed: 0 Grocery_Name  Discount_Price     MRP_Price  Brand_Name  \
# count   901.000000          901      901.000000    901.000000         901
# unique         NaN          871             NaN           NaN         205
# top            NaN   Vermicelli             NaN           NaN  Haldiram's
# freq           NaN            4             NaN           NaN          40
# mean    450.000000          NaN      191.953285    227.174251         NaN
# std     260.240594          NaN      410.431186    486.666853         NaN
# min       0.000000          NaN        0.000000      0.000000         NaN
# 25%     225.000000          NaN       61.970000     70.000000         NaN
# 50%     450.000000          NaN      115.000000    130.000000         NaN
# 75%     675.000000          NaN      210.000000    270.000000         NaN
# max     900.000000          NaN     9792.000000  11520.000000         NaN
#
#        Quantity
# count       901
# unique      459
# top      200 g
# freq         35
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# ### Now we have the discout price and MRP price so we need to calculate the difference between both the price and check if all the products are discounted or only few are discounted ?

# %%
Diff = BB_Snacknbranded.MRP_Price - BB_Snacknbranded.Discount_Price
Diff_per = ((Diff/BB_Snacknbranded.MRP_Price)*100)

print("MRP:",BB_Snacknbranded.MRP_Price,"Dis_price:",BB_Snacknbranded.Discount_Price,"Diff:",Diff,"perc dis:",Diff_per)
# Out:
# MRP: 0      145.0
# 1      168.0
# 2      360.0
# 3      140.0
# 4      120.0
#        ...
# 896     70.0
# 897     25.0
# 898    119.0
# 899    240.0
# 900     20.0
# Name: MRP_Price, Length: 901, dtype: float64 Dis_price: 0      133.4
# 1      160.0
# 2      310.0
# 3      120.0
# 4      108.0
#        ...
# 896     70.0
# 897     15.0
# 898    119.0
# 899    180.0
# 900     18.0
# Name: Discount_Price, Length: 901, dtype: float64 Diff: 0      11.6
# 1       8.0
# 2      50.0
# 3      20.0
# 4      12.0
#        ...
# 896     0.0
# 897    10.0
# 898     0.0
# 899    60.0
# 900     2.0
# Length: 901, dtype: float64 perc dis: 0       8.000000
# 1       4.761905
# 2      13.888889
# 3      14.285714
# 4      10.000000
#          ...
# 896     0.000000
# 897    40.000000
# 898     0.000000
# 899    25.000000
# 900    10.000000
# Length: 901, dtype: float64

# %%
BB_Snacknbranded_clean = []
BB_Snacknbranded_clean = BB_Snacknbranded
BB_Snacknbranded_clean["Total Disc"] = Diff
BB_Snacknbranded_clean["Percetage Disc"] = Diff_per
BB_Snacknbranded_clean.rename(columns= {'Unnamed: 0':'Sr.No.'}, inplace=True)

# %%
BB_Snacknbranded_clean
# Out:
#      Sr.No.                                       Grocery_Name Discount_Price  \
# 0         0                            Gulab Jamun Dessert Mix         ₹133.4
# 1         1                       2-Min Masala Instant Noodles           ₹160
# 2         2  Chocolate Muesli - With 57% Multigrain, Fruit,...           ₹310
# 3         3  Marie Gold Biscuit - Crunchy, Light, Zero Tran...           ₹120
# 4         4                           Gluco Biscuits - Parle-G           ₹108
# ..      ...                                                ...            ...
# 896     896                   Roasted Peanuts - Lemon & Chilli            ₹70
# 897     897  Oats - Dark Chocolate, Healthy, High In Fibre,...            ₹15
# 898     898  Oats -Whole Grain, Breakfast Cereal, Rich In F...           ₹119
# 899     899                      Snack Bar - Multigrain, Choco           ₹180
# 900     900                   Playz Puffs Masala Munch Namkeen            ₹18
#
#     MRP_Price    Brand_Name                    Quantity  Total Disc  \
# 0        ₹145  Tata Sampann  175 g - (Buy 1 Get 1 Free)        11.6
# 1        ₹168        MAGGI    840 g - (12 Packs x 70 g)         8.0
# 2        ₹360      Kelloggs                      450 g         50.0
# 3        ₹140     Britannia                      950 g         20.0
# 4        ₹120         Parle        12x130 g - Multipack        12.0
# ..        ...           ...                         ...         ...
# 896       ₹70       JABSONS                      140 g          0.0
# 897       ₹25      Yoga Bar                       40 g         10.0
# 898      ₹119        Quaker               600 g - Pouch         0.0
# 899      ₹240        UNIBIC          6X30 g - Multipack        60.0
# 900       ₹20       Kurkure                       55 g          2.0
#
#      Percetage Disc
# 0          8.000000
# 1          4.761905
# 2         13.888889
# 3         14.285714
# 4         10.000000
# ..              ...
# 896        0.000000
# 897       40.000000
# 898        0.000000
# 899       25.000000
# 900       10.000000
#
# [901 rows x 8 columns]

# %%
BB_Snacknbranded_clean['Quantity']
# Out:
# 0      175 g - (Buy 1 Get 1 Free)
# 1       840 g - (12 Packs x 70 g)
# 2                          450 g
# 3                          950 g
# 4            12x130 g - Multipack
#                   ...
# 896                        140 g
# 897                         40 g
# 898                 600 g - Pouch
# 899            6X30 g - Multipack
# 900                         55 g
# Name: Quantity, Length: 901, dtype: object

# %%
#from pivottablejs import pivot_ui
#pivot_ui(BB_foodnoil_clean)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
BB_Snacknbranded_clean = BB_Snacknbranded_clean[['Sr.No.','Grocery_Name','Brand_Name','MRP_Price','Discount_Price','Total Disc','Percetage Disc','Quantity']]
BB_Snacknbranded_clean['Percetage Disc'] = BB_Snacknbranded_clean['Percetage Disc'].round(2)

#BB_Snacknbranded_clean.drop(["Srr.No."], axis=1)
BB_Snacknbranded_clean
# Out:
#      Sr.No.                                       Grocery_Name    Brand_Name  \
# 0         0                            Gulab Jamun Dessert Mix  Tata Sampann
# 1         1                       2-Min Masala Instant Noodles        MAGGI
# 2         2  Chocolate Muesli - With 57% Multigrain, Fruit,...      Kelloggs
# 3         3  Marie Gold Biscuit - Crunchy, Light, Zero Tran...     Britannia
# 4         4                           Gluco Biscuits - Parle-G         Parle
# ..      ...                                                ...           ...
# 896     896                   Roasted Peanuts - Lemon & Chilli       JABSONS
# 897     897  Oats - Dark Chocolate, Healthy, High In Fibre,...      Yoga Bar
# 898     898  Oats -Whole Grain, Breakfast Cereal, Rich In F...        Quaker
# 899     899                      Snack Bar - Multigrain, Choco        UNIBIC
# 900     900                   Playz Puffs Masala Munch Namkeen       Kurkure
#
#     MRP_Price Discount_Price  Total Disc  Percetage Disc  \
# 0        ₹145         ₹133.4        11.6            8.00
# 1        ₹168           ₹160         8.0            4.76
# 2        ₹360           ₹310        50.0           13.89
# 3        ₹140           ₹120        20.0           14.29
# 4        ₹120           ₹108        12.0           10.00
# ..        ...            ...         ...             ...
# 896       ₹70            ₹70         0.0            0.00
# 897       ₹25            ₹15        10.0           40.00
# 898      ₹119           ₹119         0.0            0.00
# 899      ₹240           ₹180        60.0           25.00
# 900       ₹20            ₹18         2.0           10.00
#
#                        Quantity
# 0    175 g - (Buy 1 Get 1 Free)
# 1     840 g - (12 Packs x 70 g)
# 2                        450 g
# 3                        950 g
# 4          12x130 g - Multipack
# ..                          ...
# 896                      140 g
# 897                       40 g
# 898               600 g - Pouch
# 899          6X30 g - Multipack
# 900                       55 g
#
# [901 rows x 8 columns]

# %%
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['Quantity'].str.split('-').str[0]

BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace(" x ", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace("x", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace(" X ", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace("X", "*")

print(BB_Snacknbranded_clean['strip_qua'])
# Out:
# 0         175 g
# 1         840 g
# 2         450 g
# 3         950 g
# 4      12*130 g
#          ...
# 896       140 g
# 897        40 g
# 898       600 g
# 899      6*30 g
# 900        55 g
# Name: strip_qua, Length: 901, dtype: object

# %%
if '*' in BB_Snacknbranded_clean['strip_qua']:
    print("Split the quantity into parts around *")
    parts = quantity_str.split('*')
        
    # Extract numerical values and units from the parts
    
    values = [float(re.search(r'(\d+(\.\d+)?)', part).group(1)) for part in parts]
    units = [re.search(r'([a-zA-Z]+)', part).group(1).lower() for part in parts]
    print("values:",values)
    print("units:",units)
    # Multiply the values and return the result
    result_value = 1
    for value in values:
        result_value *= value
        # Take the unit from the last part
        result_unit = units[-1]

print("result_value:", result_value, "result_unit:", result_unit)

BB_Snacknbranded_clean['strip_qua']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 18
#      15         # Take the unit from the last part
#      16         result_unit = units[-1]
# ---> 18 print("result_value:", result_value, "result_unit:", result_unit)
#      20 BB_Snacknbranded_clean['strip_qua']
#
# NameError: name 'result_value' is not defined

# %%
import re

def extract_first_numeric_part(quantity_str):

    match = re.match(r'(\d+)\*(\d+)\s*([a-zA-Z]+)', quantity_str)

    if match:
        multiplier = int(match.group(1))
        factor = int(match.group(2))
        unit = match.group(3)
        print("Multiplier:",multiplier,"factor:",factor,"unit:",unit)

        basic_unit_value = multiplier * factor
        #return basic_unit_value, unit
        new_quant = str(basic_unit_value)+' '+str(unit)
        print('Converted quant:',new_quant)
        return new_quant
        
    else:
        # If the format doesn't match, return the original value
        new_quant = quantity_str
        print("not converted:", new_quant)
        return new_quant
        

BB_Snacknbranded_clean['Quantity_upd'] = BB_Snacknbranded_clean['strip_qua'].apply(extract_first_numeric_part)

# Print the DataFrame with the extracted first numeric parts
print(BB_Snacknbranded_clean[['strip_qua', 'Quantity_upd']])
# Out:
# not converted: 175 g
# not converted: 840 g
# not converted: 450 g
# not converted: 950 g
# Multiplier: 12 factor: 130 unit: g
# Converted quant: 1560 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 135 g
# not converted: 12* 41.7 g
# Multiplier: 2 factor: 138 unit: g
# Converted quant: 276 g
# not converted: 135 g
# not converted: 2 kg
# not converted: 75 g
# Multiplier: 6 factor: 44 unit: g
# Converted quant: 264 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# not converted: 265 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 2 factor: 750 unit: g
# Converted quant: 1500 g
# Multiplier: 6 factor: 24 unit: g
# Converted quant: 144 g
# Multiplier: 3 factor: 160 unit: g
# Converted quant: 480 g
# Multiplier: 2 factor: 350 unit: g
# Converted quant: 700 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 2* 250 g
# not converted: 3* 100 g
# not converted: 918.75 g
# not converted: 1 kg
# not converted: 1 kg
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 300 g
# not converted: 120 g
# Multiplier: 6 factor: 60 unit: g
# Converted quant: 360 g
# not converted: 1 kg
# Multiplier: 4 factor: 45 unit: g
# Converted quant: 180 g
# Multiplier: 24 factor: 250 unit: g
# Converted quant: 6000 g
# Multiplier: 12 factor: 21 unit: g
# Converted quant: 252 g
# not converted: 435 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# Multiplier: 2 factor: 300 unit: g
# Converted quant: 600 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# Multiplier: 6 factor: 45 unit: g
# Converted quant: 270 g
# Multiplier: 6 factor: 50 unit: g
# Converted quant: 300 g
# not converted: 400 g
# Multiplier: 12 factor: 15 unit: g
# Converted quant: 180 g
# not converted: 481.25 g
# Multiplier: 3 factor: 300 unit: g
# Converted quant: 900 g
# Multiplier: 6 factor: 58 unit: g
# Converted quant: 348 g
# not converted: 1 kg
# Multiplier: 6 factor: 120 unit: g
# Converted quant: 720 g
# not converted: 700 g
# not converted: 600 g
# not converted: 750 g
# not converted: 450 g
# Multiplier: 3 factor: 96 unit: g
# Converted quant: 288 g
# not converted: 138.6 g
# not converted: 134 g
# not converted: 850 g
# Multiplier: 6 factor: 45 unit: g
# Converted quant: 270 g
# not converted: 700 g
# Multiplier: 2 factor: 240 unit: g
# Converted quant: 480 g
# Multiplier: 3 factor: 200 unit: ml
# Converted quant: 600 ml
# Multiplier: 15 factor: 350 unit: g
# Converted quant: 5250 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# not converted: 10 g
# Multiplier: 6 factor: 143 unit: g
# Converted quant: 858 g
# Multiplier: 2 factor: 273 unit: g
# Converted quant: 546 g
# Multiplier: 2 factor: 60 unit: g
# Converted quant: 120 g
# Multiplier: 3 factor: 119 unit: g
# Converted quant: 357 g
# not converted: 1.1 kg
# not converted: 700 g
# Multiplier: 12 factor: 18 unit: g
# Converted quant: 216 g
# Multiplier: 3 factor: 114 unit: g
# Converted quant: 342 g
# not converted: 500 g
# not converted: 1 kg
# not converted: 584 g
# Multiplier: 6 factor: 21 unit: g
# Converted quant: 126 g
# Multiplier: 2 factor: 117 unit: g
# Converted quant: 234 g
# Multiplier: 2 factor: 650 unit: g
# Converted quant: 1300 g
# not converted: 277.5 g
# not converted: 200 g
# Multiplier: 12 factor: 50 unit: g
# Converted quant: 600 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# Multiplier: 8 factor: 36 unit: g
# Converted quant: 288 g
# not converted: 500 g
# not converted: 277.5 g
# not converted: 1.2 Kg
# Multiplier: 4 factor: 150 unit: g
# Converted quant: 600 g
# Multiplier: 3 factor: 137 unit: g
# Converted quant: 411 g
# not converted: 1.3 kg
# not converted: 1.25 kg
# not converted: 1 kg
# not converted: 900 g
# not converted: 200 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# not converted: 135 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# Multiplier: 12 factor: 69 unit: g
# Converted quant: 828 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 400 g
# Multiplier: 3 factor: 30 unit: g
# Converted quant: 90 g
# Multiplier: 3 factor: 40 unit: g
# Converted quant: 120 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# not converted: 100 g
# Multiplier: 3 factor: 126 unit: g
# Converted quant: 378 g
# not converted: 18 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# not converted: 300 g
# not converted: 2*481.25 g
# not converted: 3*288.75 g
# not converted: 400 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# not converted: 135 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# not converted: 125 g
# Multiplier: 6 factor: 33 unit: g
# Converted quant: 198 g
# not converted: 970 g
# not converted: 25 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 800 g
# not converted: 5* 85.3 g
# not converted: 10 g
# not converted: 95.5 g
# not converted: 1 kg
# Multiplier: 2 factor: 1 unit: kg
# Converted quant: 2 kg
# not converted: 75 g
# not converted: 850 g
# not converted: 5*51.1 g
# Multiplier: 4 factor: 100 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 1 unit: Kg
# Converted quant: 2 Kg
# not converted: 200 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 1 kg
# not converted: 3 *71.5 g
# not converted: 95.5 g
# not converted: 2 kg
# not converted: 1 Kg
# not converted: 3*191.9 g
# Multiplier: 8 factor: 70 unit: g
# Converted quant: 560 g
# Multiplier: 5 factor: 150 unit: g
# Converted quant: 750 g
# not converted: 150 g
# Multiplier: 3 factor: 200 unit: g
# Converted quant: 600 g
# Multiplier: 2 factor: 1 unit: kg
# Converted quant: 2 kg
# Multiplier: 6 factor: 69 unit: g
# Converted quant: 414 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# not converted: 400 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 135 g
# Multiplier: 10 factor: 10 unit: g
# Converted quant: 100 g
# not converted: 1 kg
# not converted: 2*82.5 g
# Multiplier: 2 factor: 85 unit: g
# Converted quant: 170 g
# not converted: 75 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 57 g
# Multiplier: 2 factor: 1 unit: kg
# Converted quant: 2 kg
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 500 g
# Multiplier: 6 factor: 58 unit: g
# Converted quant: 348 g
# Multiplier: 3 factor: 250 unit: g
# Converted quant: 750 g
# not converted: 720 g
# not converted: 1 kg
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# Multiplier: 5 factor: 28 unit: g
# Converted quant: 140 g
# not converted: 150 g
# not converted: 86 g
# not converted: 75 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 65 g
# not converted: 253.3 g
# not converted: 3*113.75 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# Multiplier: 5 factor: 28 unit: g
# Converted quant: 140 g
# Multiplier: 2 factor: 260 unit: g
# Converted quant: 520 g
# not converted: 400 g
# not converted: 41 g
# Multiplier: 2 factor: 56 unit: g
# Converted quant: 112 g
# not converted: 840 g
# not converted: 200 g
# not converted: 35 g
# not converted: 924 g
# not converted: 60 g
# not converted: 135 g
# not converted: 33.4 g
# not converted: 300 g
# not converted: 500 g
# Multiplier: 2 factor: 250 unit: g
# Converted quant: 500 g
# not converted: 1 Kg
# Multiplier: 3 factor: 200 unit: g
# Converted quant: 600 g
# Multiplier: 8 factor: 30 unit: g
# Converted quant: 240 g
# Multiplier: 10 factor: 12 unit: g
# Converted quant: 120 g
# not converted: 1 kg
# not converted: 1.25 kg
# not converted: 150 g
# not converted: 500 g
# not converted: 400 g
# Multiplier: 10 factor: 11 unit: g
# Converted quant: 110 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 100 unit: g
# Converted quant: 200 g
# not converted: 1 Kg
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 12.5 g
# not converted: 850 g
# not converted: 248 g
# Multiplier: 6 factor: 55 unit: g
# Converted quant: 330 g
# not converted: 80 g
# Multiplier: 3 factor: 52 unit: g
# Converted quant: 156 g
# Multiplier: 3 factor: 153 unit: g
# Converted quant: 459 g
# not converted: 1 kg
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# Multiplier: 3 factor: 190 unit: g
# Converted quant: 570 g
# Multiplier: 3 factor: 1 unit: kg
# Converted quant: 3 kg
# Multiplier: 3 factor: 186 unit: g
# Converted quant: 558 g
# not converted: 500 g
# not converted: 350 g
# Multiplier: 12 factor: 64 unit: g
# Converted quant: 768 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 1.15 Kg
# not converted: 850 g
# not converted: 12 g
# not converted: 500 g
# Multiplier: 6 factor: 65 unit: g
# Converted quant: 390 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# Multiplier: 3 factor: 35 unit: g
# Converted quant: 105 g
# Multiplier: 3 factor: 40 unit: g
# Converted quant: 120 g
# not converted: 9.5 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# Multiplier: 8 factor: 36 unit: g
# Converted quant: 288 g
# not converted: 200 g
# not converted: 180 g
# not converted: 396 g
# not converted: 38 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# Multiplier: 6 factor: 80 unit: g
# Converted quant: 480 g
# Multiplier: 288 factor: 45 unit: g
# Converted quant: 12960 g
# not converted: 391 g
# not converted: 200 g
# not converted: 60 g
# Multiplier: 6 factor: 55 unit: g
# Converted quant: 330 g
# Multiplier: 3 factor: 175 unit: g
# Converted quant: 525 g
# not converted: 200 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 100 g
# not converted: 800 g
# not converted: 200 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 38 g
# not converted: 280 g
# Multiplier: 2 factor: 600 unit: g
# Converted quant: 1200 g
# Multiplier: 3 factor: 45 unit: g
# Converted quant: 135 g
# not converted: 200 g
# Multiplier: 6 factor: 99 unit: g
# Converted quant: 594 g
# not converted: 200 g
# not converted: 2* 150 g
# not converted: 200 g
# not converted: 100 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 336 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 1 kg
# not converted: 40 g
# not converted: 38 g
# not converted: 1 kg
# Multiplier: 2 factor: 35 unit: g
# Converted quant: 70 g
# not converted: 200 g
# Multiplier: 2 factor: 55 unit: g
# Converted quant: 110 g
# not converted: 400 g
# not converted: 1 kg
# not converted: 800 g
# not converted: 60 g
# not converted: 700 g
# not converted: 200 g
# Multiplier: 6 factor: 58 unit: gm
# Converted quant: 348 gm
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 3 factor: 200 unit: g
# Converted quant: 600 g
# not converted: 36 g
# not converted: 120 g
# not converted: 500 g
# Multiplier: 3 factor: 56 unit: g
# Converted quant: 168 g
# not converted: 30 g
# not converted: 200 g
# not converted: 750 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# Multiplier: 2 factor: 350 unit: g
# Converted quant: 700 g
# not converted: 500 g
# not converted: 160 g
# not converted: 59.8 g
# not converted: 400 g
# not converted: 150 g
# not converted: 200 g
# not converted: 50 g
# not converted: 34 g
# Multiplier: 3 factor: 200 unit: g
# Converted quant: 600 g
# not converted: 284 g
# not converted: 460 g
# not converted: 150 g
# not converted: 1 kg
# not converted: 180 g
# Multiplier: 5 factor: 96 unit: g
# Converted quant: 480 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 60 unit: g
# Converted quant: 120 g
# Multiplier: 2 factor: 900 unit: g
# Converted quant: 1800 g
# not converted: 900 g
# not converted: 200 g
# not converted: 500 g
# Multiplier: 12 factor: 500 unit: g
# Converted quant: 6000 g
# Multiplier: 6 factor: 59 unit: g
# Converted quant: 354 g
# not converted: 500 g
# Multiplier: 2 factor: 425 unit: g
# Converted quant: 850 g
# Multiplier: 8 factor: 45 unit: g
# Converted quant: 360 g
# not converted: 42 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 107 unit: g
# Converted quant: 214 g
# not converted: 250 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# not converted: 80 g
# not converted: 30 g
# not converted: 200 g
# not converted: 200 g
# not converted: 45 g
# not converted: 60 g
# Multiplier: 2 factor: 25 unit: Sheets
# Converted quant: 50 Sheets
# not converted: 150 g
# not converted: 200 g
# not converted: 400 g
# not converted: 300 g
# Multiplier: 3 factor: 192 unit: g
# Converted quant: 576 g
# not converted: 75 g
# not converted: 150 g
# not converted: 139 g
# not converted: 450 g
# not converted: 3* 75 g
# not converted: 27.5 g
# not converted: 178.8 g
# Multiplier: 3 factor: 90 unit: g
# Converted quant: 270 g
# not converted: 300 g
# Multiplier: 3 factor: 45 unit: g
# Converted quant: 135 g
# not converted: 180 g
# not converted: 1 kg
# not converted: 300 g
# not converted: 177 g
# Multiplier: 3 factor: 50 unit: g
# Converted quant: 150 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 946 unit: ml
# Converted quant: 1892 ml
# not converted: 180 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 750 g
# not converted: 242 g
# Multiplier: 2 factor: 107 unit: g
# Converted quant: 214 g
# not converted: 60 g
# not converted: 100 g
# not converted: 58 g
# not converted: 500 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 500 g
# not converted: 900 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 75 g
# not converted: 850 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# not converted: 400 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 3*142.8 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 250 g
# not converted: 935 g
# not converted: 450 g
# not converted: 200 g
# not converted: 900 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# not converted: 2* 375 g
# Multiplier: 6 factor: 120 unit: g
# Converted quant: 720 g
# not converted: 1 Kg
# not converted: 420 g
# not converted: 200 g
# not converted: 500 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# Multiplier: 3 factor: 130 unit: g
# Converted quant: 390 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 1 kg
# not converted: 125 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# not converted: 270 g
# not converted: 250 g
# not converted: 200 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 185 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 150 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 27.5 g
# not converted: 170 g
# not converted: 80 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# not converted: 500 g
# not converted: 50 g
# not converted: 100 g
# not converted: 9 g
# Multiplier: 4 factor: 60 unit: g
# Converted quant: 240 g
# Multiplier: 2 factor: 350 unit: g
# Converted quant: 700 g
# not converted: 850 g
# not converted: 68.5 g
# not converted: 250 g
# not converted: 200 g
# Multiplier: 2 factor: 100 unit: g
# Converted quant: 200 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 3 factor: 330 unit: g
# Converted quant: 990 g
# not converted: 200 g
# not converted: 135 g
# not converted: 575 g
# Multiplier: 3 factor: 72 unit: g
# Converted quant: 216 g
# Multiplier: 3 factor: 250 unit: g
# Converted quant: 750 g
# not converted: 200 g
# not converted: 400 g
# not converted: 150 g
# not converted: 500 g
# Multiplier: 2 factor: 167 unit: g
# Converted quant: 334 g
# not converted: 35 g
# Multiplier: 2 factor: 50 unit: g
# Converted quant: 100 g
# not converted: 500 g
# not converted: 1 kg
# not converted: 1 kg
# Multiplier: 4 factor: 30 unit: g
# Converted quant: 120 g
# not converted: 8.9 g
# Multiplier: 3 factor: 140 unit: g
# Converted quant: 420 g
# not converted: 50 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# Multiplier: 2 factor: 315 unit: g
# Converted quant: 630 g
# Multiplier: 6 factor: 76 unit: g
# Converted quant: 456 g
# Multiplier: 3 factor: 120 unit: g
# Converted quant: 360 g
# not converted: 50 g
# not converted: 200 g
# not converted: 500 g
# not converted: 200 g
# not converted: 130 g
# not converted: 900 g
# not converted: 100 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 250 unit: g
# Converted quant: 500 g
# not converted: 1 kg
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 1 kg
# not converted: 150 g
# not converted: 80 g
# Multiplier: 3 factor: 33 unit: g
# Converted quant: 99 g
# not converted: 150 g
# not converted: 75 g
# not converted: 1 Kg
# Multiplier: 2 factor: 285 unit: g
# Converted quant: 570 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# not converted: 25 g
# not converted: 415 g
# not converted: 200 g
# not converted: 200 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 285 g
# not converted: 500 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 38 g
# not converted: 160 g
# Multiplier: 3 factor: 250 unit: g
# Converted quant: 750 g
# not converted: 38 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 90 g
# Multiplier: 3 factor: 135 unit: g
# Converted quant: 405 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 60 g
# not converted: 200 g
# not converted: 400 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# not converted: 970 g
# not converted: 68.5 g
# Multiplier: 3 factor: 250 unit: g
# Converted quant: 750 g
# not converted: 1 kg
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 2 factor: 100 unit: g
# Converted quant: 200 g
# not converted: 360 g
# not converted: 80 g
# not converted: 400 g
# not converted: 25 g
# not converted: 300 g
# not converted: 200 g
# not converted: 240 g
# not converted: 75 g
# not converted: 150 g
# not converted: 1 kg
# not converted: 25 g
# not converted: 400 g
# not converted: 1 L
# Multiplier: 3 factor: 52 unit: g
# Converted quant: 156 g
# not converted: 297.5 g
# not converted: 200 g
# not converted: 1 kg
# not converted: 720 g
# Multiplier: 3 factor: 10 unit: pcs
# Converted quant: 30 pcs
# not converted: 150 g
# not converted: 200 g
# not converted: 500 g
# not converted: 100 g
# not converted: 290 g
# not converted: 170 g
# not converted: 160 g
# Multiplier: 3 factor: 192 unit: g
# Converted quant: 576 g
# not converted: 59 g
# not converted: 330 g
# not converted: 168 g
# not converted: 200 g
# not converted: 250 g
# Multiplier: 2 factor: 78 unit: g
# Converted quant: 156 g
# not converted: 200 g
# not converted: 500 g
# not converted: 180 g
# not converted: 170 ml
# not converted: 150 g
# not converted: 240 g
# Multiplier: 4 factor: 22 unit: g
# Converted quant: 88 g
# not converted: 1.5 kg
# not converted: 135 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 500 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 1 kg
# not converted: 42 g
# not converted: 450 g
# not converted: 58 g
# not converted: 100 g
# Multiplier: 10 factor: 150 unit: g
# Converted quant: 1500 g
# not converted: 450 g
# not converted: 875 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# Multiplier: 2 factor: 20 unit: pcs
# Converted quant: 40 pcs
# Multiplier: 2 factor: 300 unit: g
# Converted quant: 600 g
# not converted: 500 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 500 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 550 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 13 g
# not converted: 750 g
# not converted: 480 g
# not converted: 233 g
# not converted: 100 g
# not converted: 225 g
# Multiplier: 2 factor: 350 unit: g
# Converted quant: 700 g
# Multiplier: 2 factor: 65 unit: g
# Converted quant: 130 g
# not converted: 80 g
# not converted: 1.2 kg
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 50 g
# not converted: 80 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 450 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 420 g
# Multiplier: 4 factor: 60 unit: g
# Converted quant: 240 g
# not converted: 650 g
# not converted: 75 g
# not converted: 100 g
# not converted: 1 kg
# not converted: 268 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# not converted: 350 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# not converted: 110 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 4 factor: 148 unit: g
# Converted quant: 592 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 70 unit: g
# Converted quant: 140 g
# not converted: 200 g
# not converted: 250 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 500 g
# not converted: 200 g
# not converted: 90 g
# not converted: 170 g
# not converted: 75 g
# not converted: 75 g (65+10)
# not converted: 170 g
# not converted: 200 g
# not converted: 307.8 g
# not converted: 27.5 g
# Multiplier: 3 factor: 143 unit: g
# Converted quant: 429 g
# not converted: 100 g
# not converted: 160 g
# not converted: 12 pcs
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 140 g
# not converted: 50 g
# not converted: 200 g
# not converted: 250 g
# not converted: 23 g
# not converted: 180g
# not converted: 55 g
# not converted: 60 g
# not converted: 300 g
# not converted: 550 g
# Multiplier: 2 factor: 245 unit: g
# Converted quant: 490 g
# Multiplier: 4 factor: 22 unit: g
# Converted quant: 88 g
# not converted: 1 kg
# not converted: 180 g
# not converted: 100 g
# not converted: 140 g
# Multiplier: 5 factor: 65 unit: g
# Converted quant: 325 g
# not converted: 110 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 125 g
# not converted: 200 g
# not converted: 100 g
# Multiplier: 3 factor: 152 unit: g
# Converted quant: 456 g
# Multiplier: 2 factor: 130 unit: g
# Converted quant: 260 g
# not converted: 250 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 250 g
# not converted: 500 g
# not converted: 150 g
# not converted: 24 g
# not converted: 500 g
# not converted: 35 g
# not converted: 200 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 150 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# not converted: 400 g
# not converted: 100 g
# not converted: 450 g
# not converted: 500 g
# Multiplier: 2 factor: 250 unit: g
# Converted quant: 500 g
# not converted: 294 g
# not converted: 630 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# not converted: 100 g
# not converted: 300 g
# not converted: 100 g
# not converted: 300 g
# Multiplier: 4 factor: 200 unit: g
# Converted quant: 800 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 66 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 6 factor: 100 unit: g
# Converted quant: 600 g
# not converted: 400 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 400 g
# not converted: 350 g
# Multiplier: 10 factor: 15 unit: g
# Converted quant: 150 g
# not converted: 300 g
# not converted: 300 g
# not converted: 100 g
# not converted: 25 g
# not converted: 850 g
# not converted: 8.8 g
# not converted: 200 g
# not converted: 250 g
# Multiplier: 2 factor: 75 unit: g
# Converted quant: 150 g
# not converted: 35 g
# not converted: 12 g
# not converted: 100 g
# not converted: 300 g
# not converted: 500 g
# Multiplier: 2 factor: 50 unit: g
# Converted quant: 100 g
# not converted: 200 g
# not converted: 135 g
# not converted: 200g
# Multiplier: 4 factor: 60 unit: g
# Converted quant: 240 g
# not converted: 46 g
# not converted: 150 g
# not converted: 100 g
# Multiplier: 2 factor: 212 unit: g
# Converted quant: 424 g
# Multiplier: 3 factor: 210 unit: g
# Converted quant: 630 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 200 g
# not converted: 200 g
# not converted: 1 kg
# not converted: 300 g
# not converted: 200 g
# not converted: 500 g
# Multiplier: 3 factor: 300 unit: g
# Converted quant: 900 g
# not converted: 1.27 kg
# not converted: 510 g
# not converted: 100 g
# Multiplier: 12 factor: 60 unit: g
# Converted quant: 720 g
# not converted: 500 g
# not converted: 500 g
# not converted: 300 g
# not converted: 1 Kg
# Multiplier: 3 factor: 41 unit: g
# Converted quant: 123 g
# not converted: 450 g
# not converted: 100 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# not converted: 500 g
# not converted: 2 Kg
# Multiplier: 2 factor: 24 unit: pcs
# Converted quant: 48 pcs
# Multiplier: 2 factor: 160 unit: g
# Converted quant: 320 g
# not converted: 500 g
# Multiplier: 2 factor: 130 unit: g
# Converted quant: 260 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 200 g
# Multiplier: 12 factor: 351 unit: g
# Converted quant: 4212 g
# Multiplier: 2 factor: 425 unit: g
# Converted quant: 850 g
# not converted: 27.5 g
# not converted: 420 g
# not converted: 200 g
# not converted: 50 g
# not converted: 5*4.5 g
# not converted: 100 g
# not converted: 300 g
# not converted: 250 g
# not converted: 200 g
# not converted: 280 g
# not converted: 248 g
# not converted: 60 g
# not converted: 70 g
# not converted: 20 pcs
# not converted: 350 g
# not converted: 500 g
# not converted: 500 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 42 g
# Multiplier: 2 factor: 107 unit: g
# Converted quant: 214 g
# not converted: 500 g
# not converted: 200 g
# not converted: 2 *71.5 g
# Multiplier: 2 factor: 24 unit: pcs
# Converted quant: 48 pcs
# not converted: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 1 kg
# not converted: 23 g
# not converted: 150 g
# Multiplier: 10 factor: 15 unit: g
# Converted quant: 150 g
# Multiplier: 4 factor: 44 unit: g
# Converted quant: 176 g
# not converted: 80 g
# not converted: 200 g
# not converted: 80 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# not converted: 250 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 100 unit: g
# Converted quant: 200 g
# not converted: 924 g
# not converted: 100 g
# not converted: 75 g
# not converted: 100 g
# Multiplier: 2 factor: 342 unit: g
# Converted quant: 684 g
# not converted: 200 g
# not converted: 228 gm
# Multiplier: 2 factor: 750 unit: g
# Converted quant: 1500 g
# not converted: 151.2 g
# not converted: 180 g
# not converted: 500 ml
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 400 g
# not converted: 300 g
# not converted: 38 g
# not converted: 200 g
# not converted: 450 g
# not converted: 3*153.85 g
# not converted: 800 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 40 unit: g
# Converted quant: 80 g
# Multiplier: 2 factor: 190 unit: g
# Converted quant: 380 g
# Multiplier: 3 factor: 116 unit: g
# Converted quant: 348 g
# not converted: 250 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# Multiplier: 2 factor: 450 unit: g
# Converted quant: 900 g
# not converted: 1 kg
# not converted: 200 g
# not converted: 288 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 90 g
# Multiplier: 3 factor: 30 unit: g
# Converted quant: 90 g
# not converted: 920 g
# Multiplier: 2 factor: 65 unit: g
# Converted quant: 130 g
# not converted: 300 g
# not converted: 250 g
# not converted: 450 g
# not converted: 400 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# not converted: 250 g
# not converted: 500 g
# not converted: 3*36.4 g
# not converted: 1.250 kg
# not converted: 150 g
# Multiplier: 6 factor: 52 unit: g
# Converted quant: 312 g
# not converted: 90 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# not converted: 25 g
# not converted: 700 g
# not converted: 180 g
# not converted: 400 g
# not converted: 185 g
# not converted: 70 g
# not converted: 520 g
# Multiplier: 2 factor: 143 unit: g
# Converted quant: 286 g
# not converted: 60 g
# not converted: 500 g
# not converted: 340 g
# not converted: 355 ml
# Multiplier: 2 factor: 107 unit: g
# Converted quant: 214 g
# Multiplier: 10 factor: 15 unit: g
# Converted quant: 150 g
# not converted: 75 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 50 g
# not converted: 400 g
# not converted: 500 g
# not converted: 400 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 250 g
# not converted: 250 g
# not converted: 100 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 200 g
# not converted: 250 g
# Multiplier: 2 factor: 120 unit: g
# Converted quant: 240 g
# Multiplier: 2 factor: 75 unit: g
# Converted quant: 150 g
# not converted: 300 g
# not converted: 180 g
# not converted: 60 g
# not converted: 250 g
# not converted: 180 g
# not converted: 200 g
# not converted: 200 g
# not converted: 400 g
# not converted: 300 g
# not converted: 450 g
# not converted: 300 g
# not converted: 200 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# Multiplier: 3 factor: 77 unit: g
# Converted quant: 231 g
# not converted: 90 g
# not converted: 720 ml
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 22 g
# not converted: 200 g
# not converted: 200 g
# not converted: 300 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# not converted: 250 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 100 g
# not converted: 100 g
# not converted: 140 g
# not converted: 500 g
# Multiplier: 10 factor: 40 unit: g
# Converted quant: 400 g
# not converted: 100 g
# not converted: 60 g
# not converted: 500 g
# Multiplier: 2 factor: 709 unit: ml
# Converted quant: 1418 ml
# not converted: 660 g
# Multiplier: 2 factor: 60 unit: g
# Converted quant: 120 g
# not converted: 180 g
# not converted: 500 g
# not converted: 375 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 1.2 kg
# not converted: 400 g
# Multiplier: 4 factor: 75 unit: g
# Converted quant: 300 g
# not converted: 180 g
# not converted: 300 g
# not converted: 250 g
# not converted: 200 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 1 kg
# Multiplier: 3 factor: 120 unit: g
# Converted quant: 360 g
# not converted: 75 g
# not converted: 61 g
# not converted: 3*57.6 g
# not converted: 172.2 g
# not converted: 350 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 125 g
# Multiplier: 5 factor: 90 unit: g
# Converted quant: 450 g
# not converted: 525 g
# not converted: 125 g
# not converted: 75 g
# not converted: 140 g
# not converted: 40 g
# not converted: 600 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# not converted: 55 g
#      strip_qua Quantity_upd
# 0       175 g        175 g
# 1       840 g        840 g
# 2       450 g        450 g
# 3       950 g        950 g
# 4    12*130 g        1560 g
# ..         ...          ...
# 896     140 g        140 g
# 897      40 g         40 g
# 898     600 g        600 g
# 899    6*30 g         180 g
# 900      55 g         55 g
#
# [901 rows x 2 columns]

# %%
BB_Snacknbranded_clean['Quantity_upd']
# Out:
# 0      175 g
# 1      840 g
# 2      450 g
# 3      950 g
# 4      1560 g
#         ...
# 896    140 g
# 897     40 g
# 898    600 g
# 899     180 g
# 900     55 g
# Name: Quantity_upd, Length: 901, dtype: object

# %%
import re

def convert_to_grams_ml(quantity_str):
    # Check if '*' is present indicating multiplication
    # Extract numerical value and unit from the input string
    match = re.match(r'(\d+(\.\d+)?)\s*([a-zA-Z]+)', quantity_str)
        
    if match:
        value = float(match.group(1))
        unit = match.group(3).lower()
            # Convert to grams or milliliters
        if unit in ['g', 'gm', 'grams']:
            return value
        elif unit in ['kg', 'kilograms']:
            return value * 1000
        elif unit in ['l', 'ltr', 'liters']:
            return value * 1000  # Assuming 1 liter is approximately 1000 grams (density varies)
        elif unit in ['ml', 'milliliters']:
            return value
        elif unit in ['pc', 'pcs', 'pieces']:
            return value
        else:
            print(f"Warning: Unknown unit '{unit}'. Assuming it is grams.",quantity_str)
            return value
          
BB_Snacknbranded_clean['Converted_Quantity'] = BB_Snacknbranded_clean['Quantity_upd'].apply(convert_to_grams_ml)

# Print the DataFrame with the converted quantities
print(BB_Snacknbranded_clean[['Quantity', 'Quantity_upd', 'Converted_Quantity']])
# Out:
# Warning: Unknown unit 'sheets'. Assuming it is grams. 50 Sheets
#                        Quantity Quantity_upd  Converted_Quantity
# 0    175 g - (Buy 1 Get 1 Free)       175 g                175.0
# 1     840 g - (12 Packs x 70 g)       840 g                840.0
# 2                        450 g        450 g                450.0
# 3                        950 g        950 g                950.0
# 4          12x130 g - Multipack       1560 g              1560.0
# ..                          ...          ...                 ...
# 896                      140 g        140 g                140.0
# 897                       40 g         40 g                 40.0
# 898               600 g - Pouch       600 g                600.0
# 899          6X30 g - Multipack        180 g               180.0
# 900                       55 g         55 g                 55.0
#
# [901 rows x 3 columns]

# %%
BB_Snacknbranded_clean["Price_per_unit(gm/ml/pc)"] = BB_Snacknbranded_clean['Discount_Price'] / BB_Snacknbranded_clean['Converted_Quantity']
BB_Snacknbranded_clean["Price_per_unit(gm/ml/pc)"].round(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 BB_Snacknbranded_clean["Price_per_unit(gm/ml/pc)"] = BB_Snacknbranded_clean['Discount_Price'] / BB_Snacknbranded_clean['Converted_Quantity']
#       2 BB_Snacknbranded_clean["Price_per_unit(gm/ml/pc)"].round(2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:126, in OpsMixin.__truediv__(self, other)
#     124 @unpack_zerodim_and_defer("__truediv__")
#     125 def __truediv__(self, other):
# --> 126     return self._arith_method(other, operator.truediv)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6259, in Series._arith_method(self, other, op)
#    6257 def _arith_method(self, other, op):
#    6258     self, other = ops.align_method_SERIES(self, other)
# -> 6259     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:1325, in IndexOpsMixin._arith_method(self, other, op)
#    1322 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1324 with np.errstate(all="ignore"):
# -> 1325     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1327 return self._construct_result(result, name=res_name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:226, in arithmetic_op(left, right, op)
#     222     _bool_arith_check(op, left, right)
#     224     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     225     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 226     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     228 return res_values
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:172, in _na_arithmetic_op(left, right, op, is_cmp)
#     166 except TypeError:
#     167     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     168         # For object dtype, fallback to a masked operation (only operating
#     169         #  on the non-missing values)
#     170         # Don't do this for comparisons, as that will handle complex numbers
#     171         #  incorrectly, see GH#32047
# --> 172         result = _masked_arith_op(left, right, op)
#     173     else:
#     174         raise
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:110, in _masked_arith_op(x, y, op)
#     108     # See GH#5284, GH#5035, GH#19448 for historical reference
#     109     if mask.any():
# --> 110         result[mask] = op(xrav[mask], yrav[mask])
#     112 else:
#     113     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
BB_Snacknbranded_clean
# Out:
#      Sr.No.                                       Grocery_Name    Brand_Name  \
# 0         0                            Gulab Jamun Dessert Mix  Tata Sampann
# 1         1                       2-Min Masala Instant Noodles        MAGGI
# 2         2  Chocolate Muesli - With 57% Multigrain, Fruit,...      Kelloggs
# 3         3  Marie Gold Biscuit - Crunchy, Light, Zero Tran...     Britannia
# 4         4                           Gluco Biscuits - Parle-G         Parle
# ..      ...                                                ...           ...
# 896     896                   Roasted Peanuts - Lemon & Chilli       JABSONS
# 897     897  Oats - Dark Chocolate, Healthy, High In Fibre,...      Yoga Bar
# 898     898  Oats -Whole Grain, Breakfast Cereal, Rich In F...        Quaker
# 899     899                      Snack Bar - Multigrain, Choco        UNIBIC
# 900     900                   Playz Puffs Masala Munch Namkeen       Kurkure
#
#     MRP_Price Discount_Price  Total Disc  Percetage Disc  \
# 0        ₹145         ₹133.4        11.6            8.00
# 1        ₹168           ₹160         8.0            4.76
# 2        ₹360           ₹310        50.0           13.89
# 3        ₹140           ₹120        20.0           14.29
# 4        ₹120           ₹108        12.0           10.00
# ..        ...            ...         ...             ...
# 896       ₹70            ₹70         0.0            0.00
# 897       ₹25            ₹15        10.0           40.00
# 898      ₹119           ₹119         0.0            0.00
# 899      ₹240           ₹180        60.0           25.00
# 900       ₹20            ₹18         2.0           10.00
#
#                        Quantity  strip_qua Quantity_upd  Converted_Quantity
# 0    175 g - (Buy 1 Get 1 Free)     175 g        175 g                175.0
# 1     840 g - (12 Packs x 70 g)     840 g        840 g                840.0
# 2                        450 g      450 g        450 g                450.0
# 3                        950 g      950 g        950 g                950.0
# 4          12x130 g - Multipack  12*130 g        1560 g              1560.0
# ..                          ...        ...          ...                 ...
# 896                      140 g      140 g        140 g                140.0
# 897                       40 g       40 g         40 g                 40.0
# 898               600 g - Pouch     600 g        600 g                600.0
# 899          6X30 g - Multipack    6*30 g         180 g               180.0
# 900                       55 g       55 g         55 g                 55.0
#
# [901 rows x 11 columns]

# %%
BB_Snacknbranded_clean.to_csv('C:/Users/pijadhav/OneDrive - BMC Software, Inc/BITS DS/Piyush/BB_foodgrains-oil-masala_22Nov_clean.csv')

# %%
BB_Snacknbranded_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sr.No.              901 non-null    int64
#  1   Grocery_Name        901 non-null    object
#  2   Brand_Name          901 non-null    object
#  3   MRP_Price           901 non-null    object
#  4   Discount_Price      901 non-null    object
#  5   Total Disc          901 non-null    float64
#  6   Percetage Disc      900 non-null    float64
#  7   Quantity            901 non-null    object
#  8   strip_qua           901 non-null    object
#  9   Quantity_upd        901 non-null    object
#  10  Converted_Quantity  881 non-null    float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 77.6+ KB
