# %% [markdown]
# ## This notebook is for EDA on Bigbasket Snack and Branded, this is to be perfomed on each dataset/csv file extracted from website using scrapping.
# ### Import SYS and OS and display system version with current working directory.
# ### On next cell, import the Pandas, Numpy and Matplotlib for various EDA functions.

# %%
import sys
print(sys.version)

import os
print(os.getcwd())
# Out:
# 3.11.3 | packaged by Anaconda, Inc. | (main, Apr 19 2023, 23:46:34) [MSC v.1916 64 bit (AMD64)]
# C:\Users\pijadhav\OneDrive - BMC Software, Inc\BITS DS\Piyush

# %% [markdown]
# ### This is to import all the necessary libraries from python directories in order to run the various commands.

# %%
import pandas as pd
import time
print("pandas imported as pd")
import numpy as np
print("numpy imported as np")
import matplotlib
print("matplotlib imported")
time.ctime()
# Out:
# pandas imported as pd
# numpy imported as np
# matplotlib imported
# 'Sat Dec  9 19:08:42 2023'

# %% [markdown]
# # Data Exploration by printing basic
# ### Reading the .csv file into the local dataset created for reading and viewing or explorative data analysis purpose using pandas
#
# ### BB_Snacknbranded will now contain all the data as it is present in a .csv file saved at particular location.

# %% [markdown]
# ### BB_Snacknbranded will now contain all the data as it is present in a .csv file saved at particular location.
# ### Data Exploration by printing basic info, info command describes the information present at csv on very high level, by using it and reading the output of the same,
# ### we can analyze that dataset have 6 columns (0-5), Column has null or not-null count, Data types.
# ### Quantitative variable is either integer or float.
# ### Qualitative/categorical variable is always of object type.

# %%
# Reading the .csv file.
BB_Snacknbranded=pd.read_csv('C:/Users/pijadhav/OneDrive - BMC Software, Inc/BITS DS/Piyush/BB_Snacknbranded_27Nov.csv')

#info command dispalys the basic information about the dataset. 
BB_Snacknbranded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      901 non-null    int64
#  1   Grocery_Name    901 non-null    object
#  2   Brand_Name      901 non-null    object
#  3   Rating          901 non-null    float64
#  4   Discount_Price  901 non-null    object
#  5   MRP_Price       901 non-null    object
#  6   Quantity        901 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 49.4+ KB

# %% [markdown]
# ### As per above description of columns only Rating has Numeric attribute type, so plotting only for Rating column, currently we have "0" values in Rating which is nothing but a 'NaN'. Rest of the columns like MRP and Discout, we have to convert to Numeric and then plot.

# %%
# %matplotlib inline
import numpy as np

BB_Snacknbranded.hist('Rating')
# Out:
# array([[<Axes: title={'center': 'Rating'}>]], dtype=object)

# %% [markdown]
# ### Column command provides the desciption of the columns i.e.'Unnamed: 0','Grocery_Name','Discount_Price','MRP_Price','Brand_Name', 'Quantity'.
# ### Len of column gives total no of columns, shape gives the rows and columns.

# %%
print("BB_Snacknbranded_Columns:",BB_Snacknbranded.columns)
print('Total columns in Dataset:',len(BB_Snacknbranded.columns))
print('Shape of current dataset:',BB_Snacknbranded.shape)
# Out:
# BB_Snacknbranded_Columns: Index(['Unnamed: 0', 'Grocery_Name', 'Brand_Name', 'Rating', 'Discount_Price',
#        'MRP_Price', 'Quantity'],
#       dtype='object')
# Total columns in Dataset: 7
# Shape of current dataset: (901, 7)

# %% [markdown]
# ### Data Exploration by looking at some records.This prints the head of the CSV dataset, as we have mentioned 5 in brackets it printed top 5 recrods.

# %%
print("Top 5 recs:")
print(BB_Snacknbranded.head(5))
print("Last 5 recs:")
BB_Snacknbranded.tail(5)
# Out:
# Top 5 recs:
#    Unnamed: 0                                       Grocery_Name  \
# 0           0                            Gulab Jamun Dessert Mix
# 1           1                       2-Min Masala Instant Noodles
# 2           2  Chocolate Muesli - With 57% Multigrain, Fruit,...
# 3           3  Marie Gold Biscuit - Crunchy, Light, Zero Tran...
# 4           4                           Gluco Biscuits - Parle-G
#
#      Brand_Name  Rating Discount_Price MRP_Price                    Quantity
# 0  Tata Sampann     3.5         ₹133.4      ₹145  175 g - (Buy 1 Get 1 Free)
# 1         MAGGI     4.1           ₹160      ₹168   840 g - (12 Packs x 70 g)
# 2      Kelloggs     4.0           ₹310      ₹360                       450 g
# 3     Britannia     4.0           ₹120      ₹140                       950 g
# 4         Parle     4.2           ₹108      ₹120        12x130 g - Multipack
# Last 5 recs:
#      Unnamed: 0                                       Grocery_Name Brand_Name  \
# 896         896                   Roasted Peanuts - Lemon & Chilli    JABSONS
# 897         897  Oats - Dark Chocolate, Healthy, High In Fibre,...   Yoga Bar
# 898         898  Oats -Whole Grain, Breakfast Cereal, Rich In F...     Quaker
# 899         899                      Snack Bar - Multigrain, Choco     UNIBIC
# 900         900                   Playz Puffs Masala Munch Namkeen    Kurkure
#
#      Rating Discount_Price MRP_Price            Quantity
# 896     4.0            ₹70       ₹70               140 g
# 897     4.3            ₹15       ₹25                40 g
# 898     4.3           ₹119      ₹119       600 g - Pouch
# 899     4.1           ₹180      ₹240  6X30 g - Multipack
# 900     3.7            ₹18       ₹20                55 g

# %% [markdown]
# ### Using include(all) command for data exploration we can get more insights of the data that has been extracted. This also shows us the total count, unique values per column, most frequntly appeared values, frequency, mean median and quartile values.

# %%
BB_Snacknbranded.describe(include='all')
# Out:
#         Unnamed: 0 Grocery_Name  Brand_Name      Rating Discount_Price  \
# count   901.000000          901         901  901.000000            901
# unique         NaN          871         205         NaN            423
# top            NaN   Vermicelli  Haldiram's         NaN            ₹60
# freq           NaN            4          40         NaN             22
# mean    450.000000          NaN         NaN    4.062486            NaN
# std     260.240594          NaN         NaN    0.412892            NaN
# min       0.000000          NaN         NaN    0.000000            NaN
# 25%     225.000000          NaN         NaN    4.000000            NaN
# 50%     450.000000          NaN         NaN    4.100000            NaN
# 75%     675.000000          NaN         NaN    4.200000            NaN
# max     900.000000          NaN         NaN    5.000000            NaN
#
#        MRP_Price Quantity
# count        901      901
# unique       203      459
# top         ₹120    200 g
# freq          39       35
# mean         NaN      NaN
# std          NaN      NaN
# min          NaN      NaN
# 25%          NaN      NaN
# 50%          NaN      NaN
# 75%          NaN      NaN
# max          NaN      NaN

# %% [markdown]
# #### By looking at those records we came to know that, Sr. No. Column is named as "Unnamed", we need to change that with more meaningful column name.
# #### Discount price and MRP price has rupees symbol included in it, because of which it is showing as type as object which should be changed to float to have various operations to be performed on it.
# #### Quantity has multiple values associated with it, Box, Multipack etc etc. this field can be modified to get the per gram or per liter value of mentioned product.

# %%
# By checking the Discount_Price we get to know that it has rupees sign init. We would have to replace it and also need to change it numeric column.
print('Discount_price before:',BB_Snacknbranded.Discount_Price)
BB_Snacknbranded['Discount_Price'] = BB_Snacknbranded['Discount_Price'].str.replace('₹', '')
BB_Snacknbranded['Discount_Price'] = BB_Snacknbranded.Discount_Price.astype(float)
BB_Snacknbranded.Discount_Price
# Out:
# Discount_price before: 0      ₹133.4
# 1        ₹160
# 2        ₹310
# 3        ₹120
# 4        ₹108
#         ...
# 896       ₹70
# 897       ₹15
# 898      ₹119
# 899      ₹180
# 900       ₹18
# Name: Discount_Price, Length: 901, dtype: object
# 0      133.4
# 1      160.0
# 2      310.0
# 3      120.0
# 4      108.0
#        ...
# 896     70.0
# 897     15.0
# 898    119.0
# 899    180.0
# 900     18.0
# Name: Discount_Price, Length: 901, dtype: float64

# %%
# By checking the MRP_Price we get to know that it has rupees sign embeded init. We would have to replace it and also need to change it numeric column.print(BB_foodnoil.MRP_Price)
print('MRP_price before:',BB_Snacknbranded.MRP_Price)
BB_Snacknbranded['MRP_Price'] = BB_Snacknbranded['MRP_Price'].str.replace('₹', '')
BB_Snacknbranded['MRP_Price'] = BB_Snacknbranded.MRP_Price.astype(float)
BB_Snacknbranded.MRP_Price
# Out:
# MRP_price before: 0      ₹145
# 1      ₹168
# 2      ₹360
# 3      ₹140
# 4      ₹120
#        ...
# 896     ₹70
# 897     ₹25
# 898    ₹119
# 899    ₹240
# 900     ₹20
# Name: MRP_Price, Length: 901, dtype: object
# 0      145.0
# 1      168.0
# 2      360.0
# 3      140.0
# 4      120.0
#        ...
# 896     70.0
# 897     25.0
# 898    119.0
# 899    240.0
# 900     20.0
# Name: MRP_Price, Length: 901, dtype: float64

# %%
# Now if we describe the dataset, it give below information. Which included the Discount and MRP price as numeric.
BB_Snacknbranded.describe(include='all')
print('brand name unique:',BB_Snacknbranded.Brand_Name.unique())
print('total brands in dataset:',len(BB_Snacknbranded.Brand_Name.unique()))

BB_Snacknbranded.replace(0, np.nan, inplace=True)

BB_Snacknbranded
# Out:
# brand name unique: ['Tata Sampann' 'MAGGI' 'Kelloggs' 'Britannia' 'Parle' 'Fresho'
#  'Wild Date' 'Britannia NutriChoice' 'iD Fresho' "Haldiram's" 'Lays'
#  'ADF Soul' 'Cadbury Bournvita' 'Cadbury Oreo' 'Safal' 'Kissan' 'Sunfeast'
#  'Bingo' 'PEPPY' 'Quaker' 'Rasna' 'MTR' 'Anil' 'Paper Boat' 'Nestle'
#  'Cadbury Dairy Milk' 'Dabur' 'Nutella' 'Piknik' 'Cadbury Chocobakes'
#  'Tasties' 'Cadbury Dairy Milk Silk' 'McCain' 'Del Monte'
#  'Cadbury Bournville' 'Townbus' 'ACT II' 'Cadbury Perk' 'Nissin Food'
#  'Beyond Snack' 'Lotte' 'Desi' 'Keya' 'True Elements' 'Kurkure' 'Bambino'
#  'Lal' 'BORGES' 'Godrej Yummiez' 'Asal' 'Cadbury 5 Star' 'Top Ramen'
#  'Chings' 'Amul' 'BB Royal' 'Knorr' 'Lijjat' 'Doritos' 'Malkist'
#  'Farmland' 'Happilo' 'Cheetos' 'UNIBIC' 'Tasties Origins' 'Bisk Farm'
#  'Sowbhagya foods' 'Wai Wai' "McVitie's" 'Sundrop' 'Dukes' 'Dr. Oetker'
#  "Ching's Secret" 'Cadbury Nutties' 'Saffola' "Daadi's" 'Aashirvaad'
#  'Nissin' 'Slurrp Farm' 'MTR FOODS' 'Snickers' 'Milky Mist' 'Weikfield'
#  'HappyChef' 'Sunfeast YiPPee!' '4700BC' 'SDA' 'Ambika' 'Orion' 'Yoga Bar'
#  'Lal sweets Pvt Ltd' 'Britannia Treat' 'Pintola' 'Tata Soulfull' 'Manna'
#  'Hersheys' 'JABSONS' 'Cadbury Celebrations' 'Grocery Farm'
#  'Modern Kitchens' 'GRB' "Mother's Recipe" 'Amul Happy Treats'
#  'Cadbury Fuse' 'Pringles' 'Hellmanns' 'Lindberg' 'Switz' 'MR. MAKHANA'
#  'Too Yumm!' 'A-1 Chips' 'Twix' 'Bragg' 'Cadbury' 'Bagrrys' 'GoodDiet'
#  'Sanketi Adukale' 'VEEBA' 'Batter Box' '24 Mantra Organic' 'Disano'
#  'Pillsbury' 'RiteBite Max Protein' 'Skittles' 'Sanjay' 'Brookside'
#  'Habanero' 'Azad' 'Cadbury Temptations' 'Ramyeon' 'ITC Master Chef'
#  'Fabelle' "Jimmy's" 'Mars' 'Heinz' 'IndiSecrets' 'Betty Crocker'
#  'Parle Platina' 'Atish Papad' 'Open Secret' 'Cadbury Bournvita Biscuits'
#  'Lindt' 'Gits' 'Bikaji' 'Cornitos' 'Karachi Bakery' 'KOPIKO' 'Go Desi'
#  'Kinder Joy' 'Orbit' 'ZANDU' 'NESTLE MUNCH' 'UNROLL' 'Tong Garden'
#  'Doublemint' 'Bombucha' 'SDA PAPPADS' 'iD' 'ALPENLIEBE' 'Atish' 'Indomie'
#  'Kiara Foods' 'Hintz' 'Double Horse' 'Patanjali' 'Dnv'
#  'Britannia Good Day' 'Balaji foods' 'Polo' 'Meatzza' 'Farmveda' 'Priya'
#  'By Nature' 'Food Circle' 'Pravin Mixbox' 'Swastiks' 'Lee Kum Kee'
#  'Sugar Free' 'Prasuma' 'Brown & Polson' 'Center Fresh' 'Ask Foods'
#  'Nourish Organics' 'DR.OETKER' 'Cocon' 'Keventer' 'Goldrops' 'REAL THAI'
#  'Rishta' 'Pulse' 'Wingreens Farms' 'Mentos' 'Zoff' 'Tasty Nibbles'
#  'Cadbury Choclairs' 'Blue Bird' 'Tasty Fresh' 'Milano' 'Protyze'
#  'DIVINE BITE' 'ProV' 'American Garden' 'Chupa Chups' 'Ferrero Rocher'
#  'Bansiwala' 'Farmley']
# total brands in dataset: 205
#      Unnamed: 0                                       Grocery_Name  \
# 0           NaN                            Gulab Jamun Dessert Mix
# 1           1.0                       2-Min Masala Instant Noodles
# 2           2.0  Chocolate Muesli - With 57% Multigrain, Fruit,...
# 3           3.0  Marie Gold Biscuit - Crunchy, Light, Zero Tran...
# 4           4.0                           Gluco Biscuits - Parle-G
# ..          ...                                                ...
# 896       896.0                   Roasted Peanuts - Lemon & Chilli
# 897       897.0  Oats - Dark Chocolate, Healthy, High In Fibre,...
# 898       898.0  Oats -Whole Grain, Breakfast Cereal, Rich In F...
# 899       899.0                      Snack Bar - Multigrain, Choco
# 900       900.0                   Playz Puffs Masala Munch Namkeen
#
#        Brand_Name  Rating  Discount_Price  MRP_Price  \
# 0    Tata Sampann     3.5           133.4      145.0
# 1           MAGGI     4.1           160.0      168.0
# 2        Kelloggs     4.0           310.0      360.0
# 3       Britannia     4.0           120.0      140.0
# 4           Parle     4.2           108.0      120.0
# ..            ...     ...             ...        ...
# 896       JABSONS     4.0            70.0       70.0
# 897      Yoga Bar     4.3            15.0       25.0
# 898        Quaker     4.3           119.0      119.0
# 899        UNIBIC     4.1           180.0      240.0
# 900       Kurkure     3.7            18.0       20.0
#
#                        Quantity
# 0    175 g - (Buy 1 Get 1 Free)
# 1     840 g - (12 Packs x 70 g)
# 2                         450 g
# 3                         950 g
# 4          12x130 g - Multipack
# ..                          ...
# 896                       140 g
# 897                        40 g
# 898               600 g - Pouch
# 899          6X30 g - Multipack
# 900                        55 g
#
# [901 rows x 7 columns]

# %%
#ADD a barcplot fo Rating, Discount and MRP

import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# Barplot - Brand-wise distribution
#plt.figure(figsize=(10, 6))
#sns.countplot(x='Brand_Name', data = BB_foodnoil.Brand_Name)
#plt.title('Brand-wise Distribution')
#plt.xlabel('Brand Name')
##plt.ylabel('Count')
#plt.xticks(rotation=45)
#plt.show()

# Using Scatter Matrix function from pandas to generate multiple pairwise scatter plots
#SelectedColumns=['price', 'carat','table','x']
#pd.plotting.scatter_matrix(DiamondPricesData[SelectedColumns], figsize=(15, 10) , marker='o')

# Saving the plot in the current working directory
#plotObject.savefig('DiamondScatterPlot.png')
#print('The plot has been saved at dir: ',os.getcwd())

# %%
BB_Snacknbranded.hist('MRP_Price')
BB_Snacknbranded.hist('Discount_Price')
BB_Snacknbranded.corr()
# Out:
# C:\Users\pijadhav\AppData\Local\Temp\ipykernel_12204\1625252242.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   BB_Snacknbranded.corr()
#                 Unnamed: 0    Rating  Discount_Price  MRP_Price
# Unnamed: 0        1.000000 -0.131961       -0.020675  -0.020917
# Rating           -0.131961  1.000000        0.081598   0.038419
# Discount_Price   -0.020675  0.081598        1.000000   0.979647
# MRP_Price        -0.020917  0.038419        0.979647   1.000000

# %% [markdown]
# ### Below plot shows the Groceries without "Zero" rating, we have removed zero rating as it might be the case that those products are not rated yet. This will change the allignment of plot compared to the previous plot of rating.

# %%
plt.figure(figsize=(4, 3))
sns.histplot(BB_Snacknbranded['Rating'], bins=10, kde=True, color='skyblue')
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plot

# %% [markdown]
# ### Below is snippet to print all the uniquely present Brand names and the count with which it is present in dataset. i.e Haldiram's and Britannia are the Brand_Name with highest product count with also we have printed rest of the brands and their count as well.

# %%
sizes = BB_Snacknbranded['Brand_Name'].value_counts()
unique_brand_name = BB_Snacknbranded['Brand_Name'].unique()
print('sizes:',sizes)
print(sizes.count)
print('unique_brand_name:',unique_brand_name)
# Out:
# sizes: Haldiram's                    40
# Britannia                     38
# Sunfeast                      37
# MTR                           36
# Kelloggs                      28
#                               ..
# Cadbury Bournvita Biscuits     1
# Atish Papad                    1
# Mars                           1
# Jimmy's                        1
# Farmley                        1
# Name: Brand_Name, Length: 205, dtype: int64
# <bound method Series.count of Haldiram's                    40
# Britannia                     38
# Sunfeast                      37
# MTR                           36
# Kelloggs                      28
#                               ..
# Cadbury Bournvita Biscuits     1
# Atish Papad                    1
# Mars                           1
# Jimmy's                        1
# Farmley                        1
# Name: Brand_Name, Length: 205, dtype: int64>
# unique_brand_name: ['Tata Sampann' 'MAGGI' 'Kelloggs' 'Britannia' 'Parle' 'Fresho'
#  'Wild Date' 'Britannia NutriChoice' 'iD Fresho' "Haldiram's" 'Lays'
#  'ADF Soul' 'Cadbury Bournvita' 'Cadbury Oreo' 'Safal' 'Kissan' 'Sunfeast'
#  'Bingo' 'PEPPY' 'Quaker' 'Rasna' 'MTR' 'Anil' 'Paper Boat' 'Nestle'
#  'Cadbury Dairy Milk' 'Dabur' 'Nutella' 'Piknik' 'Cadbury Chocobakes'
#  'Tasties' 'Cadbury Dairy Milk Silk' 'McCain' 'Del Monte'
#  'Cadbury Bournville' 'Townbus' 'ACT II' 'Cadbury Perk' 'Nissin Food'
#  'Beyond Snack' 'Lotte' 'Desi' 'Keya' 'True Elements' 'Kurkure' 'Bambino'
#  'Lal' 'BORGES' 'Godrej Yummiez' 'Asal' 'Cadbury 5 Star' 'Top Ramen'
#  'Chings' 'Amul' 'BB Royal' 'Knorr' 'Lijjat' 'Doritos' 'Malkist'
#  'Farmland' 'Happilo' 'Cheetos' 'UNIBIC' 'Tasties Origins' 'Bisk Farm'
#  'Sowbhagya foods' 'Wai Wai' "McVitie's" 'Sundrop' 'Dukes' 'Dr. Oetker'
#  "Ching's Secret" 'Cadbury Nutties' 'Saffola' "Daadi's" 'Aashirvaad'
#  'Nissin' 'Slurrp Farm' 'MTR FOODS' 'Snickers' 'Milky Mist' 'Weikfield'
#  'HappyChef' 'Sunfeast YiPPee!' '4700BC' 'SDA' 'Ambika' 'Orion' 'Yoga Bar'
#  'Lal sweets Pvt Ltd' 'Britannia Treat' 'Pintola' 'Tata Soulfull' 'Manna'
#  'Hersheys' 'JABSONS' 'Cadbury Celebrations' 'Grocery Farm'
#  'Modern Kitchens' 'GRB' "Mother's Recipe" 'Amul Happy Treats'
#  'Cadbury Fuse' 'Pringles' 'Hellmanns' 'Lindberg' 'Switz' 'MR. MAKHANA'
#  'Too Yumm!' 'A-1 Chips' 'Twix' 'Bragg' 'Cadbury' 'Bagrrys' 'GoodDiet'
#  'Sanketi Adukale' 'VEEBA' 'Batter Box' '24 Mantra Organic' 'Disano'
#  'Pillsbury' 'RiteBite Max Protein' 'Skittles' 'Sanjay' 'Brookside'
#  'Habanero' 'Azad' 'Cadbury Temptations' 'Ramyeon' 'ITC Master Chef'
#  'Fabelle' "Jimmy's" 'Mars' 'Heinz' 'IndiSecrets' 'Betty Crocker'
#  'Parle Platina' 'Atish Papad' 'Open Secret' 'Cadbury Bournvita Biscuits'
#  'Lindt' 'Gits' 'Bikaji' 'Cornitos' 'Karachi Bakery' 'KOPIKO' 'Go Desi'
#  'Kinder Joy' 'Orbit' 'ZANDU' 'NESTLE MUNCH' 'UNROLL' 'Tong Garden'
#  'Doublemint' 'Bombucha' 'SDA PAPPADS' 'iD' 'ALPENLIEBE' 'Atish' 'Indomie'
#  'Kiara Foods' 'Hintz' 'Double Horse' 'Patanjali' 'Dnv'
#  'Britannia Good Day' 'Balaji foods' 'Polo' 'Meatzza' 'Farmveda' 'Priya'
#  'By Nature' 'Food Circle' 'Pravin Mixbox' 'Swastiks' 'Lee Kum Kee'
#  'Sugar Free' 'Prasuma' 'Brown & Polson' 'Center Fresh' 'Ask Foods'
#  'Nourish Organics' 'DR.OETKER' 'Cocon' 'Keventer' 'Goldrops' 'REAL THAI'
#  'Rishta' 'Pulse' 'Wingreens Farms' 'Mentos' 'Zoff' 'Tasty Nibbles'
#  'Cadbury Choclairs' 'Blue Bird' 'Tasty Fresh' 'Milano' 'Protyze'
#  'DIVINE BITE' 'ProV' 'American Garden' 'Chupa Chups' 'Ferrero Rocher'
#  'Bansiwala' 'Farmley']

# %% [markdown]
# ### We have plotted the pie and horizontal bar chart with count of Brand name. for this we have considered Brand_name with less than 10 products as a single group.
#
# ### For drawing a Pie chart we have ignored the brands having less than 10 proudct in Dataset.
# ### For horizontal bar plot we took one more category as "Others" which is addition of all the products of Brand_Names occuring less than 10 times.

# %%
import matplotlib.pyplot as plt

brand_counts = BB_Snacknbranded["Brand_Name"].value_counts()
brand_count_morethan10 = brand_counts[brand_counts > 11]

brand_counts['Other'] = brand_counts[brand_counts <= 10].sum()

brand_count_morethan5 = brand_counts[brand_counts > 10]

# Plotting the pie chart
plt.figure(figsize=(10, 8))
plt.pie(brand_count_morethan10, labels=brand_count_morethan10.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Groceries for Different Brands for more than 10')
plt.show()

plt.figure(figsize=(10, 8))
brand_count_morethan5.plot(kind='barh')
plt.title('Distribution of Brands(count>10) including other(count<=10)')
plt.xlabel('Count')
plt.ylabel('Brand')
plt.show()

# %% [markdown]
# ### For better representation of available data we have added the count infront of each brand.

# %%
plt.figure(figsize=(10, 8))
ax = brand_count_morethan5.plot(kind='barh')

# Add count values on top of each bar
for i, v in enumerate(brand_count_morethan5):
    ax.text(v + 0.5, i, str(v), color='black', fontweight='bold')

plt.title('Distribution of Brands (Counts > 10)')
plt.xlabel('Count')
plt.ylabel('Brand')
plt.show()

# %% [markdown]
# ## Looking at the above bar plot and pie plot, it seems that Brand name Haldiram's and Britannia is having highest count i.e. 40 out of 38 resp, when we performed same analysis on FoodandOil section that time we found out that in the Food and Oil section there are BB_Royal and BB_Popular brands are Big Basket's own products i.e there own brand means they are selling their own brands more than other brands available in market but that is not case

# %% [markdown]
# ### Now we have the discout price and MRP price so we need to calculate the difference between both the price and check if all the products are discounted or only few are discounted ?

# %%
Diff = BB_Snacknbranded.MRP_Price - BB_Snacknbranded.Discount_Price
Diff_per = ((Diff/BB_Snacknbranded.MRP_Price)*100)

print("MRP:",BB_Snacknbranded.MRP_Price,"Dis_price:",BB_Snacknbranded.Discount_Price,"Diff:",Diff,"perc dis:",Diff_per)
# Out:
# MRP: 0      145.0
# 1      168.0
# 2      360.0
# 3      140.0
# 4      120.0
#        ...
# 896     70.0
# 897     25.0
# 898    119.0
# 899    240.0
# 900     20.0
# Name: MRP_Price, Length: 901, dtype: float64 Dis_price: 0      133.4
# 1      160.0
# 2      310.0
# 3      120.0
# 4      108.0
#        ...
# 896     70.0
# 897     15.0
# 898    119.0
# 899    180.0
# 900     18.0
# Name: Discount_Price, Length: 901, dtype: float64 Diff: 0      11.6
# 1       8.0
# 2      50.0
# 3      20.0
# 4      12.0
#        ...
# 896     0.0
# 897    10.0
# 898     0.0
# 899    60.0
# 900     2.0
# Length: 901, dtype: float64 perc dis: 0       8.000000
# 1       4.761905
# 2      13.888889
# 3      14.285714
# 4      10.000000
#          ...
# 896     0.000000
# 897    40.000000
# 898     0.000000
# 899    25.000000
# 900    10.000000
# Length: 901, dtype: float64

# %%
BB_Snacknbranded_clean = []
BB_Snacknbranded_clean = BB_Snacknbranded
BB_Snacknbranded_clean["Total Disc"] = Diff
BB_Snacknbranded_clean["Percetage Disc"] = Diff_per
BB_Snacknbranded_clean.rename(columns= {'Unnamed: 0':'Sr.No.'}, inplace=True)

# %%
BB_Snacknbranded_clean
# Out:
#      Sr.No.                                       Grocery_Name    Brand_Name  \
# 0       NaN                            Gulab Jamun Dessert Mix  Tata Sampann
# 1       1.0                       2-Min Masala Instant Noodles         MAGGI
# 2       2.0  Chocolate Muesli - With 57% Multigrain, Fruit,...      Kelloggs
# 3       3.0  Marie Gold Biscuit - Crunchy, Light, Zero Tran...     Britannia
# 4       4.0                           Gluco Biscuits - Parle-G         Parle
# ..      ...                                                ...           ...
# 896   896.0                   Roasted Peanuts - Lemon & Chilli       JABSONS
# 897   897.0  Oats - Dark Chocolate, Healthy, High In Fibre,...      Yoga Bar
# 898   898.0  Oats -Whole Grain, Breakfast Cereal, Rich In F...        Quaker
# 899   899.0                      Snack Bar - Multigrain, Choco        UNIBIC
# 900   900.0                   Playz Puffs Masala Munch Namkeen       Kurkure
#
#      Rating  Discount_Price  MRP_Price                    Quantity  \
# 0       3.5           133.4      145.0  175 g - (Buy 1 Get 1 Free)
# 1       4.1           160.0      168.0   840 g - (12 Packs x 70 g)
# 2       4.0           310.0      360.0                       450 g
# 3       4.0           120.0      140.0                       950 g
# 4       4.2           108.0      120.0        12x130 g - Multipack
# ..      ...             ...        ...                         ...
# 896     4.0            70.0       70.0                       140 g
# 897     4.3            15.0       25.0                        40 g
# 898     4.3           119.0      119.0               600 g - Pouch
# 899     4.1           180.0      240.0          6X30 g - Multipack
# 900     3.7            18.0       20.0                        55 g
#
#      Total Disc  Percetage Disc
# 0          11.6        8.000000
# 1           8.0        4.761905
# 2          50.0       13.888889
# 3          20.0       14.285714
# 4          12.0       10.000000
# ..          ...             ...
# 896         0.0        0.000000
# 897        10.0       40.000000
# 898         0.0        0.000000
# 899        60.0       25.000000
# 900         2.0       10.000000
#
# [901 rows x 9 columns]

# %%
BB_Snacknbranded_clean['Quantity']
# Out:
# 0      175 g - (Buy 1 Get 1 Free)
# 1       840 g - (12 Packs x 70 g)
# 2                           450 g
# 3                           950 g
# 4            12x130 g - Multipack
#                   ...
# 896                         140 g
# 897                          40 g
# 898                 600 g - Pouch
# 899            6X30 g - Multipack
# 900                          55 g
# Name: Quantity, Length: 901, dtype: object

# %% [markdown]
# ### Below cell explains us the which products are with most rating, least rating and number of products with no rating.

# %%
Rating_col = BB_Snacknbranded_clean.Rating

Maximum_Rating = Rating_col.max()
Minimum_Rating = Rating_col.min()
print('Maximum_Rating:',Maximum_Rating)
print('Minimum_Rating:',Minimum_Rating)

#Rating_col
i=0
for rating in Rating_col:
    if rating == Maximum_Rating:
        print('products with max ratings:',BB_Snacknbranded_clean['Grocery_Name'][i],'Brand Name:',BB_Snacknbranded_clean['Brand_Name'][i])
    elif rating == Minimum_Rating:
        print('products with min ratings:',BB_Snacknbranded_clean['Grocery_Name'][i],'Brand Name:',BB_Snacknbranded_clean['Brand_Name'][i])
    i=i+1

print('Number of No rating records:',BB_Snacknbranded_clean.Rating.isna().sum())

#if BB_foodnoil_clean['Rating'].isna():
#    print("Value with NaN:",BB_foodnoil_clean['Grocery_Name'])
# Out:
# Maximum_Rating: 5.0
# Minimum_Rating: 2.5
# products with max ratings: Pure Bee Honey Brand Name: Hintz
# products with max ratings: Mini Makhana - Salt & Pepper, High In Protein & Calcium, Gluten Free Snack Brand Name: Protyze
# products with min ratings: Premium California Pistachio - Roasted & Salted Brand Name: ProV
# Number of No rating records: 7

# %%
BB_Snacknbranded_clean = BB_Snacknbranded_clean[['Sr.No.','Grocery_Name','Brand_Name','Rating','MRP_Price','Discount_Price','Total Disc','Percetage Disc','Quantity']]
BB_Snacknbranded_clean['Percetage Disc'] = BB_Snacknbranded_clean['Percetage Disc'].round(2)

#BB_foodnoil_clean1.drop(["Srr.No."], axis=1)
BB_Snacknbranded_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sr.No.          900 non-null    float64
#  1   Grocery_Name    901 non-null    object
#  2   Brand_Name      901 non-null    object
#  3   Rating          894 non-null    float64
#  4   MRP_Price       900 non-null    float64
#  5   Discount_Price  900 non-null    float64
#  6   Total Disc      900 non-null    float64
#  7   Percetage Disc  900 non-null    float64
#  8   Quantity        901 non-null    object
# dtypes: float64(6), object(3)
# memory usage: 63.5+ KB

# %% [markdown]
# ## Data cleansing.
#
# ### If you carefully check the Quantity column, it has various data in it sometimes it is useful and sometimes it is not. FIrst we need to get that into proper way to process further to use Qunatity column for our calculation or comparison.
#
# #### Split the Quantity String based upon "-" in between quantity and pack description.
# #### If pack has multiple packs included in it then that needs to identified and seperated.

# %%
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['Quantity'].str.split('-').str[0]

BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace(" x ", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace(" x", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace("x ", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace("x", "*")

BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace(" X ", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace(" X", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace("X ", "*")
BB_Snacknbranded_clean['strip_qua'] = BB_Snacknbranded_clean['strip_qua'].str.replace("X", "*")

print(BB_Snacknbranded_clean['strip_qua'])
# Out:
# 0         175 g
# 1         840 g
# 2          450 g
# 3          950 g
# 4      12*130 g
#          ...
# 896        140 g
# 897         40 g
# 898       600 g
# 899      6*30 g
# 900         55 g
# Name: strip_qua, Length: 901, dtype: object

# %% [markdown]
# ### Below function is to seperate the quantiy and its measured unit. using below function we seperated the quantity and it's units.

# %%
import re

def extract_first_numeric_part(quantity_str):

    match = re.match(r'(\d+)\*(\d+)\s*([a-zA-Z]+)', quantity_str)
    match_f = re.match(r'(\d+)\*(\d+\.\d+)\s*([a-zA-Z]+)', quantity_str)
    
    if match:
        multiplier = int(match.group(1))
        factor = int(match.group(2))
        unit = match.group(3)
        print("Multiplier:",multiplier,"factor:",factor,"unit:",unit)

        basic_unit_value = multiplier * factor
        #return basic_unit_value, unit
        new_quant = str(basic_unit_value)+' '+str(unit)
        print('Converted quant:',new_quant)
        return new_quant
    
    elif match_f:
        multiplier = float(match_f.group(1))
        factor = float(match_f.group(2))
        unit = match_f.group(3)
        print("Multiplier_f:",multiplier,"factor_f:",factor,"unit_f:",unit)

        basic_unit_value = multiplier * factor
        #return basic_unit_value, unit
        new_quant = str(basic_unit_value)+' '+str(unit)
        print('Converted quant_f:',new_quant)
        return new_quant
        
    
    else:
        # If the format doesn't match, return the original value
        new_quant = quantity_str
        print("not converted:", new_quant)
        return new_quant
        

BB_Snacknbranded_clean['Quantity_upd'] = BB_Snacknbranded_clean['strip_qua'].apply(extract_first_numeric_part)

# Print the DataFrame with the extracted first numeric parts
print(BB_Snacknbranded_clean[['strip_qua', 'Quantity_upd']])
# Out:
# not converted: 175 g
# not converted: 840 g
# not converted: 450 g
# not converted: 950 g
# Multiplier: 12 factor: 130 unit: g
# Converted quant: 1560 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 135 g
# Multiplier_f: 12.0 factor_f: 41.7 unit_f: g
# Converted quant_f: 500.40000000000003 g
# Multiplier: 2 factor: 138 unit: g
# Converted quant: 276 g
# not converted: 135 g
# not converted: 2 kg
# not converted: 75 g
# Multiplier: 6 factor: 44 unit: g
# Converted quant: 264 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# not converted: 265 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 2 factor: 750 unit: g
# Converted quant: 1500 g
# Multiplier: 6 factor: 24 unit: g
# Converted quant: 144 g
# Multiplier: 3 factor: 160 unit: g
# Converted quant: 480 g
# Multiplier: 2 factor: 350 unit: g
# Converted quant: 700 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 250 unit: g
# Converted quant: 500 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# not converted: 918.75 g
# not converted: 1 kg
# not converted: 1 kg
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 300 g
# not converted: 120 g
# Multiplier: 6 factor: 60 unit: g
# Converted quant: 360 g
# not converted: 1 kg
# Multiplier: 4 factor: 45 unit: g
# Converted quant: 180 g
# Multiplier: 24 factor: 250 unit: g
# Converted quant: 6000 g
# Multiplier: 12 factor: 21 unit: g
# Converted quant: 252 g
# not converted: 435 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# Multiplier: 2 factor: 300 unit: g
# Converted quant: 600 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# Multiplier: 6 factor: 45 unit: g
# Converted quant: 270 g
# Multiplier: 6 factor: 50 unit: g
# Converted quant: 300 g
# not converted: 400 g
# Multiplier: 12 factor: 15 unit: g
# Converted quant: 180 g
# not converted: 481.25 g
# Multiplier: 3 factor: 300 unit: g
# Converted quant: 900 g
# Multiplier: 6 factor: 58 unit: g
# Converted quant: 348 g
# not converted: 1 kg
# Multiplier: 6 factor: 120 unit: g
# Converted quant: 720 g
# not converted: 700 g
# not converted: 600 g
# not converted: 750 g
# not converted: 450 g
# Multiplier: 3 factor: 96 unit: g
# Converted quant: 288 g
# not converted: 138.6 g
# not converted: 134 g
# not converted: 850 g
# Multiplier: 6 factor: 45 unit: g
# Converted quant: 270 g
# not converted: 700 g
# Multiplier: 2 factor: 240 unit: g
# Converted quant: 480 g
# Multiplier: 3 factor: 200 unit: ml
# Converted quant: 600 ml
# Multiplier: 15 factor: 350 unit: g
# Converted quant: 5250 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# not converted: 10 g
# Multiplier: 6 factor: 143 unit: g
# Converted quant: 858 g
# Multiplier: 2 factor: 273 unit: g
# Converted quant: 546 g
# Multiplier: 2 factor: 60 unit: g
# Converted quant: 120 g
# Multiplier: 3 factor: 119 unit: g
# Converted quant: 357 g
# not converted: 1.1 kg
# not converted: 700 g
# Multiplier: 12 factor: 18 unit: g
# Converted quant: 216 g
# Multiplier: 3 factor: 114 unit: g
# Converted quant: 342 g
# not converted: 500 g
# not converted: 1 kg
# not converted: 584 g
# Multiplier: 6 factor: 21 unit: g
# Converted quant: 126 g
# Multiplier: 2 factor: 117 unit: g
# Converted quant: 234 g
# Multiplier: 2 factor: 650 unit: g
# Converted quant: 1300 g
# not converted: 277.5 g
# not converted: 200 g
# Multiplier: 12 factor: 50 unit: g
# Converted quant: 600 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# Multiplier: 8 factor: 36 unit: g
# Converted quant: 288 g
# not converted: 500 g
# not converted: 277.5 g
# not converted: 1.2 Kg
# Multiplier: 4 factor: 150 unit: g
# Converted quant: 600 g
# Multiplier: 3 factor: 137 unit: g
# Converted quant: 411 g
# not converted: 1.3 kg
# not converted: 1.25 kg
# not converted: 1 kg
# not converted: 900 g
# not converted: 200 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# not converted: 135 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# Multiplier: 12 factor: 69 unit: g
# Converted quant: 828 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 400 g
# Multiplier: 3 factor: 30 unit: g
# Converted quant: 90 g
# Multiplier: 3 factor: 40 unit: g
# Converted quant: 120 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# not converted: 100 g
# Multiplier: 3 factor: 126 unit: g
# Converted quant: 378 g
# not converted: 18 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# not converted: 300 g
# Multiplier_f: 2.0 factor_f: 481.25 unit_f: g
# Converted quant_f: 962.5 g
# Multiplier_f: 3.0 factor_f: 288.75 unit_f: g
# Converted quant_f: 866.25 g
# not converted: 400 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# not converted: 135 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# not converted: 125 g
# Multiplier: 6 factor: 33 unit: g
# Converted quant: 198 g
# not converted: 970 g
# not converted: 25 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 800 g
# Multiplier_f: 5.0 factor_f: 85.3 unit_f: g
# Converted quant_f: 426.5 g
# not converted: 10 g
# not converted: 95.5 g
# not converted: 1 kg
# Multiplier: 2 factor: 1 unit: kg
# Converted quant: 2 kg
# not converted: 75 g
# not converted: 850 g
# Multiplier_f: 5.0 factor_f: 51.1 unit_f: g
# Converted quant_f: 255.5 g
# Multiplier: 4 factor: 100 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 1 unit: Kg
# Converted quant: 2 Kg
# not converted: 200 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 1 kg
# Multiplier_f: 3.0 factor_f: 71.5 unit_f: g
# Converted quant_f: 214.5 g
# not converted: 95.5 g
# not converted: 2 kg
# not converted: 1 Kg
# Multiplier_f: 3.0 factor_f: 191.9 unit_f: g
# Converted quant_f: 575.7 g
# Multiplier: 8 factor: 70 unit: g
# Converted quant: 560 g
# Multiplier: 5 factor: 150 unit: g
# Converted quant: 750 g
# not converted: 150 g
# Multiplier: 3 factor: 200 unit: g
# Converted quant: 600 g
# Multiplier: 2 factor: 1 unit: kg
# Converted quant: 2 kg
# Multiplier: 6 factor: 69 unit: g
# Converted quant: 414 g
# Multiplier: 2 factor: 90 unit: g
# Converted quant: 180 g
# not converted: 400 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 135 g
# Multiplier: 10 factor: 10 unit: g
# Converted quant: 100 g
# not converted: 1 kg
# Multiplier_f: 2.0 factor_f: 82.5 unit_f: g
# Converted quant_f: 165.0 g
# Multiplier: 2 factor: 85 unit: g
# Converted quant: 170 g
# not converted: 75 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 57 g
# Multiplier: 2 factor: 1 unit: kg
# Converted quant: 2 kg
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 500 g
# Multiplier: 6 factor: 58 unit: g
# Converted quant: 348 g
# Multiplier: 3 factor: 250 unit: g
# Converted quant: 750 g
# not converted: 720 g
# not converted: 1 kg
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# Multiplier: 5 factor: 28 unit: g
# Converted quant: 140 g
# not converted: 150 g
# not converted: 86 g
# not converted: 75 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 65 g
# not converted: 253.3 g
# Multiplier_f: 3.0 factor_f: 113.75 unit_f: g
# Converted quant_f: 341.25 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# Multiplier: 5 factor: 28 unit: g
# Converted quant: 140 g
# Multiplier: 2 factor: 260 unit: g
# Converted quant: 520 g
# not converted: 400 g
# not converted: 41 g
# Multiplier: 2 factor: 56 unit: g
# Converted quant: 112 g
# not converted: 840 g
# not converted: 200 g
# not converted: 35 g
# not converted: 924 g
# not converted: 60 g
# not converted: 135 g
# not converted: 33.4 g
# not converted: 300 g
# not converted: 500 g
# Multiplier: 2 factor: 250 unit: g
# Converted quant: 500 g
# not converted: 1 Kg
# Multiplier: 3 factor: 200 unit: g
# Converted quant: 600 g
# Multiplier: 8 factor: 30 unit: g
# Converted quant: 240 g
# Multiplier: 10 factor: 12 unit: g
# Converted quant: 120 g
# not converted: 1 kg
# not converted: 1.25 kg
# not converted: 150 g
# not converted: 500 g
# not converted: 400 g
# Multiplier: 10 factor: 11 unit: g
# Converted quant: 110 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 100 unit: g
# Converted quant: 200 g
# not converted: 1 Kg
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 12.5 g
# not converted: 850 g
# not converted: 248 g
# Multiplier: 6 factor: 55 unit: g
# Converted quant: 330 g
# not converted: 80 g
# Multiplier: 3 factor: 52 unit: g
# Converted quant: 156 g
# Multiplier: 3 factor: 153 unit: g
# Converted quant: 459 g
# not converted: 1 kg
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# Multiplier: 3 factor: 190 unit: g
# Converted quant: 570 g
# Multiplier: 3 factor: 1 unit: kg
# Converted quant: 3 kg
# Multiplier: 3 factor: 186 unit: g
# Converted quant: 558 g
# not converted: 500 g
# not converted: 350 g
# Multiplier: 12 factor: 64 unit: g
# Converted quant: 768 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 1.15 Kg
# not converted: 850 g
# not converted: 12 g
# not converted: 500 g
# Multiplier: 6 factor: 65 unit: g
# Converted quant: 390 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# Multiplier: 3 factor: 35 unit: g
# Converted quant: 105 g
# Multiplier: 3 factor: 40 unit: g
# Converted quant: 120 g
# not converted: 9.5 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# Multiplier: 8 factor: 36 unit: g
# Converted quant: 288 g
# not converted: 200 g
# not converted: 180 g
# not converted: 396 g
# not converted: 38 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# Multiplier: 6 factor: 80 unit: g
# Converted quant: 480 g
# Multiplier: 288 factor: 45 unit: g
# Converted quant: 12960 g
# not converted: 391 g
# not converted: 200 g
# not converted: 60 g
# Multiplier: 6 factor: 55 unit: g
# Converted quant: 330 g
# Multiplier: 3 factor: 175 unit: g
# Converted quant: 525 g
# not converted: 200 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 100 g
# not converted: 800 g
# not converted: 200 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 38 g
# not converted: 280 g
# Multiplier: 2 factor: 600 unit: g
# Converted quant: 1200 g
# Multiplier: 3 factor: 45 unit: g
# Converted quant: 135 g
# not converted: 200 g
# Multiplier: 6 factor: 99 unit: g
# Converted quant: 594 g
# not converted: 200 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 200 g
# not converted: 100 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 336 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 1 kg
# not converted: 40 g
# not converted: 38 g
# not converted: 1 kg
# Multiplier: 2 factor: 35 unit: g
# Converted quant: 70 g
# not converted: 200 g
# Multiplier: 2 factor: 55 unit: g
# Converted quant: 110 g
# not converted: 400 g
# not converted: 1 kg
# not converted: 800 g
# not converted: 60 g
# not converted: 700 g
# not converted: 200 g
# Multiplier: 6 factor: 58 unit: gm
# Converted quant: 348 gm
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 3 factor: 200 unit: g
# Converted quant: 600 g
# not converted: 36 g
# not converted: 120 g
# not converted: 500 g
# Multiplier: 3 factor: 56 unit: g
# Converted quant: 168 g
# not converted: 30 g
# not converted: 200 g
# not converted: 750 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# Multiplier: 2 factor: 350 unit: g
# Converted quant: 700 g
# not converted: 500 g
# not converted: 160 g
# not converted: 59.8 g
# not converted: 400 g
# not converted: 150 g
# not converted: 200 g
# not converted: 50 g
# not converted: 34 g
# Multiplier: 3 factor: 200 unit: g
# Converted quant: 600 g
# not converted: 284 g
# not converted: 460 g
# not converted: 150 g
# not converted: 1 kg
# not converted: 180 g
# Multiplier: 5 factor: 96 unit: g
# Converted quant: 480 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 60 unit: g
# Converted quant: 120 g
# Multiplier: 2 factor: 900 unit: g
# Converted quant: 1800 g
# not converted: 900 g
# not converted: 200 g
# not converted: 500 g
# Multiplier: 12 factor: 500 unit: g
# Converted quant: 6000 g
# Multiplier: 6 factor: 59 unit: g
# Converted quant: 354 g
# not converted: 500 g
# Multiplier: 2 factor: 425 unit: g
# Converted quant: 850 g
# Multiplier: 8 factor: 45 unit: g
# Converted quant: 360 g
# not converted: 42 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 107 unit: g
# Converted quant: 214 g
# not converted: 250 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# not converted: 80 g
# not converted: 30 g
# not converted: 200 g
# not converted: 200 g
# not converted: 45 g
# not converted: 60 g
# Multiplier: 2 factor: 25 unit: Sheets
# Converted quant: 50 Sheets
# not converted: 150 g
# not converted: 200 g
# not converted: 400 g
# not converted: 300 g
# Multiplier: 3 factor: 192 unit: g
# Converted quant: 576 g
# not converted: 75 g
# not converted: 150 g
# not converted: 139 g
# not converted: 450 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 27.5 g
# not converted: 178.8 g
# Multiplier: 3 factor: 90 unit: g
# Converted quant: 270 g
# not converted: 300 g
# Multiplier: 3 factor: 45 unit: g
# Converted quant: 135 g
# not converted: 180 g
# not converted: 1 kg
# not converted: 300 g
# not converted: 177 g
# Multiplier: 3 factor: 50 unit: g
# Converted quant: 150 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 946 unit: ml
# Converted quant: 1892 ml
# not converted: 180 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 750 g
# not converted: 242 g
# Multiplier: 2 factor: 107 unit: g
# Converted quant: 214 g
# not converted: 60 g
# not converted: 100 g
# not converted: 58 g
# not converted: 500 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 500 g
# not converted: 900 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 75 g
# not converted: 850 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# not converted: 400 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# Multiplier_f: 3.0 factor_f: 142.8 unit_f: g
# Converted quant_f: 428.40000000000003 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 250 g
# not converted: 935 g
# not converted: 450 g
# not converted: 200 g
# not converted: 900 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# Multiplier: 2 factor: 375 unit: g
# Converted quant: 750 g
# Multiplier: 6 factor: 120 unit: g
# Converted quant: 720 g
# not converted: 1 Kg
# not converted: 420 g
# not converted: 200 g
# not converted: 500 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# Multiplier: 3 factor: 130 unit: g
# Converted quant: 390 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 1 kg
# not converted: 125 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# not converted: 270 g
# not converted: 250 g
# not converted: 200 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 185 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 150 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 27.5 g
# not converted: 170 g
# not converted: 80 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# not converted: 500 g
# not converted: 50 g
# not converted: 100 g
# not converted: 9 g
# Multiplier: 4 factor: 60 unit: g
# Converted quant: 240 g
# Multiplier: 2 factor: 350 unit: g
# Converted quant: 700 g
# not converted: 850 g
# not converted: 68.5 g
# not converted: 250 g
# not converted: 200 g
# Multiplier: 2 factor: 100 unit: g
# Converted quant: 200 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 3 factor: 330 unit: g
# Converted quant: 990 g
# not converted: 200 g
# not converted: 135 g
# not converted: 575 g
# Multiplier: 3 factor: 72 unit: g
# Converted quant: 216 g
# Multiplier: 3 factor: 250 unit: g
# Converted quant: 750 g
# not converted: 200 g
# not converted: 400 g
# not converted: 150 g
# not converted: 500 g
# Multiplier: 2 factor: 167 unit: g
# Converted quant: 334 g
# not converted: 35 g
# Multiplier: 2 factor: 50 unit: g
# Converted quant: 100 g
# not converted: 500 g
# not converted: 1 kg
# not converted: 1 kg
# Multiplier: 4 factor: 30 unit: g
# Converted quant: 120 g
# not converted: 8.9 g
# Multiplier: 3 factor: 140 unit: g
# Converted quant: 420 g
# not converted: 50 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# Multiplier: 2 factor: 315 unit: g
# Converted quant: 630 g
# Multiplier: 6 factor: 76 unit: g
# Converted quant: 456 g
# Multiplier: 3 factor: 120 unit: g
# Converted quant: 360 g
# not converted: 50 g
# not converted: 200 g
# not converted: 500 g
# not converted: 200 g
# not converted: 130 g
# not converted: 900 g
# not converted: 100 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 250 unit: g
# Converted quant: 500 g
# not converted: 1 kg
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 1 kg
# not converted: 150 g
# not converted: 80 g
# Multiplier: 3 factor: 33 unit: g
# Converted quant: 99 g
# not converted: 150 g
# not converted: 75 g
# not converted: 1 Kg
# Multiplier: 2 factor: 285 unit: g
# Converted quant: 570 g
# Multiplier: 3 factor: 60 unit: g
# Converted quant: 180 g
# not converted: 25 g
# not converted: 415 g
# not converted: 200 g
# not converted: 200 g
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 285 g
# not converted: 500 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 38 g
# not converted: 160 g
# Multiplier: 3 factor: 250 unit: g
# Converted quant: 750 g
# not converted: 38 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 90 g
# Multiplier: 3 factor: 135 unit: g
# Converted quant: 405 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 60 g
# not converted: 200 g
# not converted: 400 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# not converted: 970 g
# not converted: 68.5 g
# Multiplier: 3 factor: 250 unit: g
# Converted quant: 750 g
# not converted: 1 kg
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 2 factor: 100 unit: g
# Converted quant: 200 g
# not converted: 360 g
# not converted: 80 g
# not converted: 400 g
# not converted: 25 g
# not converted: 300 g
# not converted: 200 g
# not converted: 240 g
# not converted: 75 g
# not converted: 150 g
# not converted: 1 kg
# not converted: 25 g
# not converted: 400 g
# not converted: 1 L
# Multiplier: 3 factor: 52 unit: g
# Converted quant: 156 g
# not converted: 297.5 g
# not converted: 200 g
# not converted: 1 kg
# not converted: 720 g
# Multiplier: 3 factor: 10 unit: pcs
# Converted quant: 30 pcs
# not converted: 150 g
# not converted: 200 g
# not converted: 500 g
# not converted: 100 g
# not converted: 290 g
# not converted: 170 g
# not converted: 160 g
# Multiplier: 3 factor: 192 unit: g
# Converted quant: 576 g
# not converted: 59 g
# not converted: 330 g
# not converted: 168 g
# not converted: 200 g
# not converted: 250 g
# Multiplier: 2 factor: 78 unit: g
# Converted quant: 156 g
# not converted: 200 g
# not converted: 500 g
# not converted: 180 g
# not converted: 170 ml
# not converted: 150 g
# not converted: 240 g
# Multiplier: 4 factor: 22 unit: g
# Converted quant: 88 g
# not converted: 1.5 kg
# not converted: 135 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 500 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 1 kg
# not converted: 42 g
# not converted: 450 g
# not converted: 58 g
# not converted: 100 g
# Multiplier: 10 factor: 150 unit: g
# Converted quant: 1500 g
# not converted: 450 g
# not converted: 875 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# Multiplier: 2 factor: 20 unit: pcs
# Converted quant: 40 pcs
# Multiplier: 2 factor: 300 unit: g
# Converted quant: 600 g
# not converted: 500 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 500 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 550 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 13 g
# not converted: 750 g
# not converted: 480 g
# not converted: 233 g
# not converted: 100 g
# not converted: 225 g
# Multiplier: 2 factor: 350 unit: g
# Converted quant: 700 g
# Multiplier: 2 factor: 65 unit: g
# Converted quant: 130 g
# not converted: 80 g
# not converted: 1.2 kg
# Multiplier: 6 factor: 150 unit: g
# Converted quant: 900 g
# not converted: 50 g
# not converted: 80 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 450 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 420 g
# Multiplier: 4 factor: 60 unit: g
# Converted quant: 240 g
# not converted: 650 g
# not converted: 75 g
# not converted: 100 g
# not converted: 1 kg
# not converted: 268 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# not converted: 350 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# not converted: 110 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# Multiplier: 4 factor: 148 unit: g
# Converted quant: 592 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 70 unit: g
# Converted quant: 140 g
# not converted: 200 g
# not converted: 250 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 500 g
# not converted: 200 g
# not converted: 90 g
# not converted: 170 g
# not converted: 75 g
# not converted: 75 g (65+10)
# not converted: 170 g
# not converted: 200 g
# not converted: 307.8 g
# not converted: 27.5 g
# Multiplier: 3 factor: 143 unit: g
# Converted quant: 429 g
# not converted: 100 g
# not converted: 160 g
# not converted: 12 pcs
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 140 g
# not converted: 50 g
# not converted: 200 g
# not converted: 250 g
# not converted: 23 g
# not converted: 180g
# not converted: 55 g
# not converted: 60 g
# not converted: 300 g
# not converted: 550 g
# Multiplier: 2 factor: 245 unit: g
# Converted quant: 490 g
# Multiplier: 4 factor: 22 unit: g
# Converted quant: 88 g
# not converted: 1 kg
# not converted: 180 g
# not converted: 100 g
# not converted: 140 g
# Multiplier: 5 factor: 65 unit: g
# Converted quant: 325 g
# not converted: 110 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 125 g
# not converted: 200 g
# not converted: 100 g
# Multiplier: 3 factor: 152 unit: g
# Converted quant: 456 g
# Multiplier: 2 factor: 130 unit: g
# Converted quant: 260 g
# not converted: 250 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 250 g
# not converted: 500 g
# not converted: 150 g
# not converted: 24 g
# not converted: 500 g
# not converted: 35 g
# not converted: 200 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 150 g
# Multiplier: 3 factor: 80 unit: g
# Converted quant: 240 g
# not converted: 400 g
# not converted: 100 g
# not converted: 450 g
# not converted: 500 g
# Multiplier: 2 factor: 250 unit: g
# Converted quant: 500 g
# not converted: 294 g
# not converted: 630 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# Multiplier: 3 factor: 100 unit: g
# Converted quant: 300 g
# not converted: 100 g
# not converted: 300 g
# not converted: 100 g
# not converted: 300 g
# Multiplier: 4 factor: 200 unit: g
# Converted quant: 800 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 66 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 6 factor: 100 unit: g
# Converted quant: 600 g
# not converted: 400 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 400 g
# not converted: 350 g
# Multiplier: 10 factor: 15 unit: g
# Converted quant: 150 g
# not converted: 300 g
# not converted: 300 g
# not converted: 100 g
# not converted: 25 g
# not converted: 850 g
# not converted: 8.8 g
# not converted: 200 g
# not converted: 250 g
# Multiplier: 2 factor: 75 unit: g
# Converted quant: 150 g
# not converted: 35 g
# not converted: 12 g
# not converted: 100 g
# not converted: 300 g
# not converted: 500 g
# Multiplier: 2 factor: 50 unit: g
# Converted quant: 100 g
# not converted: 200 g
# not converted: 135 g
# not converted: 200g
# Multiplier: 4 factor: 60 unit: g
# Converted quant: 240 g
# not converted: 46 g
# not converted: 150 g
# not converted: 100 g
# Multiplier: 2 factor: 212 unit: g
# Converted quant: 424 g
# Multiplier: 3 factor: 210 unit: g
# Converted quant: 630 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 200 g
# not converted: 200 g
# not converted: 1 kg
# not converted: 300 g
# not converted: 200 g
# not converted: 500 g
# Multiplier: 3 factor: 300 unit: g
# Converted quant: 900 g
# not converted: 1.27 kg
# not converted: 510 g
# not converted: 100 g
# Multiplier: 12 factor: 60 unit: g
# Converted quant: 720 g
# not converted: 500 g
# not converted: 500 g
# not converted: 300 g
# not converted: 1 Kg
# Multiplier: 3 factor: 41 unit: g
# Converted quant: 123 g
# not converted: 450 g
# not converted: 100 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# not converted: 500 g
# not converted: 2 Kg
# Multiplier: 2 factor: 24 unit: pcs
# Converted quant: 48 pcs
# Multiplier: 2 factor: 160 unit: g
# Converted quant: 320 g
# not converted: 500 g
# Multiplier: 2 factor: 130 unit: g
# Converted quant: 260 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# not converted: 200 g
# Multiplier: 12 factor: 351 unit: g
# Converted quant: 4212 g
# Multiplier: 2 factor: 425 unit: g
# Converted quant: 850 g
# not converted: 27.5 g
# not converted: 420 g
# not converted: 200 g
# not converted: 50 g
# Multiplier_f: 5.0 factor_f: 4.5 unit_f: g
# Converted quant_f: 22.5 g
# not converted: 100 g
# not converted: 300 g
# not converted: 250 g
# not converted: 200 g
# not converted: 280 g
# not converted: 248 g
# not converted: 60 g
# not converted: 70 g
# not converted: 20 pcs
# not converted: 350 g
# not converted: 500 g
# not converted: 500 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# not converted: 42 g
# Multiplier: 2 factor: 107 unit: g
# Converted quant: 214 g
# not converted: 500 g
# not converted: 200 g
# Multiplier_f: 2.0 factor_f: 71.5 unit_f: g
# Converted quant_f: 143.0 g
# Multiplier: 2 factor: 24 unit: pcs
# Converted quant: 48 pcs
# not converted: 450 g
# not converted: 200 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 1 kg
# not converted: 23 g
# not converted: 150 g
# Multiplier: 10 factor: 15 unit: g
# Converted quant: 150 g
# Multiplier: 4 factor: 44 unit: g
# Converted quant: 176 g
# not converted: 80 g
# not converted: 200 g
# not converted: 80 g
# Multiplier: 5 factor: 30 unit: g
# Converted quant: 150 g
# not converted: 250 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# Multiplier: 2 factor: 100 unit: g
# Converted quant: 200 g
# not converted: 924 g
# not converted: 100 g
# not converted: 75 g
# not converted: 100 g
# Multiplier: 2 factor: 342 unit: g
# Converted quant: 684 g
# not converted: 200 g
# not converted: 228 gm
# Multiplier: 2 factor: 750 unit: g
# Converted quant: 1500 g
# not converted: 151.2 g
# not converted: 180 g
# not converted: 500 ml
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 400 g
# not converted: 300 g
# not converted: 38 g
# not converted: 200 g
# not converted: 450 g
# Multiplier_f: 3.0 factor_f: 153.85 unit_f: g
# Converted quant_f: 461.54999999999995 g
# not converted: 800 g
# Multiplier: 2 factor: 200 unit: g
# Converted quant: 400 g
# Multiplier: 2 factor: 40 unit: g
# Converted quant: 80 g
# Multiplier: 2 factor: 190 unit: g
# Converted quant: 380 g
# Multiplier: 3 factor: 116 unit: g
# Converted quant: 348 g
# not converted: 250 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# Multiplier: 2 factor: 450 unit: g
# Converted quant: 900 g
# not converted: 1 kg
# not converted: 200 g
# not converted: 288 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 90 g
# Multiplier: 3 factor: 30 unit: g
# Converted quant: 90 g
# not converted: 920 g
# Multiplier: 2 factor: 65 unit: g
# Converted quant: 130 g
# not converted: 300 g
# not converted: 250 g
# not converted: 450 g
# not converted: 400 g
# Multiplier: 2 factor: 80 unit: g
# Converted quant: 160 g
# not converted: 250 g
# not converted: 500 g
# Multiplier_f: 3.0 factor_f: 36.4 unit_f: g
# Converted quant_f: 109.19999999999999 g
# not converted: 1.250 kg
# not converted: 150 g
# Multiplier: 6 factor: 52 unit: g
# Converted quant: 312 g
# not converted: 90 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# not converted: 25 g
# not converted: 700 g
# not converted: 180 g
# not converted: 400 g
# not converted: 185 g
# not converted: 70 g
# not converted: 520 g
# Multiplier: 2 factor: 143 unit: g
# Converted quant: 286 g
# not converted: 60 g
# not converted: 500 g
# not converted: 340 g
# not converted: 355 ml
# Multiplier: 2 factor: 107 unit: g
# Converted quant: 214 g
# Multiplier: 10 factor: 15 unit: g
# Converted quant: 150 g
# not converted: 75 g
# Multiplier: 3 factor: 75 unit: g
# Converted quant: 225 g
# not converted: 50 g
# not converted: 400 g
# not converted: 500 g
# not converted: 400 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 250 g
# not converted: 250 g
# not converted: 100 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 200 g
# not converted: 250 g
# Multiplier: 2 factor: 120 unit: g
# Converted quant: 240 g
# Multiplier: 2 factor: 75 unit: g
# Converted quant: 150 g
# not converted: 300 g
# not converted: 180 g
# not converted: 60 g
# not converted: 250 g
# not converted: 180 g
# not converted: 200 g
# not converted: 200 g
# not converted: 400 g
# not converted: 300 g
# not converted: 450 g
# not converted: 300 g
# not converted: 200 g
# Multiplier: 8 factor: 20 unit: g
# Converted quant: 160 g
# Multiplier: 3 factor: 77 unit: g
# Converted quant: 231 g
# not converted: 90 g
# not converted: 720 ml
# Multiplier: 2 factor: 150 unit: g
# Converted quant: 300 g
# not converted: 22 g
# not converted: 200 g
# not converted: 200 g
# not converted: 300 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# not converted: 250 g
# Multiplier: 3 factor: 150 unit: g
# Converted quant: 450 g
# not converted: 100 g
# not converted: 100 g
# not converted: 140 g
# not converted: 500 g
# Multiplier: 10 factor: 40 unit: g
# Converted quant: 400 g
# not converted: 100 g
# not converted: 60 g
# not converted: 500 g
# Multiplier: 2 factor: 709 unit: ml
# Converted quant: 1418 ml
# not converted: 660 g
# Multiplier: 2 factor: 60 unit: g
# Converted quant: 120 g
# not converted: 180 g
# not converted: 500 g
# not converted: 375 g
# Multiplier: 2 factor: 400 unit: g
# Converted quant: 800 g
# not converted: 1.2 kg
# not converted: 400 g
# Multiplier: 4 factor: 75 unit: g
# Converted quant: 300 g
# not converted: 180 g
# not converted: 300 g
# not converted: 250 g
# not converted: 200 g
# Multiplier: 2 factor: 500 unit: g
# Converted quant: 1000 g
# Multiplier: 3 factor: 70 unit: g
# Converted quant: 210 g
# not converted: 1 kg
# Multiplier: 3 factor: 120 unit: g
# Converted quant: 360 g
# not converted: 75 g
# not converted: 61 g
# Multiplier_f: 3.0 factor_f: 57.6 unit_f: g
# Converted quant_f: 172.8 g
# not converted: 172.2 g
# not converted: 350 g
# Multiplier: 6 factor: 75 unit: g
# Converted quant: 450 g
# not converted: 125 g
# Multiplier: 5 factor: 90 unit: g
# Converted quant: 450 g
# not converted: 525 g
# not converted: 125 g
# not converted: 75 g
# not converted: 140 g
# not converted: 40 g
# not converted: 600 g
# Multiplier: 6 factor: 30 unit: g
# Converted quant: 180 g
# not converted: 55 g
#      strip_qua Quantity_upd
# 0       175 g        175 g
# 1       840 g        840 g
# 2        450 g        450 g
# 3        950 g        950 g
# 4    12*130 g        1560 g
# ..         ...          ...
# 896      140 g        140 g
# 897       40 g         40 g
# 898     600 g        600 g
# 899    6*30 g         180 g
# 900       55 g         55 g
#
# [901 rows x 2 columns]

# %%
BB_Snacknbranded_clean['Quantity_upd']
# Out:
# 0      175 g
# 1      840 g
# 2       450 g
# 3       950 g
# 4      1560 g
#         ...
# 896     140 g
# 897      40 g
# 898    600 g
# 899     180 g
# 900      55 g
# Name: Quantity_upd, Length: 901, dtype: object

# %% [markdown]
# ### After cleansing the Quantity column i.e. by removing the unwanted and extra data we converted that into the proper quantity format. We used Regrex function for the same.
# ### Converted quantity is pure numeric/float form of the qunatity which is trimmed to remove

# %%
import re

def convert_to_grams_ml(quantity_str):
    # Check if '*' is present indicating multiplication
    # Extract numerical value and unit from the input string
    match = re.match(r'(\d+(\.\d+)?)\s*([a-zA-Z]+)', quantity_str)
        
    if match:
        value = float(match.group(1))
        unit = match.group(3).lower()
            # Convert to grams or milliliters
        if unit in ['g', 'gm', 'grams']:
            return value
        elif unit in ['kg', 'kilograms']:
            return value * 1000
        elif unit in ['l', 'ltr', 'liters']:
            return value * 1000  # Assuming 1 liter is approximately 1000 grams (density varies)
        elif unit in ['ml', 'milliliters']:
            return value
        elif unit in ['pc', 'pcs', 'pieces']:
            return value
        else:
            print(f"Warning: Unknown unit '{unit}'. Assuming it is grams.",quantity_str)
            return value
          
BB_Snacknbranded_clean['Converted_Quantity'] = BB_Snacknbranded_clean['Quantity_upd'].apply(convert_to_grams_ml)

# Print the DataFrame with the converted quantities
print(BB_Snacknbranded_clean[['Quantity', 'Quantity_upd', 'Converted_Quantity']])
# Out:
# Warning: Unknown unit 'sheets'. Assuming it is grams. 50 Sheets
#                        Quantity Quantity_upd  Converted_Quantity
# 0    175 g - (Buy 1 Get 1 Free)       175 g                175.0
# 1     840 g - (12 Packs x 70 g)       840 g                840.0
# 2                         450 g        450 g               450.0
# 3                         950 g        950 g               950.0
# 4          12x130 g - Multipack       1560 g              1560.0
# ..                          ...          ...                 ...
# 896                       140 g        140 g               140.0
# 897                        40 g         40 g                40.0
# 898               600 g - Pouch       600 g                600.0
# 899          6X30 g - Multipack        180 g               180.0
# 900                        55 g         55 g                55.0
#
# [901 rows x 3 columns]

# %%
import numpy as np
BB_Snacknbranded_clean["Price_per_unit(gm/ml/pc)"] = BB_Snacknbranded_clean['Discount_Price'] / BB_Snacknbranded_clean['Converted_Quantity']
BB_Snacknbranded_clean["Price_per_unit(gm/ml/pc)"].round(2)
# Out:
# 0      0.76
# 1      0.19
# 2      0.69
# 3      0.13
# 4      0.07
#        ...
# 896    0.50
# 897    0.38
# 898    0.20
# 899    1.00
# 900    0.33
# Name: Price_per_unit(gm/ml/pc), Length: 901, dtype: float64

# %% [markdown]
# ### find out the duplicates on the grocery name and Brand name combination. BB_FnO_dup_rows has the csv dataset those are duplicate on the basis of grocery name and Brand name. further we can remove those records from our dataset.

# %%
#find out the duplicate grocery name and Brand name combination. 
BB_FnO_dup_rows_snb = BB_Snacknbranded_clean[BB_Snacknbranded_clean.duplicated(['Grocery_Name', 'Brand_Name'])]
#Print 
print("Duplicate Rows count:", len(BB_FnO_dup_rows_snb) ,"based on Grocery and Brand name\n") #BB_FnO_dup_rows)

BB_FnO_dup_rows_snb.to_csv('C:/Users/pijadhav/OneDrive - BMC Software, Inc/BITS DS/Piyush/BB_FnO_dup_rows_snb_5dec.csv')

BB_Snacknbranded_clean1 = BB_Snacknbranded_clean.drop_duplicates(['Grocery_Name', 'Brand_Name'],keep='first')
# Out:
# Duplicate Rows count: 13 based on Grocery and Brand name

# %%
BB_Snacknbranded_clean2 = BB_Snacknbranded_clean1.drop(["Quantity","strip_qua","Converted_Quantity",], axis=1)
print(BB_Snacknbranded_clean2)
BB_Snacknbranded_clean2.to_csv('C:/Users/pijadhav/OneDrive - BMC Software, Inc/BITS DS/Piyush/BB_Snacknbranded_clean_5dec.csv')
# Out:
#      Sr.No.                                       Grocery_Name    Brand_Name  \
# 0       NaN                            Gulab Jamun Dessert Mix  Tata Sampann
# 1       1.0                       2-Min Masala Instant Noodles         MAGGI
# 2       2.0  Chocolate Muesli - With 57% Multigrain, Fruit,...      Kelloggs
# 3       3.0  Marie Gold Biscuit - Crunchy, Light, Zero Tran...     Britannia
# 4       4.0                           Gluco Biscuits - Parle-G         Parle
# ..      ...                                                ...           ...
# 896   896.0                   Roasted Peanuts - Lemon & Chilli       JABSONS
# 897   897.0  Oats - Dark Chocolate, Healthy, High In Fibre,...      Yoga Bar
# 898   898.0  Oats -Whole Grain, Breakfast Cereal, Rich In F...        Quaker
# 899   899.0                      Snack Bar - Multigrain, Choco        UNIBIC
# 900   900.0                   Playz Puffs Masala Munch Namkeen       Kurkure
#
#      Rating  MRP_Price  Discount_Price  Total Disc  Percetage Disc  \
# 0       3.5      145.0           133.4        11.6            8.00
# 1       4.1      168.0           160.0         8.0            4.76
# 2       4.0      360.0           310.0        50.0           13.89
# 3       4.0      140.0           120.0        20.0           14.29
# 4       4.2      120.0           108.0        12.0           10.00
# ..      ...        ...             ...         ...             ...
# 896     4.0       70.0            70.0         0.0            0.00
# 897     4.3       25.0            15.0        10.0           40.00
# 898     4.3      119.0           119.0         0.0            0.00
# 899     4.1      240.0           180.0        60.0           25.00
# 900     3.7       20.0            18.0         2.0           10.00
#
#     Quantity_upd  Price_per_unit(gm/ml/pc)
# 0         175 g                   0.762286
# 1         840 g                   0.190476
# 2          450 g                  0.688889
# 3          950 g                  0.126316
# 4         1560 g                  0.069231
# ..           ...                       ...
# 896        140 g                  0.500000
# 897         40 g                  0.375000
# 898       600 g                   0.198333
# 899        180 g                  1.000000
# 900         55 g                  0.327273
#
# [888 rows x 10 columns]

# %%
print(BB_Snacknbranded_clean2.info())
BB_Snacknbranded_clean2.describe(include='all')

#BB_foodnoil_clean2 = BB_foodnoil_clean1['Grocery_Name','Brand_Name','Rating','MRP_Price','Discount_Price','Total Disc','Quantity','Converted_Quantity','Price_per_unit(gm/ml/pc)']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 888 entries, 0 to 900
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sr.No.                    887 non-null    float64
#  1   Grocery_Name              888 non-null    object
#  2   Brand_Name                888 non-null    object
#  3   Rating                    881 non-null    float64
#  4   MRP_Price                 887 non-null    float64
#  5   Discount_Price            887 non-null    float64
#  6   Total Disc                887 non-null    float64
#  7   Percetage Disc            887 non-null    float64
#  8   Quantity_upd              888 non-null    object
#  9   Price_per_unit(gm/ml/pc)  887 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 76.3+ KB
# None
#             Sr.No. Grocery_Name Brand_Name      Rating     MRP_Price  \
# count   887.000000          888        888  881.000000    887.000000
# unique         NaN          871        205         NaN           NaN
# top            NaN   Vermicelli  Britannia         NaN           NaN
# freq           NaN            4         38         NaN           NaN
# mean    452.561443          NaN        NaN    4.093644    225.785795
# std     260.311218          NaN        NaN    0.204785    487.105614
# min       1.000000          NaN        NaN    2.500000      5.000000
# 25%     227.500000          NaN        NaN    4.000000     70.000000
# 50%     454.000000          NaN        NaN    4.100000    130.000000
# 75%     678.500000          NaN        NaN    4.200000    270.000000
# max     900.000000          NaN        NaN    5.000000  11520.000000
#
#         Discount_Price   Total Disc  Percetage Disc Quantity_upd  \
# count        887.00000   887.000000      887.000000          888
# unique             NaN          NaN             NaN          281
# top                NaN          NaN             NaN        200 g
# freq               NaN          NaN             NaN           39
# mean         190.24920    35.536595       12.476618          NaN
# std          409.74731   118.927935       14.938624          NaN
# min            5.00000     0.000000        0.000000          NaN
# 25%           63.07500     0.000000        0.000000          NaN
# 50%          114.40000     9.600000        8.000000          NaN
# 75%          210.00000    32.720000       19.000000          NaN
# max         9792.00000  2663.420000       69.090000          NaN
#
#         Price_per_unit(gm/ml/pc)
# count                 887.000000
# unique                       NaN
# top                          NaN
# freq                         NaN
# mean                    0.667704
# std                     1.094143
# min                     0.053475
# 25%                     0.260000
# 50%                     0.407407
# 75%                     0.661000
# max                    15.050167
