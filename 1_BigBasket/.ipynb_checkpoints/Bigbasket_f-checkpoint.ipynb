# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
from csv import DictWriter
import time

Grocery_Name_list = []
Brand_Name_list = []
Discount_Price_list = []
MRP_Price_list = [] 
Quantity_list = []
#Quantity_ML_list = []
#Quantity_KG_list = []

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
 
#url = 'https://www.bigbasket.com/cl/foodgrains-oil-masala'
#r = requests.get(url, headers=headers)#, proxies=proxies)

# Initialize WebDriver
driver = webdriver.Chrome()  # You should replace this with the appropriate web driver you're using (Chrome, Firefox, etc.)

# Open the URL of the webpage
url = "https://www.bigbasket.com/cl/foodgrains-oil-masala/?page=10"
driver.get(url)
driver.implicitly_wait(5)
# Automatically scroll the page
scroll_pause_time = 2  # Pause between each scroll
screen_height = driver.execute_script("return window.screen.height;")  # Browser window height
i = 1
scroll = 1
while True:
    # Scroll down
    driver.execute_script(f"window.scrollTo(0, {screen_height * i});")
    i += 1
    time.sleep(scroll_pause_time)
    scroll = scroll + 1
    print('scroll:',scroll)

    # Check if reaching the end of the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")
    if screen_height * i > scroll_height or scroll == 100:
        break

# Fetch the data using BeautifulSoup after all data is loaded
#print("scroll:",scroll)
soup = BeautifulSoup(driver.page_source, "html.parser")
#print(soup)
prettyf = open("scrollBB.txt", "wb")
prettyf.write(soup.prettify().encode("utf-8"))
print("written to scrollbb.txt")

skulist =soup.find_all(class_="SKUDeck___StyledDiv-sc-1e5d9gk-0 eA-dmzP") 
for sku in skulist:
    sp = sku.find_all(class_='block m-0 line-clamp-2 font-regular text-base leading-sm text-darkOnyx-800 pt-0.5 h-full')
    #print(sp)
 
    for h in sp:
        Grocery_Name = h.get_text()
        print("Grocery_Name=",Grocery_Name)
        Grocery_Name_list.append(Grocery_Name)
        
        discountlist= sku.find_all(class_='Label-sc-15v1nk5-0 Pricing___StyledLabel-sc-pldi2d-1 gJxZPQ AypOi')
        for dis in discountlist:
            Discount_Price = dis.get_text()
            print('Discount_Price=',Discount_Price)
            Discount_Price_list.append(Discount_Price)
        
        MRP_Price=0
        MRPlist= sku.find_all(class_='Label-sc-15v1nk5-0 Pricing___StyledLabel2-sc-pldi2d-2 gJxZPQ hsCgvu')
        for mrp in MRPlist:
            MRP_Price = mrp.get_text()
            print('MRP_Price=',MRP_Price)
            MRP_Price_list.append(MRP_Price)
        if MRP_Price == 0:
            print('MRP_Price=',Discount_Price)
            MRP_Price_list.append(Discount_Price)
        
        BrandList= sku.find_all(class_="Label-sc-15v1nk5-0 BrandName___StyledLabel2-sc-hssfrl-1 gJxZPQ keQNWn")
        for Brand in BrandList:
            Brand_Name = Brand.get_text()
            print('Brand_Name=',Brand_Name)
            Brand_Name_list.append(Brand_Name)
        
        QuantityListML= sku.find_all(class_="Label-sc-15v1nk5-0 PackSelector___StyledLabel-sc-1lmu4hv-0 gJxZPQ fnsuXg")
        for QuantML in QuantityListML:
            Quantity = QuantML.get_text()
            #Quantity_KG = 0
            print('Quantity=',Quantity)
            Quantity_list.append(Quantity)
            #Quantity_KG_list.append(Quantity_KG)
                
        QuantityListKg= sku.find_all(class_="Label-sc-15v1nk5-0 PackChanger___StyledLabel-sc-newjpv-1 gJxZPQ cWbtUx")
        for QuantKg in QuantityListKg:
            Quantity = QuantKg.get_text()
            #Quantity_ML = 0
            print('Quantity=',Quantity)
            Quantity_list.append(Quantity)
            #Quantity_ML_list.append(Quantity_ML)
        
        
        
        print("list Quantity_list",len(Quantity_list), "\nMRP_Price_list:",len(MRP_Price_list))
     
        print('\n')

driver.close()
# Close the file object
dict = {'Grocery_Name': Grocery_Name_list, 'Discount_Price': Discount_Price_list, 'MRP_Price': MRP_Price_list, 'Brand_Name': Brand_Name_list,
        'Quantity': Quantity_list }
              
df = pd.DataFrame(dict)
#print("df dict:",df)
 # saving the dataframe
df.to_csv('Bigbasket_data.csv')
prettyf.close()
# Out:
# scroll: 2
# scroll: 3
# scroll: 4
# scroll: 5
# scroll: 6
# scroll: 7
# scroll: 8
# scroll: 9
# scroll: 10
# scroll: 11
# scroll: 12
# scroll: 13
# scroll: 14
# scroll: 15
# scroll: 16
# scroll: 17
# scroll: 18
# scroll: 19
# scroll: 20
# scroll: 21
# scroll: 22
# scroll: 23
# scroll: 24
# scroll: 25
# scroll: 26
# scroll: 27
# scroll: 28
# scroll: 29
# scroll: 30
# scroll: 31
# scroll: 32
# scroll: 33
# scroll: 34
# scroll: 35
# scroll: 36
# scroll: 37
# scroll: 38
# scroll: 39
# scroll: 40
# scroll: 41
# scroll: 42
# scroll: 43
# scroll: 44
# scroll: 45
# scroll: 46
# scroll: 47
# scroll: 48
# scroll: 49
# scroll: 50
# scroll: 51
# scroll: 52
# scroll: 53
# scroll: 54
# scroll: 55
# scroll: 56
# scroll: 57
# scroll: 58
# scroll: 59
# scroll: 60
# scroll: 61
# scroll: 62
# scroll: 63
# scroll: 64
# scroll: 65
# scroll: 66
# scroll: 67
# scroll: 68
# scroll: 69
# scroll: 70
# scroll: 71
# scroll: 72
# scroll: 73
# scroll: 74
# scroll: 75
# scroll: 76
# scroll: 77
# scroll: 78
# scroll: 79
# scroll: 80
# scroll: 81
# scroll: 82
# scroll: 83
# scroll: 84
# scroll: 85
# scroll: 86
# scroll: 87
# scroll: 88
# scroll: 89
# scroll: 90
# scroll: 91
# scroll: 92
# scroll: 93
# scroll: 94
# scroll: 95
# scroll: 96
# scroll: 97
# scroll: 98
# scroll: 99
# scroll: 100
# scroll: 100
# written to scrollbb.txt
# Grocery_Name= Iodized Crystal Salt/Uppu
# Discount_Price= ₹19.58
# MRP_Price= ₹22
# Brand_Name= Aashirvaad
# Quantity= 1 kg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 91
#      89     #Quantity_KG = 0
#      90     print('Quantity=',Quantity)
# ---> 91     Quantity_list.append(Quantity)
#      92     #Quantity_KG_list.append(Quantity_KG)
#      94 QuantityListKg= sku.find_all(class_="Label-sc-15v1nk5-0 PackChanger___StyledLabel-sc-newjpv-1 gJxZPQ cWbtUx")
#
# NameError: name 'Quantity_list' is not defined

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
from csv import DictWriter
import time

Grocery_Name_list = []
Brand_Name_list = []
Discount_Price_list = []
MRP_Price_list = [] 
Quantity_ML_list = []
Quantity_KG_list = []

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
 
#url = 'https://www.bigbasket.com/cl/foodgrains-oil-masala'
#r = requests.get(url, headers=headers)#, proxies=proxies)

# Initialize WebDriver
driver = webdriver.Chrome()  # You should replace this with the appropriate web driver you're using (Chrome, Firefox, etc.)

# Open the URL of the webpage
url = "https://www.bigbasket.com/cl/foodgrains-oil-masala/?page=10"
driver.get(url)
driver.implicitly_wait(5)
# Automatically scroll the page
scroll_pause_time = 2  # Pause between each scroll
screen_height = driver.execute_script("return window.screen.height;")  # Browser window height
i = 1
scroll = 1
while True:
    # Scroll down
    driver.execute_script(f"window.scrollTo(0, {screen_height * i});")
    i += 1
    time.sleep(scroll_pause_time)
    scroll = scroll + 1
    print('scroll:',scroll)

    # Check if reaching the end of the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")
    if screen_height * i > scroll_height or scroll == 50:
        break

# Fetch the data using BeautifulSoup after all data is loaded
print("scroll:",scroll)
soup = BeautifulSoup(driver.page_source, "html.parser")
#print(soup)
prettyf = open("scrollBB.txt", "wb")
prettyf.write(soup.prettify().encode("utf-8"))
print("written to scrollbb.txt")

skulist =soup.find_all(class_="SKUDeck___StyledDiv-sc-1e5d9gk-0 eA-dmzP") 
for sku in skulist:
    sp = sku.find_all(class_='block m-0 line-clamp-2 font-regular text-base leading-sm text-darkOnyx-800 pt-0.5 h-full')
    #print(sp)
 
    for h in sp:
        Grocery_Name = h.get_text()
        print("Grocery_Name=",Grocery_Name)
        Grocery_Name_list.append(Grocery_Name)
        
        discountlist= sku.find_all(class_='Label-sc-15v1nk5-0 Pricing___StyledLabel-sc-pldi2d-1 gJxZPQ AypOi')
        for dis in discountlist:
            Discount_Price = dis.get_text()
            print('Discount_Price=',Discount_Price)
            Discount_Price_list.append(Discount_Price)
        
        MRP_Price=0
        MRPlist= sku.find_all(class_='Label-sc-15v1nk5-0 Pricing___StyledLabel2-sc-pldi2d-2 gJxZPQ hsCgvu')
        for mrp in MRPlist:
            MRP_Price = mrp.get_text()
            print('MRP_Price=',MRP_Price)
            MRP_Price_list.append(MRP_Price)
        if MRP_Price == 0:
            print('MRP_Price=',Discount_Price)
            MRP_Price_list.append(Discount_Price)
        
        BrandList= sku.find_all(class_="Label-sc-15v1nk5-0 BrandName___StyledLabel2-sc-hssfrl-1 gJxZPQ keQNWn")
        for Brand in BrandList:
            Brand_Name = Brand.get_text()
            print('Brand_Name=',Brand_Name)
            Brand_Name_list.append(Brand_Name)
        
        QuantityListML= sku.find_all(class_="Label-sc-15v1nk5-0 PackSelector___StyledLabel-sc-1lmu4hv-0 gJxZPQ fnsuXg")
        for QuantML in QuantityListML:
            Quantity_ML = QuantML.get_text()
            Quantity_KG = 0
            print('Quantity_ML=',Quantity_ML)
            Quantity_ML_list.append(Quantity_ML)
            Quantity_KG_list.append(Quantity_KG)
                
        QuantityListKg= sku.find_all(class_="Label-sc-15v1nk5-0 PackChanger___StyledLabel-sc-newjpv-1 gJxZPQ cWbtUx")
        for QuantKg in QuantityListKg:
            Quantity_KG = QuantKg.get_text()
            Quantity_ML = 0
            print('Quantity_KG=',Quantity_KG)
            Quantity_KG_list.append(Quantity_KG)
            Quantity_ML_list.append(Quantity_ML)
        
        
        
        print("list Quantity_ML_list",len(Quantity_ML_list), "\n\nQuantity_KG_list",len(Quantity_KG_list), "\n\nMRP_Price_list:",len(MRP_Price_list))
     
        print('\n')

driver.close()
# Close the file object
dict = {'Grocery_Name': Grocery_Name_list, 'Discount_Price': Discount_Price_list, 'MRP_Price': MRP_Price_list, 'Brand_Name': Brand_Name_list,
        'Quantity_ML': Quantity_ML_list, 'Quantity_KG': Quantity_KG_list}
              
df = pd.DataFrame(dict)
#print("df dict:",df)
 # saving the dataframe
df.to_csv('Bigbasket_data.csv')
prettyf.close()

# %%
import sys
print(sys.version_info)
import os
print(os.getcwd())
#!pip install requests
#!pip3 install beautifulsoup4
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
# Out:
# sys.version_info(major=3, minor=11, micro=3, releaselevel='final', serial=0)
# C:\Users\pijadhav\anaconda3\MTech

# %%
Grocery_Name_list = []
Brand_Name_list = []
Discount_Price_list = []
MRP_Price_list = [] 
Quantity_list = []

prettyf = open("scrollBB1.txt", "wb")
prettyf.write(soup.prettify().encode("utf-8"))
#print("written to scrollbb.txt")

skulist =soup.find_all(class_="SKUDeck___StyledDiv-sc-1e5d9gk-0 eA-dmzP") 
for sku in skulist:
    sp = sku.find_all(class_='block m-0 line-clamp-2 font-regular text-base leading-sm text-darkOnyx-800 pt-0.5 h-full')
    #print(sp)
 
    for h in sp:
        Grocery_Name = h.get_text()
        print("Grocery_Name=",Grocery_Name)
        Grocery_Name_list.append(Grocery_Name)
        
        discountlist= sku.find_all(class_='Label-sc-15v1nk5-0 Pricing___StyledLabel-sc-pldi2d-1 gJxZPQ AypOi')
        for dis in discountlist:
            Discount_Price = dis.get_text()
            print('Discount_Price=',Discount_Price)
            Discount_Price_list.append(Discount_Price)
        
        MRP_Price=0
        MRPlist= sku.find_all(class_='Label-sc-15v1nk5-0 Pricing___StyledLabel2-sc-pldi2d-2 gJxZPQ hsCgvu')
        for mrp in MRPlist:
            MRP_Price = mrp.get_text()
            print('MRP_Price=',MRP_Price)
            MRP_Price_list.append(MRP_Price)
        if MRP_Price == 0:
            print('MRP_Price=',Discount_Price)
            MRP_Price_list.append(Discount_Price)
        
        BrandList= sku.find_all(class_="Label-sc-15v1nk5-0 BrandName___StyledLabel2-sc-hssfrl-1 gJxZPQ keQNWn")
        for Brand in BrandList:
            Brand_Name = Brand.get_text()
            print('Brand_Name=',Brand_Name)
            Brand_Name_list.append(Brand_Name)
        
        QuantityListML= sku.find_all(class_="Label-sc-15v1nk5-0 PackSelector___StyledLabel-sc-1lmu4hv-0 gJxZPQ fnsuXg")
        for QuantML in QuantityListML:
            Quantity = QuantML.get_text()
            #Quantity_KG = 0
            print('Quantity=',Quantity)
            Quantity_list.append(Quantity)
            #Quantity_KG_list.append(Quantity_KG)
                
        QuantityListKg= sku.find_all(class_="Label-sc-15v1nk5-0 PackChanger___StyledLabel-sc-newjpv-1 gJxZPQ cWbtUx")
        for QuantKg in QuantityListKg:
            Quantity = QuantKg.get_text()
            #Quantity_ML = 0
            print('Quantity=',Quantity)
            Quantity_list.append(Quantity)
            #Quantity_ML_list.append(Quantity_ML)
        
        
        
        print("list Quantity_list",len(Quantity_list), "\nMRP_Price_list:",len(MRP_Price_list))
     
        print('\n')

#driver.close()
# Close the file object
dict = {'Grocery_Name': Grocery_Name_list, 'Discount_Price': Discount_Price_list, 'MRP_Price': MRP_Price_list, 'Brand_Name': Brand_Name_list,
        'Quantity': Quantity_list }
              
df = pd.DataFrame(dict)
#print("df dict:",df)
 # saving the dataframe
df.to_csv('Bigbasket_data.csv')
prettyf.close()
# Out:
# Grocery_Name= Iodized Crystal Salt/Uppu
# Discount_Price= ₹19.58
# MRP_Price= ₹22
# Brand_Name= Aashirvaad
# Quantity= 1 kg
# list Quantity_list 1
# MRP_Price_list: 1
#
#
# Grocery_Name= Ajwain/Om Kalu - Whole
# Discount_Price= ₹49
# MRP_Price= ₹50
# Brand_Name= BB Popular
# Quantity= 100 g
# list Quantity_list 2
# MRP_Price_list: 2
#
#
# Grocery_Name= Cornflour
# Discount_Price= ₹28.2
# MRP_Price= ₹30
# Brand_Name= Weikfield
# Quantity= 100 g - Carton
# list Quantity_list 3
# MRP_Price_list: 3
#
#
# Grocery_Name= Organic - Poha Medium
# Discount_Price= ₹41
# MRP_Price= ₹60
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 4
# MRP_Price_list: 4
#
#
# Grocery_Name= Pure Ghee
# Discount_Price= ₹1270
# MRP_Price= ₹1270
# Brand_Name= Amul
# Quantity= 2 x 1 L - Multipack
# list Quantity_list 5
# MRP_Price_list: 5
#
#
# Grocery_Name= Rozana Dubar Basmati Rice
# Discount_Price= ₹95.99
# MRP_Price= ₹130
# Brand_Name= Fortune
# Quantity= 1 kg - Pouch
# list Quantity_list 6
# MRP_Price_list: 6
#
#
# Grocery_Name= Bansi Sooji
# Discount_Price= ₹54
# MRP_Price= ₹70
# Brand_Name= Super Saver
# Quantity= 1 kg
# list Quantity_list 7
# MRP_Price_list: 7
#
#
# Grocery_Name= Asafoetida Cake
# Discount_Price= ₹91
# MRP_Price= ₹91
# Brand_Name= LG
# Quantity= 50 g - Box
# list Quantity_list 8
# MRP_Price_list: 8
#
#
# Grocery_Name= Cardamom/Elaichi - Green
# Discount_Price= ₹304
# MRP_Price= ₹480
# Brand_Name= Super Saver
# Quantity= 100 g
# list Quantity_list 9
# MRP_Price_list: 9
#
#
# Grocery_Name= Groundnut Oil - Filtered, Rich In Antioxidants & Vitamins, Chemical Free
# Discount_Price= ₹210
# MRP_Price= ₹210
# Brand_Name= Sunpure
# Quantity= 1 L
# list Quantity_list 10
# MRP_Price_list: 10
#
#
# Grocery_Name= Organic Cow Ghee - Rich In Aroma, No Pesticide Residues & Antibiotics
# Discount_Price= ₹725
# MRP_Price= ₹725
# Brand_Name= Aashirvaad Svasti
# Quantity= 500 ml - Jar
# list Quantity_list 11
# MRP_Price_list: 11
#
#
# Grocery_Name= Ponni Boiled - Rice
# Discount_Price= ₹279
# MRP_Price= ₹350
# Brand_Name= BB Royal
# Quantity= 5 kg - (12 - 17 Months Old)
# list Quantity_list 12
# MRP_Price_list: 12
#
#
# Grocery_Name= Masoor Dal/Mysore Bele
# Discount_Price= ₹49
# MRP_Price= ₹70
# Brand_Name= BB Super Saver
# Quantity= 500 g
# list Quantity_list 13
# MRP_Price_list: 13
#
#
# Grocery_Name= Organic Fried Gram/Huri Kadale
# Discount_Price= ₹76.95
# MRP_Price= ₹91
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 14
# MRP_Price_list: 14
#
#
# Grocery_Name= Premium Seedless Green Raisins
# Discount_Price= ₹264
# MRP_Price= ₹330
# Brand_Name= Happilo
# Quantity= 2x250 g - Multipack
# list Quantity_list 15
# MRP_Price_list: 15
#
#
# Grocery_Name= Masoor Black, Whole
# Discount_Price= ₹23
# MRP_Price= ₹35
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 16
# MRP_Price_list: 16
#
#
# Grocery_Name= Coriander/Dhania Powder
# Discount_Price= ₹97
# MRP_Price= ₹200
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 17
# MRP_Price_list: 17
#
#
# Grocery_Name= Hommade - Ginger Garlic Paste
# Discount_Price= ₹82.8
# MRP_Price= ₹100
# Brand_Name= Dabur
# Quantity= 2x200 g - Multipack
# list Quantity_list 18
# MRP_Price_list: 18
#
#
# Grocery_Name= Chilli - Cherry/Gundu With Stem
# Discount_Price= ₹297
# MRP_Price= ₹500
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 19
# MRP_Price_list: 19
#
#
# Grocery_Name= Gobind Bhog Rice/Akki
# Discount_Price= ₹484
# MRP_Price= ₹650
# Brand_Name= BB Royal
# Quantity= 5 kg - Pouch
# list Quantity_list 20
# MRP_Price_list: 20
#
#
# Grocery_Name= Powder - Sambar
# Discount_Price= ₹39.95
# MRP_Price= ₹47
# Brand_Name= Aachi
# Quantity= 100 g - Pouch
# list Quantity_list 21
# MRP_Price_list: 21
#
#
# Grocery_Name= Soya - Chunks
# Discount_Price= ₹156.22
# MRP_Price= ₹210
# Brand_Name= Nutrela
# Quantity= 1 kg - 0
# list Quantity_list 22
# MRP_Price_list: 22
#
#
# Grocery_Name= Pink Salt - With 100% Natural Sendha Salt, For Everyday Cooking, Iodised Rock Salt
# Discount_Price= ₹72
# MRP_Price= ₹80
# Brand_Name= Tata Salt
# Quantity= 1 kg - Pouch
# list Quantity_list 23
# MRP_Price_list: 23
#
#
# Grocery_Name= Organic Suji
# Discount_Price= ₹48
# MRP_Price= ₹60
# Brand_Name= Organic Tattva
# Quantity= 500 g - Pouch
# list Quantity_list 24
# MRP_Price_list: 24
#
#
# Grocery_Name= 100% Pure Premium Raisins Seedless - Premium Quality Kishmish, Source Of Potassium, Premium Dry Fruits
# Discount_Price= ₹90.85
# MRP_Price= ₹103
# Brand_Name= Tata Sampann
# Quantity= 200 g - Pouch
# list Quantity_list 25
# MRP_Price_list: 25
#
#
# Grocery_Name= Xpert - Total Balance Oil, Blend Of Rice Bran, Soyabean & Flaxseeds, Rich In Omega 3
# Discount_Price= ₹119
# MRP_Price= ₹160
# Brand_Name= Fortune
# Quantity= 1 L - Pouch
# list Quantity_list 26
# MRP_Price_list: 26
#
#
# Grocery_Name= Powder - Kutilal Red Chilli
# Discount_Price= ₹68
# MRP_Price= ₹68
# Brand_Name= Everest
# Quantity= 100 g - Pouch
# list Quantity_list 27
# MRP_Price_list: 27
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Pulav
# Discount_Price= ₹717.62
# MRP_Price= ₹820
# Brand_Name= Daawat
# Quantity= 5 kg - Pouch
# list Quantity_list 28
# MRP_Price_list: 28
#
#
# Grocery_Name= Organic - Red Masoor Dal/Mysore Bele, Unpolished
# Discount_Price= ₹63.65
# MRP_Price= ₹92
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 29
# MRP_Price_list: 29
#
#
# Grocery_Name= Soya Health Refined Soyabean Oil
# Discount_Price= ₹111
# MRP_Price= ₹130
# Brand_Name= Fortune
# Quantity= 1 L - Pouch
# list Quantity_list 30
# MRP_Price_list: 30
#
#
# Grocery_Name= Samba Wheat Broken
# Discount_Price= ₹115
# MRP_Price= ₹115
# Brand_Name= Double Horse
# Quantity= 500 g - Pouch
# list Quantity_list 31
# MRP_Price_list: 31
#
#
# Grocery_Name= Masala Paste - Puliogare Paste
# Discount_Price= ₹100
# MRP_Price= ₹100
# Brand_Name= MTR
# Quantity= 200 g - 0
# list Quantity_list 32
# MRP_Price_list: 32
#
#
# Grocery_Name= Powder - Cumin
# Discount_Price= ₹127.84
# MRP_Price= ₹136
# Brand_Name= Everest
# Quantity= 100 g - Carton
# list Quantity_list 33
# MRP_Price_list: 33
#
#
# Grocery_Name= Wheat Flour (Atta/Godihittu)
# Discount_Price= ₹389.87
# MRP_Price= ₹475
# Brand_Name= Super Saver
# Quantity= 10 kg - Pouch
# list Quantity_list 34
# MRP_Price_list: 34
#
#
# Grocery_Name= Sugar - Low GI
# Discount_Price= ₹116
# MRP_Price= ₹280
# Brand_Name= BB Gooddiet
# Quantity= 4x500 g - Multipack
# list Quantity_list 35
# MRP_Price_list: 35
#
#
# Grocery_Name= Saffron/Kesar
# Discount_Price= ₹104
# MRP_Price= ₹200
# Brand_Name= BB Royal
# Quantity= 0.5 g
# list Quantity_list 36
# MRP_Price_list: 36
#
#
# Grocery_Name= Sesame/Till - White
# Discount_Price= ₹30
# MRP_Price= ₹40
# Brand_Name= Super Saver
# Quantity= 100 g
# list Quantity_list 37
# MRP_Price_list: 37
#
#
# Grocery_Name= Kachi Ghani Mustard Oil
# Discount_Price= ₹143.75
# MRP_Price= ₹160
# Brand_Name= Emami Healthy & Tasty
# Quantity= 1 L - Bottle
# list Quantity_list 38
# MRP_Price_list: 38
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Sehat Mini Mogra
# Discount_Price= ₹549
# MRP_Price= ₹620
# Brand_Name= Daawat
# Quantity= 10 kg
# list Quantity_list 39
# MRP_Price_list: 39
#
#
# Grocery_Name= Dry Coconut/Gadi/Gola
# Discount_Price= ₹89
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 40
# MRP_Price_list: 40
#
#
# Grocery_Name= Masala - Chat
# Discount_Price= ₹148.52
# MRP_Price= ₹158
# Brand_Name= Everest
# Quantity= 200 g
# list Quantity_list 41
# MRP_Price_list: 41
#
#
# Grocery_Name= Cloves/Lavanga
# Discount_Price= ₹39
# MRP_Price= ₹40
# Brand_Name= BB Royal
# Quantity= 20 g
# list Quantity_list 42
# MRP_Price_list: 42
#
#
# Grocery_Name= White Puttu Podi
# Discount_Price= ₹69
# MRP_Price= ₹69
# Brand_Name= Double Horse
# Quantity= 1 kg - Pouch
# list Quantity_list 43
# MRP_Price_list: 43
#
#
# Grocery_Name= Jaggery/Bella - Cubes
# Discount_Price= ₹60
# MRP_Price= ₹80
# Brand_Name= BB Royal
# Quantity= 400 g
# list Quantity_list 44
# MRP_Price_list: 44
#
#
# Grocery_Name= Refined Oil - Sunflower
# Discount_Price= ₹109.88
# MRP_Price= ₹125
# Brand_Name= Mr. Gold
# Quantity= 1 L - Pouch
# list Quantity_list 45
# MRP_Price_list: 45
#
#
# Grocery_Name= Organic - Sooji/Rava
# Discount_Price= ₹64.6
# MRP_Price= ₹88
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 46
# MRP_Price_list: 46
#
#
# Grocery_Name= Wheat - Whole
# Discount_Price= ₹261
# MRP_Price= ₹350
# Brand_Name= BB Royal
# Quantity= 5 kg - Bag
# list Quantity_list 47
# MRP_Price_list: 47
#
#
# Grocery_Name= Raw Peanut
# Discount_Price= ₹598.4
# MRP_Price= ₹680
# Brand_Name= 24 Mantra Organic
# Quantity= 2x1 kg - Multipack
# list Quantity_list 48
# MRP_Price_list: 48
#
#
# Grocery_Name= Chilli - Byadagi, Stemless
# Discount_Price= ₹508
# MRP_Price= ₹600
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 49
# MRP_Price_list: 49
#
#
# Grocery_Name= Nakshatra Pooja Oil
# Discount_Price= ₹88.11
# MRP_Price= ₹105
# Brand_Name= Mr. Gold
# Quantity= 500 ml
# list Quantity_list 50
# MRP_Price_list: 50
#
#
# Grocery_Name= Unpolished Chana Dal
# Discount_Price= ₹147.84
# MRP_Price= ₹154
# Brand_Name= Tata Sampann
# Quantity= 1 kg - Pouch
# list Quantity_list 51
# MRP_Price_list: 51
#
#
# Grocery_Name= Poha/Avalakki/Aval - Thick
# Discount_Price= ₹62
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 1 kg - Pouch
# list Quantity_list 52
# MRP_Price_list: 52
#
#
# Grocery_Name= Refined Sunflower - Oil
# Discount_Price= ₹604.95
# MRP_Price= ₹675
# Brand_Name= Sunpure
# Quantity= 5 L - Can
# list Quantity_list 53
# MRP_Price_list: 53
#
#
# Grocery_Name= Walnut/Akhrot - Kernels
# Discount_Price= ₹224
# MRP_Price= ₹360
# Brand_Name= BB Popular
# Quantity= 200 g - Pouch
# list Quantity_list 54
# MRP_Price_list: 54
#
#
# Grocery_Name= Cashew/Kaju - Whole
# Discount_Price= ₹768
# MRP_Price= ₹1000
# Brand_Name= Super Saver
# Quantity= 1 kg
# list Quantity_list 55
# MRP_Price_list: 55
#
#
# Grocery_Name= Idli/Idly Rice
# Discount_Price= ₹99
# MRP_Price= ₹130
# Brand_Name= BB Royal
# Quantity= 2 kg - Pouch
# list Quantity_list 56
# MRP_Price_list: 56
#
#
# Grocery_Name= Gold - Refined Cooking Oil, Blend Of Rice Bran & Sunflower Oil, Helps Keeps Heart Healthy
# Discount_Price= ₹499
# MRP_Price= ₹690
# Brand_Name= Saffola
# Quantity= 3 L - Jar
# list Quantity_list 57
# MRP_Price_list: 57
#
#
# Grocery_Name= Powder - Asafoetida
# Discount_Price= ₹883
# MRP_Price= ₹883
# Brand_Name= LG
# Quantity= 500 g - Jar
# list Quantity_list 58
# MRP_Price_list: 58
#
#
# Grocery_Name= White Thick Poha - High In Fibre, For Breakfast & Evening Tea
# Discount_Price= ₹180
# MRP_Price= ₹212
# Brand_Name= Tata Sampann
# Quantity= 2x1kg - Multipack
# list Quantity_list 59
# MRP_Price_list: 59
#
#
# Grocery_Name= Urad Dal/Uddina Bele Whole White
# Discount_Price= ₹210
# MRP_Price= ₹224
# Brand_Name= Tata Sampann
# Quantity= 1 Kg
# list Quantity_list 60
# MRP_Price_list: 60
#
#
# Grocery_Name= Cow Ghee - Intense Aroma & Flavour, Rich Texture, Immunity Booster
# Discount_Price= ₹340.95
# MRP_Price= ₹370
# Brand_Name= Aashirvaad Svasti
# Quantity= 2x200 ml - Multipack
# list Quantity_list 61
# MRP_Price_list: 61
#
#
# Grocery_Name= Amrit - Brown Sugar
# Discount_Price= ₹76
# MRP_Price= ₹100
# Brand_Name= Parry's
# Quantity= 2x500 g - Multipack
# list Quantity_list 62
# MRP_Price_list: 62
#
#
# Grocery_Name= Black Pepper/Kari Menasu
# Discount_Price= ₹183
# MRP_Price= ₹280
# Brand_Name= BB Popular
# Quantity= 200 g - Pouch
# list Quantity_list 63
# MRP_Price_list: 63
#
#
# Grocery_Name= Maida -  Soft & Chemical Free
# Discount_Price= ₹10
# MRP_Price= ₹15
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 64
# MRP_Price_list: 64
#
#
# Grocery_Name= Organic - Raw Peanuts/Kadalekayi
# Discount_Price= ₹103.55
# MRP_Price= ₹136
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 65
# MRP_Price_list: 65
#
#
# Grocery_Name= Organic - Brown Sugar/Sakkare
# Discount_Price= ₹138.7
# MRP_Price= ₹229
# Brand_Name= BB Royal
# Quantity= 2 kg
# list Quantity_list 66
# MRP_Price_list: 66
#
#
# Grocery_Name= Superior-Mp-Sharbati-Atta/Godihittu - Fortified
# Discount_Price= ₹487.5
# MRP_Price= ₹650
# Brand_Name= BB Royal
# Quantity= 10 kg - Pouch
# list Quantity_list 67
# MRP_Price_list: 67
#
#
# Grocery_Name= Coconut Oil - 100% Pure
# Discount_Price= ₹97
# MRP_Price= ₹114
# Brand_Name= Parachute
# Quantity= 300 ml - Bottle
# list Quantity_list 68
# MRP_Price_list: 68
#
#
# Grocery_Name= Dosa Rice/Akki
# Discount_Price= ₹254
# MRP_Price= ₹275
# Brand_Name= Super Saver
# Quantity= 5 kg
# list Quantity_list 69
# MRP_Price_list: 69
#
#
# Grocery_Name= Original Extra Virgin Olive Oil
# Discount_Price= ₹995
# MRP_Price= ₹1400
# Brand_Name= BORGES
# Quantity= 1 L - Pet Bottle
# list Quantity_list 70
# MRP_Price_list: 70
#
#
# Grocery_Name= Oil - Groundnut
# Discount_Price= ₹169.41
# MRP_Price= ₹210
# Brand_Name= Freedom
# Quantity= 1 L
# list Quantity_list 71
# MRP_Price_list: 71
#
#
# Grocery_Name= Masala - Puliogare Powder
# Discount_Price= ₹122
# MRP_Price= ₹135
# Brand_Name= MTR
# Quantity= 200 g - Pouch
# list Quantity_list 72
# MRP_Price_list: 72
#
#
# Grocery_Name= Rice Flour
# Discount_Price= ₹43
# MRP_Price= ₹60
# Brand_Name= BB Royal
# Quantity= 1 kg - Pouch
# list Quantity_list 73
# MRP_Price_list: 73
#
#
# Grocery_Name= Organic - Cumin/Jeera/Jeerige
# Discount_Price= ₹452.2
# MRP_Price= ₹600
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 74
# MRP_Price_list: 74
#
#
# Grocery_Name= Chana - Brown/Kadale Kaalu
# Discount_Price= ₹20
# MRP_Price= ₹35
# Brand_Name= BB Popular
# Quantity= 200 g - Pouch
# list Quantity_list 75
# MRP_Price_list: 75
#
#
# Grocery_Name= Kabuli Chana/Kabuli Kadale
# Discount_Price= ₹239
# MRP_Price= ₹240
# Brand_Name= BB Popular
# Quantity= 1 kg - Pouch
# list Quantity_list 76
# MRP_Price_list: 76
#
#
# Grocery_Name= Coriander/Dhania Seeds
# Discount_Price= ₹48
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 77
# MRP_Price_list: 77
#
#
# Grocery_Name= New Rice/Akki - Sona Masoori
# Discount_Price= ₹299
# MRP_Price= ₹325
# Brand_Name= BB Popular
# Quantity= 5 kg
# list Quantity_list 78
# MRP_Price_list: 78
#
#
# Grocery_Name= Fine Besan/Kadale Hittu - 100% Chana Dal
# Discount_Price= ₹134.1
# MRP_Price= ₹149
# Brand_Name= Tata Sampann
# Quantity= 1 kg
# list Quantity_list 79
# MRP_Price_list: 79
#
#
# Grocery_Name= Phool Makhana
# Discount_Price= ₹88
# MRP_Price= ₹120
# Brand_Name= BB Popular
# Quantity= 100 g - Pouch
# list Quantity_list 80
# MRP_Price_list: 80
#
#
# Grocery_Name= Cold Pressed Groundnut Cooking Oil - Cooks Indian Dishes
# Discount_Price= ₹906.99
# MRP_Price= ₹1500
# Brand_Name= BB Royal Organic
# Quantity= 3x1L - Multipack
# list Quantity_list 81
# MRP_Price_list: 81
#
#
# Grocery_Name= Tamarind/Hunisehannu/Imli Seedless Cake
# Discount_Price= ₹239
# MRP_Price= ₹400
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 82
# MRP_Price_list: 82
#
#
# Grocery_Name= Amrit Powdered Jaggery
# Discount_Price= ₹80
# MRP_Price= ₹110
# Brand_Name= Parry's
# Quantity= 2x500 g - Multipack
# list Quantity_list 83
# MRP_Price_list: 83
#
#
# Grocery_Name= Moong Dal/Hesaru Bele
# Discount_Price= ₹138
# MRP_Price= ₹190
# Brand_Name= BB Popular
# Quantity= 1 kg - Pouch
# list Quantity_list 84
# MRP_Price_list: 84
#
#
# Grocery_Name= Poha/Avalakki - Extra Thick, Mota
# Discount_Price= ₹74
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 85
# MRP_Price_list: 85
#
#
# Grocery_Name= Unpolished Green Moong Dal - Whole
# Discount_Price= ₹190.08
# MRP_Price= ₹198
# Brand_Name= Tata Sampann
# Quantity= 2 x 500 g - Multipack
# list Quantity_list 86
# MRP_Price_list: 86
#
#
# Grocery_Name= Jaggery - Square
# Discount_Price= ₹82
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 87
# MRP_Price_list: 87
#
#
# Grocery_Name= Fenugreek/Methi/Menthya
# Discount_Price= ₹36
# MRP_Price= ₹60
# Brand_Name= BB Popular
# Quantity= 200 g
# list Quantity_list 88
# MRP_Price_list: 88
#
#
# Grocery_Name= HMT Kolam Rice/Akki
# Discount_Price= ₹77
# MRP_Price= ₹95
# Brand_Name= BB Royal
# Quantity= 1 kg - (12 + Months Old)
# list Quantity_list 89
# MRP_Price_list: 89
#
#
# Grocery_Name= Iodised Crystal Salt
# Discount_Price= ₹44
# MRP_Price= ₹44
# Brand_Name= Tata Salt
# Quantity= 2x1kg - Multipack
# list Quantity_list 90
# MRP_Price_list: 90
#
#
# Grocery_Name= Tasty Refined Cooking oil | Blended Rice bran & Corn oil | Pro Fitness Conscious
# Discount_Price= ₹136
# MRP_Price= ₹150
# Brand_Name= Saffola
# Quantity= 1 L - Pouch
# list Quantity_list 91
# MRP_Price_list: 91
#
#
# Grocery_Name= Chilli - Guntur with Stem
# Discount_Price= ₹230
# MRP_Price= ₹350
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 92
# MRP_Price_list: 92
#
#
# Grocery_Name= Anjeer/Figs/Atti Hannu
# Discount_Price= ₹743
# MRP_Price= ₹1250
# Brand_Name= BB Popular
# Quantity= 500 g
# list Quantity_list 93
# MRP_Price_list: 93
#
#
# Grocery_Name= Organic - Cardamom Green/Elakki
# Discount_Price= ₹444
# MRP_Price= ₹449
# Brand_Name= BB Royal
# Quantity= 100 g
# list Quantity_list 94
# MRP_Price_list: 94
#
#
# Grocery_Name= Chiroti/Barik Sooji
# Discount_Price= ₹55
# MRP_Price= ₹65
# Brand_Name= BB Royal
# Quantity= 1 kg - Pouch
# list Quantity_list 95
# MRP_Price_list: 95
#
#
# Grocery_Name= Organic - Moong Dal/Hesaru Bele, Unpolished
# Discount_Price= ₹350
# MRP_Price= ₹449
# Brand_Name= BB Royal
# Quantity= 2 kg
# list Quantity_list 96
# MRP_Price_list: 96
#
#
# Grocery_Name= Himalayan Pink Rock Salt/Uppu Powder
# Discount_Price= ₹87
# MRP_Price= ₹110
# Brand_Name= GoodDiet
# Quantity= 1 kg
# list Quantity_list 97
# MRP_Price_list: 97
#
#
# Grocery_Name= Filtered Groundnut Oil
# Discount_Price= ₹207
# MRP_Price= ₹207
# Brand_Name= Safal
# Quantity= 1 L - pouch
# list Quantity_list 98
# MRP_Price_list: 98
#
#
# Grocery_Name= Urad Gota/Whole
# Discount_Price= ₹119
# MRP_Price= ₹190
# Brand_Name= BB Super Saver
# Quantity= 1 kg
# list Quantity_list 99
# MRP_Price_list: 99
#
#
# Grocery_Name= Chana Dal/Kadale Bele
# Discount_Price= ₹55
# MRP_Price= ₹65
# Brand_Name= BB Popular
# Quantity= 500 g - Pouch
# list Quantity_list 100
# MRP_Price_list: 100
#
#
# Grocery_Name= Cold Pressed Sunflower Cooking Oil - Cooks Indian Dishes
# Discount_Price= ₹906.99
# MRP_Price= ₹1350
# Brand_Name= BB Royal Organic
# Quantity= 3x1L - Multipack
# list Quantity_list 101
# MRP_Price_list: 101
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Rozana Super 90
# Discount_Price= ₹349
# MRP_Price= ₹486
# Brand_Name= Daawat
# Quantity= 5 kg
# list Quantity_list 102
# MRP_Price_list: 102
#
#
# Grocery_Name= Gingelly Oil
# Discount_Price= ₹351.67
# MRP_Price= ₹375
# Brand_Name= Mr. Gold
# Quantity= 1 L
# list Quantity_list 103
# MRP_Price_list: 103
#
#
# Grocery_Name= Phool Makhana
# Discount_Price= ₹114
# MRP_Price= ₹150
# Brand_Name= BB Royal
# Quantity= 100 g - Pouch
# list Quantity_list 104
# MRP_Price_list: 104
#
#
# Grocery_Name= Cow Ghee/Tuppa
# Discount_Price= ₹798
# MRP_Price= ₹840
# Brand_Name= Aashirvaad Svasti
# Quantity= 1 L - Pet Jar
# list Quantity_list 105
# MRP_Price_list: 105
#
#
# Grocery_Name= Refined Sunflower Oil - Trans Fat Free, Healthy Cooking Oil
# Discount_Price= ₹99
# MRP_Price= ₹145
# Brand_Name= Fiona
# Quantity= 1 L - Pouch
# list Quantity_list 106
# MRP_Price_list: 106
#
#
# Grocery_Name= Oil - Groundnut
# Discount_Price= ₹203
# MRP_Price= ₹250
# Brand_Name= Dhara
# Quantity= 1 L - Pouch
# list Quantity_list 107
# MRP_Price_list: 107
#
#
# Grocery_Name= Coconut Oil
# Discount_Price= ₹125.34
# MRP_Price= ₹145
# Brand_Name= Kpl Shudhi
# Quantity= 500 ml - Pouch
# list Quantity_list 108
# MRP_Price_list: 108
#
#
# Grocery_Name= Cow Desi Ghee/Tuppa
# Discount_Price= ₹1598
# MRP_Price= ₹2600
# Brand_Name= Fresho Organic
# Quantity= 2x1 L - (Multipack)
# list Quantity_list 109
# MRP_Price_list: 109
#
#
# Grocery_Name= Rice/Akki - Dosa
# Discount_Price= ₹89
# MRP_Price= ₹120
# Brand_Name= BB Royal
# Quantity= 2 kg - Pouch
# list Quantity_list 110
# MRP_Price_list: 110
#
#
# Grocery_Name= Mustard/Sasive/Rai - Small
# Discount_Price= ₹198
# MRP_Price= ₹300
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 111
# MRP_Price_list: 111
#
#
# Grocery_Name= Sabudana - White Medium
# Discount_Price= ₹120
# MRP_Price= ₹150
# Brand_Name= BB Royal
# Quantity= 1 kg - Pouch
# list Quantity_list 112
# MRP_Price_list: 112
#
#
# Grocery_Name= Mustard/Sasive/Rai - Small
# Discount_Price= ₹92
# MRP_Price= ₹150
# Brand_Name= BB Popular
# Quantity= 500 g
# list Quantity_list 113
# MRP_Price_list: 113
#
#
# Grocery_Name= Organic Jaggery/Bella Powder
# Discount_Price= ₹55.1
# MRP_Price= ₹95
# Brand_Name= BB Royal
# Quantity= 500 g - Jar
# list Quantity_list 114
# MRP_Price_list: 114
#
#
# Grocery_Name= Raisins/Ona Drakshi - Indian
# Discount_Price= ₹246
# MRP_Price= ₹500
# Brand_Name= BB Popular
# Quantity= 1 kg - Pouch
# list Quantity_list 115
# MRP_Price_list: 115
#
#
# Grocery_Name= Organic - Chana Brown/Kadale Kaalu
# Discount_Price= ₹29
# MRP_Price= ₹33
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 116
# MRP_Price_list: 116
#
#
# Grocery_Name= Tamil Ponni Boiled - Rice
# Discount_Price= ₹129
# MRP_Price= ₹150
# Brand_Name= BB Royal
# Quantity= 2 kg - Pouch
# list Quantity_list 117
# MRP_Price_list: 117
#
#
# Grocery_Name= Jeera/Jeerige - Whole
# Discount_Price= ₹201.6
# MRP_Price= ₹280
# Brand_Name= Catch
# Quantity= 200 g
# list Quantity_list 118
# MRP_Price_list: 118
#
#
# Grocery_Name= Organic - Sona Masoori Raw Rice
# Discount_Price= ₹832.2
# MRP_Price= ₹1050
# Brand_Name= BB Royal
# Quantity= 2x5 kg - Multipack
# list Quantity_list 119
# MRP_Price_list: 119
#
#
# Grocery_Name= Mustard/Sasive/Rai - Big
# Discount_Price= ₹171
# MRP_Price= ₹300
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 120
# MRP_Price_list: 120
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Dubar
# Discount_Price= ₹133
# MRP_Price= ₹159
# Brand_Name= India Gate
# Quantity= 1 kg - Pouch
# list Quantity_list 121
# MRP_Price_list: 121
#
#
# Grocery_Name= Pureit Refined Sunflower Oil
# Discount_Price= ₹569
# MRP_Price= ₹700
# Brand_Name= Gemini
# Quantity= 5 l - Jar
# list Quantity_list 122
# MRP_Price_list: 122
#
#
# Grocery_Name= Kabuli Chana/Kabuli Kadale
# Discount_Price= ₹299.86
# MRP_Price= ₹319
# Brand_Name= Tata Sampann
# Quantity= 1 kg - Pouch
# list Quantity_list 123
# MRP_Price_list: 123
#
#
# Grocery_Name= Dates/Kharjura - Deseeded
# Discount_Price= ₹149
# MRP_Price= ₹149
# Brand_Name= Lion
# Quantity= 500 g - Cup
# list Quantity_list 124
# MRP_Price_list: 124
#
#
# Grocery_Name= Maida
# Discount_Price= ₹22
# MRP_Price= ₹31
# Brand_Name= BB Super Saver
# Quantity= 500 g
# list Quantity_list 125
# MRP_Price_list: 125
#
#
# Grocery_Name= Superlite Advanced Oil - Sunflower
# Discount_Price= ₹479.22
# MRP_Price= ₹489
# Brand_Name= Sundrop
# Quantity= 3 L - Can
# list Quantity_list 126
# MRP_Price_list: 126
#
#
# Grocery_Name= Chilli - Guntur, Stemless
# Discount_Price= ₹245
# MRP_Price= ₹400
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 127
# MRP_Price_list: 127
#
#
# Grocery_Name= Rice Flour
# Discount_Price= ₹56.84
# MRP_Price= ₹58
# Brand_Name= Vijay
# Quantity= 1 kg
# list Quantity_list 128
# MRP_Price_list: 128
#
#
# Grocery_Name= MTR Hingh Powder
# Discount_Price= ₹72
# MRP_Price= ₹90
# Brand_Name= MTR
# Quantity= 50 gm
# list Quantity_list 129
# MRP_Price_list: 129
#
#
# Grocery_Name= Idli/Idly Rice
# Discount_Price= ₹96
# MRP_Price= ₹120
# Brand_Name= Super Saver
# Quantity= 2 kg
# list Quantity_list 130
# MRP_Price_list: 130
#
#
# Grocery_Name= Organic Cow Ghee/Tuppa
# Discount_Price= ₹750
# MRP_Price= ₹750
# Brand_Name= AKSHAYAKALPA
# Quantity= 490 ml
# list Quantity_list 131
# MRP_Price_list: 131
#
#
# Grocery_Name= Jaggery - Bucket
# Discount_Price= ₹63
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 900 g
# list Quantity_list 132
# MRP_Price_list: 132
#
#
# Grocery_Name= Lite - 15% Low Sodium Iodised Salt, Helps Blood Pressure & For Healthy Lifestyle
# Discount_Price= ₹47
# MRP_Price= ₹50
# Brand_Name= Tata Salt
# Quantity= 1 kg - Pouch
# list Quantity_list 133
# MRP_Price_list: 133
#
#
# Grocery_Name= Til/Ellu - White
# Discount_Price= ₹192
# MRP_Price= ₹250
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 134
# MRP_Price_list: 134
#
#
# Grocery_Name= Tamarind/Hunisehannu/Imli - Seedless
# Discount_Price= ₹170
# MRP_Price= ₹300
# Brand_Name= BB Popular
# Quantity= 1 kg - Pouch
# list Quantity_list 135
# MRP_Price_list: 135
#
#
# Grocery_Name= Cumin/Jeera/Jeerige - Whole
# Discount_Price= ₹369
# MRP_Price= ₹500
# Brand_Name= BB Popular
# Quantity= 500 g
# list Quantity_list 136
# MRP_Price_list: 136
#
#
# Grocery_Name= Red Lobia/Alasandee Kaalu
# Discount_Price= ₹75.2
# MRP_Price= ₹80
# Brand_Name= BB Royal
# Quantity= 500 g - Pouch
# list Quantity_list 137
# MRP_Price_list: 137
#
#
# Grocery_Name= Organic - Pumpkin Seeds
# Discount_Price= ₹321.1
# MRP_Price= ₹398
# Brand_Name= BB Royal
# Quantity= 2x200 g - Multipack
# list Quantity_list 138
# MRP_Price_list: 138
#
#
# Grocery_Name= Coconut Oil
# Discount_Price= ₹146.88
# MRP_Price= ₹265
# Brand_Name= Mr. Gold
# Quantity= 1 L
# list Quantity_list 139
# MRP_Price_list: 139
#
#
# Grocery_Name= Refined Oil - Sunflower
# Discount_Price= ₹110.5
# MRP_Price= ₹139
# Brand_Name= Freedom
# Quantity= 1 L - Pouch
# list Quantity_list 140
# MRP_Price_list: 140
#
#
# Grocery_Name= Turmeric Powder/Arisina Pudi
# Discount_Price= ₹153
# MRP_Price= ₹180
# Brand_Name= Tata Sampann
# Quantity= 500 g
# list Quantity_list 141
# MRP_Price_list: 141
#
#
# Grocery_Name= Sona Masuri Raw Rice/Akki - 12 Months, Pesticide Free
# Discount_Price= ₹373.1
# MRP_Price= ₹455
# Brand_Name= Safe Harvest
# Quantity= 5 kg
# list Quantity_list 142
# MRP_Price_list: 142
#
#
# Grocery_Name= Fennel/Saunf/Sompu - Big
# Discount_Price= ₹58
# MRP_Price= ₹80
# Brand_Name= BB Popular
# Quantity= 100 g
# list Quantity_list 143
# MRP_Price_list: 143
#
#
# Grocery_Name= Active Edible Oil
# Discount_Price= ₹1070
# MRP_Price= ₹1610
# Brand_Name= Saffola
# Quantity= 2x5L - Multipack
# list Quantity_list 144
# MRP_Price_list: 144
#
#
# Grocery_Name= Atta - Chakki Fresh
# Discount_Price= ₹60.36
# MRP_Price= ₹74
# Brand_Name= Fortune
# Quantity= 1 kg
# list Quantity_list 145
# MRP_Price_list: 145
#
#
# Grocery_Name= Pure Ghee/Tuppa
# Discount_Price= ₹145
# MRP_Price= ₹170
# Brand_Name= Fresho
# Quantity= 200 ml
# list Quantity_list 146
# MRP_Price_list: 146
#
#
# Grocery_Name= Organic Kabuli Chana/Kabuli Kadale
# Discount_Price= ₹453.15
# MRP_Price= ₹539
# Brand_Name= BB Royal
# Quantity= 2 kg
# list Quantity_list 147
# MRP_Price_list: 147
#
#
# Grocery_Name= Pista Magaj - Plain Kernel
# Discount_Price= ₹1329
# MRP_Price= ₹1500
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 148
# MRP_Price_list: 148
#
#
# Grocery_Name= High Aroma Cow Ghee
# Discount_Price= ₹1425.06
# MRP_Price= ₹1450
# Brand_Name= Amul
# Quantity= 2 x 1 L - Multipack
# list Quantity_list 149
# MRP_Price_list: 149
#
#
# Grocery_Name= Kurnool Sona Masoori Raw Rice (12 + Months Old)
# Discount_Price= ₹1499
# MRP_Price= ₹1820
# Brand_Name= BB Royal
# Quantity= 26 kg - (12 + Months Old)
# list Quantity_list 150
# MRP_Price_list: 150
#
#
# Grocery_Name= Rice Bran Health Physically Refined Oil
# Discount_Price= ₹683.4
# MRP_Price= ₹775
# Brand_Name= Fortune
# Quantity= 5 L - Jar
# list Quantity_list 151
# MRP_Price_list: 151
#
#
# Grocery_Name= Rock Salt/Uppu
# Discount_Price= ₹88.8
# MRP_Price= ₹120
# Brand_Name= Tata Salt
# Quantity= 1 kg - Pouch
# list Quantity_list 152
# MRP_Price_list: 152
#
#
# Grocery_Name= Jaggery/Bella - Kolhapuri
# Discount_Price= ₹46
# MRP_Price= ₹72
# Brand_Name= BB Royal
# Quantity= 450 g
# list Quantity_list 153
# MRP_Price_list: 153
#
#
# Grocery_Name= Nature's Super Foods Organic Atta
# Discount_Price= ₹65
# MRP_Price= ₹75
# Brand_Name= Aashirvaad
# Quantity= 1 kg
# list Quantity_list 154
# MRP_Price_list: 154
#
#
# Grocery_Name= Tasty - Pro Fitness Conscious Edible Oil
# Discount_Price= ₹408
# MRP_Price= ₹450
# Brand_Name= Saffola
# Quantity= 3X1 L - Multipack
# list Quantity_list 155
# MRP_Price_list: 155
#
#
# Grocery_Name= Cashew/Godambi - Broken
# Discount_Price= ₹941
# MRP_Price= ₹1200
# Brand_Name= BB Popular
# Quantity= 1 kg
# list Quantity_list 156
# MRP_Price_list: 156
#
#
# Grocery_Name= Horse Gram/Hurali Kaalu
# Discount_Price= ₹33
# MRP_Price= ₹36
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 157
# MRP_Price_list: 157
#
#
# Grocery_Name= Powder - Tikhalal Chilly
# Discount_Price= ₹660
# MRP_Price= ₹660
# Brand_Name= Everest
# Quantity= 1 kg - Pouch
# list Quantity_list 158
# MRP_Price_list: 158
#
#
# Grocery_Name= Salt/Uppu - Crystal
# Discount_Price= ₹18.27
# MRP_Price= ₹26
# Brand_Name= AKAR
# Quantity= 1 kg - Pouch
# list Quantity_list 159
# MRP_Price_list: 159
#
#
# Grocery_Name= Almond/Badam - Californian, Giri
# Discount_Price= ₹702
# MRP_Price= ₹1000
# Brand_Name= Super Saver
# Quantity= 1 kg
# list Quantity_list 160
# MRP_Price_list: 160
#
#
# Grocery_Name= Organic Walnut/Akrodu Kernels
# Discount_Price= ₹800.85
# MRP_Price= ₹1099
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 161
# MRP_Price_list: 161
#
#
# Grocery_Name= Rice/Akki - Jeera
# Discount_Price= ₹114.92
# MRP_Price= ₹135
# Brand_Name= India Gate
# Quantity= 1 kg
# list Quantity_list 162
# MRP_Price_list: 162
#
#
# Grocery_Name= Ragi Flour/Ragi Hittu
# Discount_Price= ₹53
# MRP_Price= ₹90
# Brand_Name= BB Super Saver
# Quantity= 1 kg
# list Quantity_list 163
# MRP_Price_list: 163
#
#
# Grocery_Name= Turmeric Powder
# Discount_Price= ₹73
# MRP_Price= ₹81
# Brand_Name= MTR
# Quantity= 250 Gm
# list Quantity_list 164
# MRP_Price_list: 164
#
#
# Grocery_Name= Khus Khus/Gasagase
# Discount_Price= ₹492
# MRP_Price= ₹800
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 165
# MRP_Price_list: 165
#
#
# Grocery_Name= Organic - Cashew/Godambi Whole Bold
# Discount_Price= ₹1071.6
# MRP_Price= ₹1499
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 166
# MRP_Price_list: 166
#
#
# Grocery_Name= Ghee/Tuppa
# Discount_Price= ₹3130
# MRP_Price= ₹3130
# Brand_Name= Amul
# Quantity= 5 L
# list Quantity_list 167
# MRP_Price_list: 167
#
#
# Grocery_Name= Masoor Dal/Mysore Bele
# Discount_Price= ₹29
# MRP_Price= ₹37
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 168
# MRP_Price_list: 168
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Classic
# Discount_Price= ₹196.67
# MRP_Price= ₹243
# Brand_Name= India Gate
# Quantity= 1 kg - Pouch
# list Quantity_list 169
# MRP_Price_list: 169
#
#
# Grocery_Name= Organic - Sugar
# Discount_Price= ₹226.1
# MRP_Price= ₹430
# Brand_Name= BB Royal
# Quantity= 2x2 kg - Multipack
# list Quantity_list 170
# MRP_Price_list: 170
#
#
# Grocery_Name= Sundrop Super Lite Advanced - Sunflower Oil Pouch
# Discount_Price= ₹180
# MRP_Price= ₹180
# Brand_Name= Sundrop
# Quantity= 1 L - Pouch
# list Quantity_list 171
# MRP_Price_list: 171
#
#
# Grocery_Name= Green Peas
# Discount_Price= ₹32
# MRP_Price= ₹70
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 172
# MRP_Price_list: 172
#
#
# Grocery_Name= Wheat - Sharbati
# Discount_Price= ₹493
# MRP_Price= ₹600
# Brand_Name= BB Royal
# Quantity= 10 kg - Bag
# list Quantity_list 173
# MRP_Price_list: 173
#
#
# Grocery_Name= Organic - Cinnamon/Chakke
# Discount_Price= ₹19.95
# MRP_Price= ₹27
# Brand_Name= BB Royal
# Quantity= 20 g
# list Quantity_list 174
# MRP_Price_list: 174
#
#
# Grocery_Name= Organic - Black Pepper/Kali Mirchi
# Discount_Price= ₹380
# MRP_Price= ₹500
# Brand_Name= BB Royal
# Quantity= 2x200 g - Multipack
# list Quantity_list 175
# MRP_Price_list: 175
#
#
# Grocery_Name= Organic - Chia Seeds
# Discount_Price= ₹106.4
# MRP_Price= ₹205
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 176
# MRP_Price_list: 176
#
#
# Grocery_Name= Black Raisins/Ona Drakshi - Seedless
# Discount_Price= ₹93
# MRP_Price= ₹120
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 177
# MRP_Price_list: 177
#
#
# Grocery_Name= Chilli Powder
# Discount_Price= ₹175
# MRP_Price= ₹250
# Brand_Name= Aashirvaad
# Quantity= 500 g
# list Quantity_list 178
# MRP_Price_list: 178
#
#
# Grocery_Name= Mixed Dry fruits
# Discount_Price= ₹639
# MRP_Price= ₹750
# Brand_Name= BB Royal
# Quantity= 500 g - Pouch
# list Quantity_list 179
# MRP_Price_list: 179
#
#
# Grocery_Name= Chakki-Fresh-Wheat-Atta/Godihittu - Fortified
# Discount_Price= ₹406.43
# MRP_Price= ₹550
# Brand_Name= BB Royal
# Quantity= 10 kg
# list Quantity_list 180
# MRP_Price_list: 180
#
#
# Grocery_Name= Masoor Dal/Mysore Bele - Whole, Unpolished
# Discount_Price= ₹154.23
# MRP_Price= ₹159
# Brand_Name= Tata Sampann
# Quantity= 1 kg - Pouch
# list Quantity_list 181
# MRP_Price_list: 181
#
#
# Grocery_Name= Oil - Mantra GroundNut
# Discount_Price= ₹246
# MRP_Price= ₹246
# Brand_Name= Idhayam
# Quantity= 1 L - Pouch
# list Quantity_list 182
# MRP_Price_list: 182
#
#
# Grocery_Name= California Almonds - Premium, Protein Packed
# Discount_Price= ₹199
# MRP_Price= ₹300
# Brand_Name= BB Royal
# Quantity= 200 g - Standy Ziplock Pouch
# list Quantity_list 183
# MRP_Price_list: 183
#
#
# Grocery_Name= Salt/Uppu - Iodised
# Discount_Price= ₹15.75
# MRP_Price= ₹25
# Brand_Name= Aashirvaad
# Quantity= 1 kg - Pouch
# list Quantity_list 184
# MRP_Price_list: 184
#
#
# Grocery_Name= Basmati Rice - Rozana Premium
# Discount_Price= ₹874.95
# MRP_Price= ₹1150
# Brand_Name= BB Royal
# Quantity= 2x5 Kg - Multipack
# list Quantity_list 185
# MRP_Price_list: 185
#
#
# Grocery_Name= Ginger Garlic Paste
# Discount_Price= ₹108.75
# MRP_Price= ₹145
# Brand_Name= Mother's Recipe
# Quantity= 500 g
# list Quantity_list 186
# MRP_Price_list: 186
#
#
# Grocery_Name= Oil - Groundnut Pouch
# Discount_Price= ₹609
# MRP_Price= ₹750
# Brand_Name= Dhara
# Quantity= 3x1 L - Multipack
# list Quantity_list 187
# MRP_Price_list: 187
#
#
# Grocery_Name= Coriander Powder
# Discount_Price= ₹182.75
# MRP_Price= ₹215
# Brand_Name= Tata Sampann
# Quantity= 500 g
# list Quantity_list 188
# MRP_Price_list: 188
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Biryani
# Discount_Price= ₹1011.16
# MRP_Price= ₹1170
# Brand_Name= Daawat
# Quantity= 5 kg - Bag
# list Quantity_list 189
# MRP_Price_list: 189
#
#
# Grocery_Name= Ragi Flour
# Discount_Price= ₹66.64
# MRP_Price= ₹68
# Brand_Name= Vijay
# Quantity= 1 kg
# list Quantity_list 190
# MRP_Price_list: 190
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Rozana Gold
# Discount_Price= ₹477.62
# MRP_Price= ₹560
# Brand_Name= Daawat
# Quantity= 5 kg - Pouch
# list Quantity_list 191
# MRP_Price_list: 191
#
#
# Grocery_Name= Masoor Dal/Mysore Bele
# Discount_Price= ₹89
# MRP_Price= ₹150
# Brand_Name= BB Popular
# Quantity= 1 kg - Pouch
# list Quantity_list 192
# MRP_Price_list: 192
#
#
# Grocery_Name= Sooji/Bombay Rava
# Discount_Price= ₹49
# MRP_Price= ₹62
# Brand_Name= BB Super Saver
# Quantity= 1 kg
# list Quantity_list 193
# MRP_Price_list: 193
#
#
# Grocery_Name= Coconad - Coconut Oil
# Discount_Price= ₹172.8
# MRP_Price= ₹180
# Brand_Name= Klf
# Quantity= 1 L - Pouch
# list Quantity_list 194
# MRP_Price_list: 194
#
#
# Grocery_Name= Organic - Mustard/Sasive/Rai, Small
# Discount_Price= ₹20
# MRP_Price= ₹21
# Brand_Name= BB Royal
# Quantity= 100 g
# list Quantity_list 195
# MRP_Price_list: 195
#
#
# Grocery_Name= Ponni Raw Rice - Super Premium
# Discount_Price= ₹1611
# MRP_Price= ₹1950
# Brand_Name= BB Royal
# Quantity= 26 kg - (18 + Months  Old)
# list Quantity_list 196
# MRP_Price_list: 196
#
#
# Grocery_Name= Roasted Sooji/Rava
# Discount_Price= ₹31
# MRP_Price= ₹40
# Brand_Name= BB Royal
# Quantity= 500 g - Pouch
# list Quantity_list 197
# MRP_Price_list: 197
#
#
# Grocery_Name= Lobia/Alasandee Kaalu - White
# Discount_Price= ₹27
# MRP_Price= ₹34
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 198
# MRP_Price_list: 198
#
#
# Grocery_Name= Ponni Boiled Rice
# Discount_Price= ₹1440
# MRP_Price= ₹1800
# Brand_Name= BB Popular
# Quantity= 26 kg - Bag
# list Quantity_list 199
# MRP_Price_list: 199
#
#
# Grocery_Name= Organic - Little Millet/Samai Rice
# Discount_Price= ₹69.35
# MRP_Price= ₹92
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 200
# MRP_Price_list: 200
#
#
# Grocery_Name= Cashew/Godambi - Whole
# Discount_Price= ₹893
# MRP_Price= ₹2000
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 201
# MRP_Price_list: 201
#
#
# Grocery_Name= Idli Sooji/Rava
# Discount_Price= ₹19
# MRP_Price= ₹30
# Brand_Name= BB Royal
# Quantity= 500 g - Pouch
# list Quantity_list 202
# MRP_Price_list: 202
#
#
# Grocery_Name= Green Moong Whole/Sabut
# Discount_Price= ₹28
# MRP_Price= ₹30
# Brand_Name= BB Super Saver
# Quantity= 200 g
# list Quantity_list 203
# MRP_Price_list: 203
#
#
# Grocery_Name= Ponni Raw Rice (12 + Months Old)
# Discount_Price= ₹1631
# MRP_Price= ₹1750
# Brand_Name= BB Royal
# Quantity= 25 kg - Bag
# list Quantity_list 204
# MRP_Price_list: 204
#
#
# Grocery_Name= Palakkad Red Matta Boiled Rice - Unda
# Discount_Price= ₹1299
# MRP_Price= ₹1750
# Brand_Name= BB Royal
# Quantity= 25 kg - Bag
# list Quantity_list 205
# MRP_Price_list: 205
#
#
# Grocery_Name= Dates/Kharjura
# Discount_Price= ₹189
# MRP_Price= ₹189
# Brand_Name= Lion
# Quantity= 500 g - Buy 1 Get 1 Free
# list Quantity_list 206
# MRP_Price_list: 206
#
#
# Grocery_Name= Sona Masoori Steam Rice/Akki
# Discount_Price= ₹59
# MRP_Price= ₹70
# Brand_Name= BB Royal
# Quantity= 1 kg - Pouch
# list Quantity_list 207
# MRP_Price_list: 207
#
#
# Grocery_Name= Til - Black
# Discount_Price= ₹209
# MRP_Price= ₹250
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 208
# MRP_Price_list: 208
#
#
# Grocery_Name= Organic - Methi/Menthya
# Discount_Price= ₹32.3
# MRP_Price= ₹44
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 209
# MRP_Price_list: 209
#
#
# Grocery_Name= Organic - Brown Rice
# Discount_Price= ₹1282.5
# MRP_Price= ₹1798
# Brand_Name= BB Royal
# Quantity= 2x10 kg - Multipack
# list Quantity_list 210
# MRP_Price_list: 210
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Feast Rozzana
# Discount_Price= ₹98
# MRP_Price= ₹118
# Brand_Name= India Gate
# Quantity= 1 kg - Pouch
# list Quantity_list 211
# MRP_Price_list: 211
#
#
# Grocery_Name= Besan Fine/Kadale Hittu
# Discount_Price= ₹93
# MRP_Price= ₹150
# Brand_Name= BB Royal
# Quantity= 1 kg - Pouch
# list Quantity_list 212
# MRP_Price_list: 212
#
#
# Grocery_Name= Atta With 9 Multigrain - High-Fibre & High Protein Soft Rotis, Fortified
# Discount_Price= ₹500.96
# MRP_Price= ₹650
# Brand_Name= BB Royal
# Quantity= 10 kg
# list Quantity_list 213
# MRP_Price_list: 213
#
#
# Grocery_Name= Masala - Sambar Powder
# Discount_Price= ₹134
# MRP_Price= ₹150
# Brand_Name= MTR
# Quantity= 200 g - Pouch
# list Quantity_list 214
# MRP_Price_list: 214
#
#
# Grocery_Name= Chilli Powder
# Discount_Price= ₹145
# MRP_Price= ₹170
# Brand_Name= MTR
# Quantity= 250 Gm
# list Quantity_list 215
# MRP_Price_list: 215
#
#
# Grocery_Name= Kashmiri Chilli Powder - Perfect Colour, Smell & Taste
# Discount_Price= ₹330
# MRP_Price= ₹540
# Brand_Name= Eastern
# Quantity= 2x250 g - Multipack
# list Quantity_list 216
# MRP_Price_list: 216
#
#
# Grocery_Name= Organic - Byadagi Chilli Whole
# Discount_Price= ₹180.5
# MRP_Price= ₹229
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 217
# MRP_Price_list: 217
#
#
# Grocery_Name= Powder - Green Coriander
# Discount_Price= ₹200
# MRP_Price= ₹200
# Brand_Name= Everest
# Quantity= 500 g - Pouch
# list Quantity_list 218
# MRP_Price_list: 218
#
#
# Grocery_Name= Idli Rava
# Discount_Price= ₹56.84
# MRP_Price= ₹58
# Brand_Name= Vijay
# Quantity= 1 kg
# list Quantity_list 219
# MRP_Price_list: 219
#
#
# Grocery_Name= Masala - Bisibelebath Powder
# Discount_Price= ₹65
# MRP_Price= ₹80
# Brand_Name= MTR
# Quantity= 100 g - Pouch
# list Quantity_list 220
# MRP_Price_list: 220
#
#
# Grocery_Name= Filtered Groundnut Oil
# Discount_Price= ₹208.33
# MRP_Price= ₹240
# Brand_Name= Mr. Gold
# Quantity= 1 L - Pouch
# list Quantity_list 221
# MRP_Price_list: 221
#
#
# Grocery_Name= Vadi Matta Rice
# Discount_Price= ₹392
# MRP_Price= ₹480
# Brand_Name= Double Horse
# Quantity= 5 kg - Bag
# list Quantity_list 222
# MRP_Price_list: 222
#
#
# Grocery_Name= Fried Gram - Whole/Huri Kadale
# Discount_Price= ₹153
# MRP_Price= ₹180
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 223
# MRP_Price_list: 223
#
#
# Grocery_Name= Thick Poha
# Discount_Price= ₹83.3
# MRP_Price= ₹85
# Brand_Name= Vijay
# Quantity= 1 kg
# list Quantity_list 224
# MRP_Price_list: 224
#
#
# Grocery_Name= Pure Cow Ghee
# Discount_Price= ₹698
# MRP_Price= ₹770
# Brand_Name= Gowardhan
# Quantity= 2 x 500 ml - Multipack
# list Quantity_list 225
# MRP_Price_list: 225
#
#
# Grocery_Name= Wheat Dalia/Lapsi rava
# Discount_Price= ₹54
# MRP_Price= ₹80
# Brand_Name= BB Royal
# Quantity= 1 kg - Pouch
# list Quantity_list 226
# MRP_Price_list: 226
#
#
# Grocery_Name= HMT Kolam Raw Rice/Akki
# Discount_Price= ₹69
# MRP_Price= ₹90
# Brand_Name= Super Saver
# Quantity= 1 kg
# list Quantity_list 227
# MRP_Price_list: 227
#
#
# Grocery_Name= Plain Puffed Rice/Kadle Puri/Murmure
# Discount_Price= ₹36
# MRP_Price= ₹40
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 228
# MRP_Price_list: 228
#
#
# Grocery_Name= 100% Natural & Pure Groundnut Oil - Unrefined, Cold-Pressed
# Discount_Price= ₹1662.5
# MRP_Price= ₹1750
# Brand_Name= Nature Way
# Quantity= 5 L
# list Quantity_list 229
# MRP_Price_list: 229
#
#
# Grocery_Name= Organic - Maida
# Discount_Price= ₹31.35
# MRP_Price= ₹43
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 230
# MRP_Price_list: 230
#
#
# Grocery_Name= Pure Ghee
# Discount_Price= ₹1240
# MRP_Price= ₹1240
# Brand_Name= Amul
# Quantity= 2 x 1 L - Multipack
# list Quantity_list 231
# MRP_Price_list: 231
#
#
# Grocery_Name= Refined Oil - Rice Bran
# Discount_Price= ₹108.64
# MRP_Price= ₹140
# Brand_Name= Mr. Gold
# Quantity= 1 L - Pouch
# list Quantity_list 232
# MRP_Price_list: 232
#
#
# Grocery_Name= Whole Wheat Atta
# Discount_Price= ₹325.6
# MRP_Price= ₹370
# Brand_Name= 24 Mantra Organic
# Quantity= 5 kg - Pouch
# list Quantity_list 233
# MRP_Price_list: 233
#
#
# Grocery_Name= Organic - Sona Masoori Semi Brown Rice, Hand-Pounded
# Discount_Price= ₹801.8
# MRP_Price= ₹950
# Brand_Name= BB Royal
# Quantity= 2x5 kg - Multipack
# list Quantity_list 234
# MRP_Price_list: 234
#
#
# Grocery_Name= 100% Natural Premium Californian Almonds - Value Pack
# Discount_Price= ₹899.1
# MRP_Price= ₹1350
# Brand_Name= Happilo
# Quantity= 1 kg
# list Quantity_list 235
# MRP_Price_list: 235
#
#
# Grocery_Name= Masala - Rasam Powder
# Discount_Price= ₹119
# MRP_Price= ₹135
# Brand_Name= MTR
# Quantity= 200 g - Pouch
# list Quantity_list 236
# MRP_Price_list: 236
#
#
# Grocery_Name= Kabuli Chana/Kabuli Kadale
# Discount_Price= ₹32
# MRP_Price= ₹50
# Brand_Name= BB Super Saver
# Quantity= 200 g
# list Quantity_list 237
# MRP_Price_list: 237
#
#
# Grocery_Name= Active - Goodness Of Olive Oil
# Discount_Price= ₹1395
# MRP_Price= ₹1395
# Brand_Name= Oleev
# Quantity= 5 L - Jar
# list Quantity_list 238
# MRP_Price_list: 238
#
#
# Grocery_Name= Anjeer/Figs/Atti Hannu
# Discount_Price= ₹416
# MRP_Price= ₹600
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 239
# MRP_Price_list: 239
#
#
# Grocery_Name= Cow's Pure Ghee - Source Of Calcium, Boosts Overall Health
# Discount_Price= ₹3575
# MRP_Price= ₹3575
# Brand_Name= Sri Sri Tattva
# Quantity= 5 L - Tin
# list Quantity_list 240
# MRP_Price_list: 240
#
#
# Grocery_Name= Cashew/Godambi - Split
# Discount_Price= ₹464
# MRP_Price= ₹900
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 241
# MRP_Price_list: 241
#
#
# Grocery_Name= Refined - Sunflower Oil
# Discount_Price= ₹577.5
# MRP_Price= ₹725
# Brand_Name= Dhara
# Quantity= 5 L - Can
# list Quantity_list 242
# MRP_Price_list: 242
#
#
# Grocery_Name= Organic - Idly/Idli Rice/Akki
# Discount_Price= ₹139.65
# MRP_Price= ₹175
# Brand_Name= BB Royal
# Quantity= 2 kg
# list Quantity_list 243
# MRP_Price_list: 243
#
#
# Grocery_Name= Rice Flour/Akki Hittu
# Discount_Price= ₹45
# MRP_Price= ₹55
# Brand_Name= BB Super Saver
# Quantity= 1 kg
# list Quantity_list 244
# MRP_Price_list: 244
#
#
# Grocery_Name= Basmati Rice - Super
# Discount_Price= ₹138.86
# MRP_Price= ₹220
# Brand_Name= Daawat
# Quantity= 1 kg - Pouch
# list Quantity_list 245
# MRP_Price_list: 245
#
#
# Grocery_Name= Pistachios - Roasted & Salted, Premium Californian
# Discount_Price= ₹659.66
# MRP_Price= ₹790
# Brand_Name= Happilo
# Quantity= 2x200 g - Multipack
# list Quantity_list 246
# MRP_Price_list: 246
#
#
# Grocery_Name= Mustard Oil
# Discount_Price= ₹145
# MRP_Price= ₹145
# Brand_Name= Patanjali
# Quantity= 1 L - Bottle
# list Quantity_list 247
# MRP_Price_list: 247
#
#
# Grocery_Name= Unpolished Urad Dal - Split
# Discount_Price= ₹217.28
# MRP_Price= ₹224
# Brand_Name= Tata Sampann
# Quantity= 1 kg
# list Quantity_list 248
# MRP_Price_list: 248
#
#
# Grocery_Name= 100% Pure Premium Cashews Whole - Premium Quality Kaju, Rich In Protein, Magnesium, & Phosphorus, Premium Nuts & Dry Fruits|
# Discount_Price= ₹1100.85
# MRP_Price= ₹1170
# Brand_Name= Tata Sampann
# Quantity= 1 kg - Pouch
# list Quantity_list 249
# MRP_Price_list: 249
#
#
# Grocery_Name= Powder - Kashmirilal
# Discount_Price= ₹255
# MRP_Price= ₹255
# Brand_Name= Everest
# Quantity= 200 g
# list Quantity_list 250
# MRP_Price_list: 250
#
#
# Grocery_Name= Organic - Foxtail Millet / Italian (Thinai Rice)
# Discount_Price= ₹226.1
# MRP_Price= ₹279
# Brand_Name= BB Royal
# Quantity= 2 kg
# list Quantity_list 251
# MRP_Price_list: 251
#
#
# Grocery_Name= Cashews - Whole, 100% Natural Premium
# Discount_Price= ₹469
# MRP_Price= ₹670
# Brand_Name= Happilo
# Quantity= 2x200 g - Multipack
# list Quantity_list 252
# MRP_Price_list: 252
#
#
# Grocery_Name= Organic - Jowar Flour/Jolada Hittu
# Discount_Price= ₹133
# MRP_Price= ₹179
# Brand_Name= BB Royal
# Quantity= 2 kg
# list Quantity_list 253
# MRP_Price_list: 253
#
#
# Grocery_Name= Organic - Cloves/Lavanga
# Discount_Price= ₹48
# MRP_Price= ₹49
# Brand_Name= BB Royal
# Quantity= 20 g
# list Quantity_list 254
# MRP_Price_list: 254
#
#
# Grocery_Name= Sona Masoori Steam Rice/Akki
# Discount_Price= ₹1199
# MRP_Price= ₹1375
# Brand_Name= Super Saver
# Quantity= 25 kg
# list Quantity_list 255
# MRP_Price_list: 255
#
#
# Grocery_Name= Walnuts - Kernels, Premium 100% Natural Kashmiri
# Discount_Price= ₹609.7
# MRP_Price= ₹910
# Brand_Name= Happilo
# Quantity= 2x200 g - Multipack
# list Quantity_list 256
# MRP_Price_list: 256
#
#
# Grocery_Name= Soya - Mini Chunk
# Discount_Price= ₹57
# MRP_Price= ₹60
# Brand_Name= Nutrela
# Quantity= 200 g - 0
# list Quantity_list 257
# MRP_Price_list: 257
#
#
# Grocery_Name= Pure Cow Ghee
# Discount_Price= ₹1440
# MRP_Price= ₹1450
# Brand_Name= Gowardhan
# Quantity= 2 x 1 L - Multipack
# list Quantity_list 258
# MRP_Price_list: 258
#
#
# Grocery_Name= Walnut/Akhrot- Kernels
# Discount_Price= ₹163
# MRP_Price= ₹200
# Brand_Name= BB Royal
# Quantity= 100 g - Vacuum Packed
# list Quantity_list 259
# MRP_Price_list: 259
#
#
# Grocery_Name= Jaggery/Bella Powder/Nattu Sakkarai
# Discount_Price= ₹48
# MRP_Price= ₹60
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 260
# MRP_Price_list: 260
#
#
# Grocery_Name= Rajma/Capparadavare - White/Chitra
# Discount_Price= ₹95
# MRP_Price= ₹115
# Brand_Name= BB Royal
# Quantity= 500 g - Pouch
# list Quantity_list 261
# MRP_Price_list: 261
#
#
# Grocery_Name= Dry Dates/Kharjura - Chuwara, Kharik
# Discount_Price= ₹72
# MRP_Price= ₹80
# Brand_Name= BB Royal
# Quantity= 100 g - Pouch
# list Quantity_list 262
# MRP_Price_list: 262
#
#
# Grocery_Name= Organic - Ragi Flour/Ragi Hittu
# Discount_Price= ₹34.2
# MRP_Price= ₹41
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 263
# MRP_Price_list: 263
#
#
# Grocery_Name= White Peas/Bili Batani
# Discount_Price= ₹112
# MRP_Price= ₹180
# Brand_Name= BB Royal
# Quantity= 1 kg - Pouch
# list Quantity_list 264
# MRP_Price_list: 264
#
#
# Grocery_Name= Tur/Arhar Dal
# Discount_Price= ₹510.4
# MRP_Price= ₹580
# Brand_Name= 24 Mantra Organic
# Quantity= 2x1 kg - Multipack
# list Quantity_list 265
# MRP_Price_list: 265
#
#
# Grocery_Name= Chana Dal
# Discount_Price= ₹218
# MRP_Price= ₹250
# Brand_Name= BB Super Saver
# Quantity= 2 kg
# list Quantity_list 266
# MRP_Price_list: 266
#
#
# Grocery_Name= Masala-Ae-Magic - Seasoning With Aromatic Roasted Spices, Enhances Flavour
# Discount_Price= ₹51
# MRP_Price= ₹60
# Brand_Name= MAGGI
# Quantity= 6 g - (Pack of 12)
# list Quantity_list 267
# MRP_Price_list: 267
#
#
# Grocery_Name= Bombay Sooji
# Discount_Price= ₹68.6
# MRP_Price= ₹70
# Brand_Name= Vijay
# Quantity= 1 kg
# list Quantity_list 268
# MRP_Price_list: 268
#
#
# Grocery_Name= Super Saver Palakkad Red Matta Boiled Rice
# Discount_Price= ₹63
# MRP_Price= ₹70
# Brand_Name= Super Saver
# Quantity= 1 kg
# list Quantity_list 269
# MRP_Price_list: 269
#
#
# Grocery_Name= Masala - Garam
# Discount_Price= ₹200
# MRP_Price= ₹200
# Brand_Name= Everest
# Quantity= 200 g
# list Quantity_list 270
# MRP_Price_list: 270
#
#
# Grocery_Name= Poppy Seed
# Discount_Price= ₹618
# MRP_Price= ₹618
# Brand_Name= JK
# Quantity= 250 g
# list Quantity_list 271
# MRP_Price_list: 271
#
#
# Grocery_Name= Sonamasuri Rice
# Discount_Price= ₹939.6
# MRP_Price= ₹1470
# Brand_Name= 24 Mantra Organic
# Quantity= 3x5 kg - Multipack
# list Quantity_list 272
# MRP_Price_list: 272
#
#
# Grocery_Name= Gold Palmolein Oil
# Discount_Price= ₹96
# MRP_Price= ₹125
# Brand_Name= RUCHI
# Quantity= 893 g - Pouch
# list Quantity_list 273
# MRP_Price_list: 273
#
#
# Grocery_Name= Double Roasted Rava
# Discount_Price= ₹110
# MRP_Price= ₹110
# Brand_Name= Double Horse
# Quantity= 1 kg
# list Quantity_list 274
# MRP_Price_list: 274
#
#
# Grocery_Name= Multigrain Atta - 7 Grains, High Fibre Flour, High Protein Atta
# Discount_Price= ₹550.5
# MRP_Price= ₹734
# Brand_Name= Pillsbury
# Quantity= 2 x 5 kg - Multipack
# list Quantity_list 275
# MRP_Price_list: 275
#
#
# Grocery_Name= Ghee/Tuppa
# Discount_Price= ₹375
# MRP_Price= ₹450
# Brand_Name= Milky Mist
# Quantity= 500 ml - Pet Jar
# list Quantity_list 276
# MRP_Price_list: 276
#
#
# Grocery_Name= Refined Palmolein Oil - Imported
# Discount_Price= ₹91.53
# MRP_Price= ₹101
# Brand_Name= Palmpure
# Quantity= 1 L
# list Quantity_list 277
# MRP_Price_list: 277
#
#
# Grocery_Name= Palakkad Red Matta Boiled Rice - Vadi
# Discount_Price= ₹1599
# MRP_Price= ₹1875
# Brand_Name= BB Royal
# Quantity= 25 kg - Bag
# list Quantity_list 278
# MRP_Price_list: 278
#
#
# Grocery_Name= Medium Poha
# Discount_Price= ₹86.24
# MRP_Price= ₹88
# Brand_Name= Vijay
# Quantity= 1 kg
# list Quantity_list 279
# MRP_Price_list: 279
#
#
# Grocery_Name= Dates/Kharjura - Desert King
# Discount_Price= ₹247
# MRP_Price= ₹247
# Brand_Name= Lion
# Quantity= 500 gm - Cup
# list Quantity_list 280
# MRP_Price_list: 280
#
#
# Grocery_Name= Tilnad Sesame Oil
# Discount_Price= ₹422.52
# MRP_Price= ₹430
# Brand_Name= Klf
# Quantity= 1 L
# list Quantity_list 281
# MRP_Price_list: 281
#
#
# Grocery_Name= Brown Chana
# Discount_Price= ₹75.96
# MRP_Price= ₹130
# Brand_Name= BB Super Saver
# Quantity= 1 kg
# list Quantity_list 282
# MRP_Price_list: 282
#
#
# Grocery_Name= Idli/Idly Rice
# Discount_Price= ₹513
# MRP_Price= ₹600
# Brand_Name= BB Popular
# Quantity= 10 kg
# list Quantity_list 283
# MRP_Price_list: 283
#
#
# Grocery_Name= Jaggery - Rich In Iron, Treats Anemia
# Discount_Price= ₹72
# MRP_Price= ₹90
# Brand_Name= Super Saver
# Quantity= 1 kg
# list Quantity_list 284
# MRP_Price_list: 284
#
#
# Grocery_Name= Sugar
# Discount_Price= ₹369.6
# MRP_Price= ₹435
# Brand_Name= 24 Mantra Organic
# Quantity= 3x1 kg - Multipack
# list Quantity_list 285
# MRP_Price_list: 285
#
#
# Grocery_Name= Besan/Kadale Hittu
# Discount_Price= ₹93
# MRP_Price= ₹130
# Brand_Name= BB Super Saver
# Quantity= 1 kg
# list Quantity_list 286
# ...
# MRP_Price= ₹350
# Brand_Name= Super Saver
# Quantity= 100 g
# list Quantity_list 340
# MRP_Price_list: 340
#
#
# Grocery_Name= Coconut Powder - Desiccated
# Discount_Price= ₹170
# MRP_Price= ₹250
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 341
# MRP_Price_list: 341
#
#
# Grocery_Name= 100% Pure California Almonds Whole - Premium Quality Badam Giri, Rich In Protein, Magnesium, Phosphorus, & Dietary Fibre, Premium Nuts & Dry Fruits
# Discount_Price= ₹1078.39
# MRP_Price= ₹1310
# Brand_Name= Tata Sampann
# Quantity= 1 kg - Pouch
# list Quantity_list 342
# MRP_Price_list: 342
#
#
# Grocery_Name= Double Roasted Suji Rava - Less Moisture, More Quantity, Made From MP Wheat
# Discount_Price= ₹69.3
# MRP_Price= ₹77
# Brand_Name= Aashirvaad
# Quantity= 1 kg
# list Quantity_list 343
# MRP_Price_list: 343
#
#
# Grocery_Name= Organic - Bay Leaf/Lavangada Ele
# Discount_Price= ₹11
# MRP_Price= ₹13
# Brand_Name= BB Royal
# Quantity= 20 g
# list Quantity_list 344
# MRP_Price_list: 344
#
#
# Grocery_Name= Schezwan Fried Rice Masala
# Discount_Price= ₹100
# MRP_Price= ₹100
# Brand_Name= Chings
# Quantity= 10 x 20 g - Multipack
# list Quantity_list 345
# MRP_Price_list: 345
#
#
# Grocery_Name= Organic - Turmeric Powder/Arisina Pudi
# Discount_Price= ₹43.7
# MRP_Price= ₹61
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 346
# MRP_Price_list: 346
#
#
# Grocery_Name= Organic - Quinoa
# Discount_Price= ₹566.2
# MRP_Price= ₹599
# Brand_Name= BB Royal
# Quantity= 2 kg
# list Quantity_list 347
# MRP_Price_list: 347
#
#
# Grocery_Name= Watermelon Seeds/Kallangadi Bija
# Discount_Price= ₹120
# MRP_Price= ₹160
# Brand_Name= BB Royal
# Quantity= 100 g
# list Quantity_list 348
# MRP_Price_list: 348
#
#
# Grocery_Name= Seeds - Flax
# Discount_Price= ₹29
# MRP_Price= ₹60
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 349
# MRP_Price_list: 349
#
#
# Grocery_Name= Fennel/Saunf/Sompu - Small
# Discount_Price= ₹171
# MRP_Price= ₹180
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 350
# MRP_Price_list: 350
#
#
# Grocery_Name= Organic - Kasuri Methi
# Discount_Price= ₹82
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 100 g
# list Quantity_list 351
# MRP_Price_list: 351
#
#
# Grocery_Name= Pure Desi Cow Ghee
# Discount_Price= ₹149
# MRP_Price= ₹205
# Brand_Name= Fresho
# Quantity= 200 ml - Jar
# list Quantity_list 352
# MRP_Price_list: 352
#
#
# Grocery_Name= Poha/Avalakki/Aval - Thick
# Discount_Price= ₹34
# MRP_Price= ₹40
# Brand_Name= BB Popular
# Quantity= 500 g - Pouch
# list Quantity_list 353
# MRP_Price_list: 353
#
#
# Grocery_Name= Coconut Milk - UHT Natural
# Discount_Price= ₹300
# MRP_Price= ₹300
# Brand_Name= Kara
# Quantity= 4x200 ml - Multi Pack
# list Quantity_list 354
# MRP_Price_list: 354
#
#
# Grocery_Name= Wheat Flour (Atta)
# Discount_Price= ₹300
# MRP_Price= ₹375
# Brand_Name= Organic Tattva
# Quantity= 5 kg - Pouch
# list Quantity_list 355
# MRP_Price_list: 355
#
#
# Grocery_Name= Organic - Urad Dal/Uddina Bele, White (Split), Unpolished
# Discount_Price= ₹168.34
# MRP_Price= ₹210
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 356
# MRP_Price_list: 356
#
#
# Grocery_Name= Tamarind Paste
# Discount_Price= ₹156
# MRP_Price= ₹156
# Brand_Name= Mother's Recipe
# Quantity= 3X200 g - Multipack
# list Quantity_list 357
# MRP_Price_list: 357
#
#
# Grocery_Name= Ponni Raw - Rice ( 6 + Months  Old)
# Discount_Price= ₹1497
# MRP_Price= ₹1690
# Brand_Name= BB Popular
# Quantity= 26 kg - (6 + Months Old)
# list Quantity_list 358
# MRP_Price_list: 358
#
#
# Grocery_Name= Mustard/Sasive/Rai - Big
# Discount_Price= ₹32
# MRP_Price= ₹60
# Brand_Name= BB Popular
# Quantity= 200 g
# list Quantity_list 359
# MRP_Price_list: 359
#
#
# Grocery_Name= Fenugreek Seeds
# Discount_Price= ₹49.2
# MRP_Price= ₹56
# Brand_Name= 24 Mantra Organic
# Quantity= 2x100 g - Multipack
# list Quantity_list 360
# MRP_Price_list: 360
#
#
# Grocery_Name= Masala - Garam
# Discount_Price= ₹44
# MRP_Price= ₹55
# Brand_Name= MTR
# Quantity= 50 g - Pouch
# list Quantity_list 361
# MRP_Price_list: 361
#
#
# Grocery_Name= Jaggery Powder
# Discount_Price= ₹204
# MRP_Price= ₹240
# Brand_Name= 24 Mantra Organic
# Quantity= 3x500 g - Multipack
# list Quantity_list 362
# MRP_Price_list: 362
#
#
# Grocery_Name= Indian Raisins/Ona Drakshi
# Discount_Price= ₹408
# MRP_Price= ₹600
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 363
# MRP_Price_list: 363
#
#
# Grocery_Name= Green Pumpkin Seeds/Kumbalakayi Bija
# Discount_Price= ₹84
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 100 g - Pouch
# list Quantity_list 364
# MRP_Price_list: 364
#
#
# Grocery_Name= Kuttu Atta
# Discount_Price= ₹103
# MRP_Price= ₹135
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 365
# MRP_Price_list: 365
#
#
# Grocery_Name= Green Moong Whole/Sabut
# Discount_Price= ₹147
# MRP_Price= ₹170
# Brand_Name= BB Popular
# Quantity= 1 kg - Pouch
# list Quantity_list 366
# MRP_Price_list: 366
#
#
# Grocery_Name= Seeds - Sunflower
# Discount_Price= ₹84
# MRP_Price= ₹100
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 367
# MRP_Price_list: 367
#
#
# Grocery_Name= A2 Desi Cow Ghee - Bilona Churned, Light On Gut, Lab-Tested, Clarified Butter
# Discount_Price= ₹507.5
# MRP_Price= ₹580
# Brand_Name= Anveshan
# Quantity= 250 ml - Bottle
# list Quantity_list 368
# MRP_Price_list: 368
#
#
# Grocery_Name= Popcorn Seeds
# Discount_Price= ₹23
# MRP_Price= ₹35
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 369
# MRP_Price_list: 369
#
#
# Grocery_Name= Masala - Spicy Sambar Powder
# Discount_Price= ₹115
# MRP_Price= ₹130
# Brand_Name= MTR
# Quantity= 200 g
# list Quantity_list 370
# MRP_Price_list: 370
#
#
# Grocery_Name= Cow Ghee - Intense Aroma & Flavour, Rich Texture, Immunity Booster
# Discount_Price= ₹1307.81
# MRP_Price= ₹1570
# Brand_Name= Aashirvaad Svasti
# Quantity= 2x1 L - Multipack
# list Quantity_list 371
# MRP_Price_list: 371
#
#
# Grocery_Name= A2 Desi Cow Ghee
# Discount_Price= ₹729
# MRP_Price= ₹1500
# Brand_Name= Fresho Organic
# Quantity= 500 ml
# list Quantity_list 372
# MRP_Price_list: 372
#
#
# Grocery_Name= Organic Sunflower Seeds/Suryakanti Bija
# Discount_Price= ₹95
# MRP_Price= ₹130
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 373
# MRP_Price_list: 373
#
#
# Grocery_Name= White Poha - Thin
# Discount_Price= ₹55.86
# MRP_Price= ₹57
# Brand_Name= Tata Sampann
# Quantity= 500 g
# list Quantity_list 374
# MRP_Price_list: 374
#
#
# Grocery_Name= Organic Sona Masoori White Rice/Akki
# Discount_Price= ₹820.8
# MRP_Price= ₹949
# Brand_Name= BB Royal
# Quantity= 10 kg
# list Quantity_list 375
# MRP_Price_list: 375
#
#
# Grocery_Name= Poha/Avalakki/Aval/Chivda - Thin
# Discount_Price= ₹76
# MRP_Price= ₹80
# Brand_Name= BB Popular
# Quantity= 1 kg
# list Quantity_list 376
# MRP_Price_list: 376
#
#
# Grocery_Name= Organic Tamarind/Hunisehannu
# Discount_Price= ₹309.7
# MRP_Price= ₹339
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 377
# MRP_Price_list: 377
#
#
# Grocery_Name= Sona Masoori Raw Rice (12 + Months Old)
# Discount_Price= ₹1499
# MRP_Price= ₹1820
# Brand_Name= BB Royal
# Quantity= 26 kg - Bag
# list Quantity_list 378
# MRP_Price_list: 378
#
#
# Grocery_Name= Organic - Red Chilli - Whole
# Discount_Price= ₹110.2
# MRP_Price= ₹169
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 379
# MRP_Price_list: 379
#
#
# Grocery_Name= Rice/Akki - Steam, Sona Masoori
# Discount_Price= ₹54
# MRP_Price= ₹70
# Brand_Name= BB Popular
# Quantity= 1 kg - Pouch
# list Quantity_list 380
# MRP_Price_list: 380
#
#
# Grocery_Name= Oil - Heart Pouch
# Discount_Price= ₹600
# MRP_Price= ₹600
# Brand_Name= Sundrop
# Quantity= 3x1 L - Multipack
# list Quantity_list 381
# MRP_Price_list: 381
#
#
# Grocery_Name= Basmati Rice/Basmati Akki - Mogra/Broken
# Discount_Price= ₹361.83
# MRP_Price= ₹415
# Brand_Name= India Gate
# Quantity= 5 kg - Bag
# list Quantity_list 382
# MRP_Price_list: 382
#
#
# Grocery_Name= Mix Dal
# Discount_Price= ₹84
# MRP_Price= ₹120
# Brand_Name= BB Royal
# Quantity= 500 g - Pouch
# list Quantity_list 383
# MRP_Price_list: 383
#
#
# Grocery_Name= Cumin/Jeera - Whole
# Discount_Price= ₹199
# MRP_Price= ₹500
# Brand_Name= Super Saver
# Quantity= 500 g
# list Quantity_list 384
# MRP_Price_list: 384
#
#
# Grocery_Name= Poppy Seed - Gluten Free, No Preservatives
# Discount_Price= ₹377.37
# MRP_Price= ₹860
# Brand_Name= Zoff
# Quantity= 200 g
# list Quantity_list 385
# MRP_Price_list: 385
#
#
# Grocery_Name= Organic Mustard Seeds - Whole, Big
# Discount_Price= ₹96
# MRP_Price= ₹96
# Brand_Name= 24 Mantra
# Quantity= 3X100 g - Multipack
# list Quantity_list 386
# MRP_Price_list: 386
#
#
# Grocery_Name= Corn Flour/ Starch
# Discount_Price= ₹67
# MRP_Price= ₹90
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 387
# MRP_Price_list: 387
#
#
# Grocery_Name= Refined Oil - Groundnut
# Discount_Price= ₹220
# MRP_Price= ₹220
# Brand_Name= Safal
# Quantity= 1 L - Pouch
# list Quantity_list 388
# MRP_Price_list: 388
#
#
# Grocery_Name= Gold - Pro Healthy Lifestyle Edible Oil
# Discount_Price= ₹432
# MRP_Price= ₹540
# Brand_Name= Saffola
# Quantity= 3X1 L - Multipack
# list Quantity_list 389
# MRP_Price_list: 389
#
#
# Grocery_Name= Olive Oil - Extra Virgin
# Discount_Price= ₹978
# MRP_Price= ₹1300
# Brand_Name= Del Monte
# Quantity= 2x250 ml - Multipack
# list Quantity_list 390
# MRP_Price_list: 390
#
#
# Grocery_Name= Refined Sunflower Oil - with Vitamins A, D & E
# Discount_Price= ₹566.5
# MRP_Price= ₹720
# Brand_Name= Freedom
# Quantity= 5 L - Can
# list Quantity_list 391
# MRP_Price_list: 391
#
#
# Grocery_Name= Organic - Flax Seeds
# Discount_Price= ₹76.95
# MRP_Price= ₹115
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 392
# MRP_Price_list: 392
#
#
# Grocery_Name= Refined Sunflower Oil - Trans Fat Free, Healthy Cooking Oil
# Discount_Price= ₹520
# MRP_Price= ₹750
# Brand_Name= Fiona
# Quantity= 5 L - Jar
# list Quantity_list 393
# MRP_Price_list: 393
#
#
# Grocery_Name= Urad Dal/Uddina Bele - Split
# Discount_Price= ₹104
# MRP_Price= ₹380
# Brand_Name= BB Super Saver
# Quantity= 2 kg
# list Quantity_list 394
# MRP_Price_list: 394
#
#
# Grocery_Name= Urad Balck, Whole - Desi, Unpolished Mature Pulses For Easy Cooking & Rich Flavour
# Discount_Price= ₹164
# MRP_Price= ₹180
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 395
# MRP_Price_list: 395
#
#
# Grocery_Name= Cardamom Green/Elakki
# Discount_Price= ₹175
# MRP_Price= ₹250
# Brand_Name= BB Popular
# Quantity= 50 g - Pouch
# list Quantity_list 396
# MRP_Price_list: 396
#
#
# Grocery_Name= Total Refined Cooking oil | Blended Rice Bran & Safflower oil | Helps Manage Cholesterol
# Discount_Price= ₹899
# MRP_Price= ₹1100
# Brand_Name= Saffola
# Quantity= 5 L - Jar
# list Quantity_list 397
# MRP_Price_list: 397
#
#
# Grocery_Name= Garam Masala - With Natural Oils, Crafted By Chef Sanjeev Kapoor
# Discount_Price= ₹69.7
# MRP_Price= ₹85
# Brand_Name= Tata Sampann
# Quantity= 100 g
# list Quantity_list 398
# MRP_Price_list: 398
#
#
# Grocery_Name= Organic - Red Poha Medium
# Discount_Price= ₹47.5
# MRP_Price= ₹65
# Brand_Name= BB Royal
# Quantity= 500 g
# list Quantity_list 399
# MRP_Price_list: 399
#
#
# Grocery_Name= Coconut Oil - Virgin (Cold Pressed)
# Discount_Price= ₹330
# MRP_Price= ₹375
# Brand_Name= Maxcare
# Quantity= 500 ml
# list Quantity_list 400
# MRP_Price_list: 400
#
#
# Grocery_Name= Extra Light Olive Oil for Indian Cooking - Deep Frying & Baking
# Discount_Price= ₹2055
# MRP_Price= ₹3199
# Brand_Name= La Espanola
# Quantity= 2 L - Bottle
# list Quantity_list 401
# MRP_Price_list: 401
#
#
# Grocery_Name= Organic - Puffed Rice/Kadle Puri
# Discount_Price= ₹35
# MRP_Price= ₹35
# Brand_Name= 24 Mantra Organic
# Quantity= 200 g - Pouch
# list Quantity_list 402
# MRP_Price_list: 402
#
#
# Grocery_Name= Organic - Green Moong Whole/Hesaru Kaalu
# Discount_Price= ₹331.55
# MRP_Price= ₹355
# Brand_Name= BB Royal
# Quantity= 2 kg
# list Quantity_list 403
# MRP_Price_list: 403
#
#
# Grocery_Name= Gold Low Calorie Sweetner
# Discount_Price= ₹288
# MRP_Price= ₹300
# Brand_Name= Sugar Free
# Quantity= 500 Pellets
# list Quantity_list 404
# MRP_Price_list: 404
#
#
# Grocery_Name= Sambar Powder - Perfect Colour, Smell & Taste
# Discount_Price= ₹90
# MRP_Price= ₹90
# Brand_Name= Eastern
# Quantity= 2x100 g - Multipack
# list Quantity_list 405
# MRP_Price_list: 405
#
#
# Grocery_Name= Urad Gota/Whole
# Discount_Price= ₹318
# MRP_Price= ₹400
# Brand_Name= BB Popular
# Quantity= 2 kg - Pouch
# list Quantity_list 406
# MRP_Price_list: 406
#
#
# Grocery_Name= Tasty Refined Cooking oil | Blended Rice bran & Corn oil | Pro Fitness Conscious
# Discount_Price= ₹729
# MRP_Price= ₹755
# Brand_Name= Saffola
# Quantity= 5 L - Jar
# list Quantity_list 407
# MRP_Price_list: 407
#
#
# Grocery_Name= Surti Kolam Raw Rice/Akki
# Discount_Price= ₹780
# MRP_Price= ₹800
# Brand_Name= Super Saver
# Quantity= 10 kg
# list Quantity_list 408
# MRP_Price_list: 408
#
#
# Grocery_Name= Chiroti/Barik Sooji
# Discount_Price= ₹26
# MRP_Price= ₹33
# Brand_Name= BB Super Saver
# Quantity= 500 g
# list Quantity_list 409
# MRP_Price_list: 409
#
#
# Grocery_Name= Organic - Barley
# Discount_Price= ₹133
# MRP_Price= ₹150
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 410
# MRP_Price_list: 410
#
#
# Grocery_Name= Steam Rice/Akki - Kolam
# Discount_Price= ₹1249
# MRP_Price= ₹2000
# Brand_Name= BB Royal
# Quantity= 25 kg - Bag
# list Quantity_list 411
# MRP_Price_list: 411
#
#
# Grocery_Name= Ragi - Huri Hittu
# Discount_Price= ₹75
# MRP_Price= ₹75
# Brand_Name= Indira's
# Quantity= 400 g - Pouch
# list Quantity_list 412
# MRP_Price_list: 412
#
#
# Grocery_Name= Ananas Flower/Ananas Huvu
# Discount_Price= ₹173
# MRP_Price= ₹200
# Brand_Name= BB Royal
# Quantity= 100 g
# list Quantity_list 413
# MRP_Price_list: 413
#
#
# Grocery_Name= Unpolished Kala Chana
# Discount_Price= ₹111
# MRP_Price= ₹145
# Brand_Name= Tata Sampann
# Quantity= 1 kg - Pouch
# list Quantity_list 414
# MRP_Price_list: 414
# Grocery_Name= Organic - Jaggery/Bella
# Discount_Price= ₹47.5
# MRP_Price= ₹55
# Brand_Name= BB Royal
# Quantity= 400 g
# list Quantity_list 415
# MRP_Price_list: 415
#
#
# Grocery_Name= Soya Chunks
# Discount_Price= ₹31
# MRP_Price= ₹55
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 416
# MRP_Price_list: 416
#
#
# Grocery_Name= Gold Atta - 100% MP Sharbati Wheat, 12-Hour Softness, High Fibre Atta
# Discount_Price= ₹526.5
# MRP_Price= ₹702
# Brand_Name= Pillsbury
# Quantity= 2 x 5 kg - Multipack
# list Quantity_list 417
# MRP_Price_list: 417
#
#
# Grocery_Name= Premium International Omani Dates
# Discount_Price= ₹422.73
# MRP_Price= ₹549
# Brand_Name= Happilo
# Quantity= 680 g
# list Quantity_list 418
# MRP_Price_list: 418
#
#
# Grocery_Name= Natural Jaggery/Bella Powder
# Discount_Price= ₹119
# MRP_Price= ₹119
# Brand_Name= Forgreen
# Quantity= 1 kg
# list Quantity_list 419
# MRP_Price_list: 419
#
#
# Grocery_Name= Oil - Mustard (Kachi Ghani)
# Discount_Price= ₹812
# MRP_Price= ₹825
# Brand_Name= Dhara
# Quantity= 5 L - Can
# list Quantity_list 420
# MRP_Price_list: 420
#
#
# Grocery_Name= Active Oil
# Discount_Price= ₹747
# MRP_Price= ₹747
# Brand_Name= Oleev
# Quantity= 3x1 L - Multipack
# list Quantity_list 421
# MRP_Price_list: 421
#
#
# Grocery_Name= Moth/Patanga Huruli - Whole
# Discount_Price= ₹29
# MRP_Price= ₹40
# Brand_Name= BB Royal
# Quantity= 200 g - Pouch
# list Quantity_list 422
# MRP_Price_list: 422
#
#
# Grocery_Name= Unpolished Moong Dal Chilka
# Discount_Price= ₹95.04
# MRP_Price= ₹99
# Brand_Name= Tata Sampann
# Quantity= 500 g - Pouch
# list Quantity_list 423
# MRP_Price_list: 423
#
#
# Grocery_Name= Cashew/Godambi - Split
# Discount_Price= ₹778
# MRP_Price= ₹1500
# Brand_Name= BB Popular
# Quantity= 1 kg
# list Quantity_list 424
# MRP_Price_list: 424
#
#
# Grocery_Name= Saffola Total 1L- Pack of 3
# Discount_Price= ₹507
# MRP_Price= ₹600
# Brand_Name= Saffola
# Quantity= 3 x 1 L - Multipack
# list Quantity_list 425
# MRP_Price_list: 425
#
#
# Grocery_Name= Hing - Yellow
# Discount_Price= ₹188
# MRP_Price= ₹200
# Brand_Name= Everest
# Quantity= 100 g - Bottle
# list Quantity_list 426
# MRP_Price_list: 426
#
#
# Grocery_Name= Kitchen King Masala
# Discount_Price= ₹39.48
# MRP_Price= ₹42
# Brand_Name= Everest
# Quantity= 50 g - Carton
# list Quantity_list 427
# MRP_Price_list: 427
#
#
# Grocery_Name= Powder - Black Pepper
# Discount_Price= ₹148
# MRP_Price= ₹148
# Brand_Name= Everest
# Quantity= 100 g - Carton
# list Quantity_list 428
# MRP_Price_list: 428
#
#
# Grocery_Name= Organic Rajma/Capparadavare Chitra
# Discount_Price= ₹205.2
# MRP_Price= ₹269
# Brand_Name= BB Royal
# Quantity= 1 kg
# list Quantity_list 429
# MRP_Price_list: 429
#
#
# Grocery_Name= Organic - Ajwain/Om Kalu
# Discount_Price= ₹99.75
# MRP_Price= ₹112
# Brand_Name= BB Royal
# Quantity= 200 g
# list Quantity_list 430
# MRP_Price_list: 430
#
#
# Grocery_Name= Dates Syrup
# Discount_Price= ₹390
# MRP_Price= ₹390
# Brand_Name= Lion
# Quantity= 1 kg
# list Quantity_list 431
# MRP_Price_list: 431
#
#
# Grocery_Name= Gingelly Oil - Tilnad 100% Pure
# Discount_Price= ₹386.51
# MRP_Price= ₹395
# Brand_Name= Klf
# Quantity= 1000 ml - Pouch
# list Quantity_list 432
# MRP_Price_list: 432

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
from csv import DictWriter
import time
